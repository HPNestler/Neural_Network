# %%
import sys
sys.path.append('../pkg_mod')

import db_connector as db
import chemistry_psql as cp
import importlib
importlib.reload(cp)
import psycopg2
import pandas as pd

from rdkit import Chem

# %%
#sdf = '../Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf'
#sdf = '../Drug_Libraries/L1021-DiscoveryProbe-FDA-approved-Drug-Library-SDF.sdf'
#sdf = '../Drug_Libraries/L1023P-DiscoveryProbe-Anti-cancer-Compound-Library Plus-SDF.sdf'
sdf = '../Drug_Libraries/L1029-DiscoveryProbe-Epigenetics-Compound-Library-SDF.sdf'


suppl = Chem.SDMolSupplier(sdf)

for mol in suppl:
    m = Chem.MolToSmiles(mol)
    #print(m)
    ml = (m,)
    #print(ml)
    cp.SmilesInsert(ml)
    #print(mol.GetProp('Item Name')) 
    #print(mol.GetProp('CAS Number'))
# Out:
# Structure Exist:  CCCCCCCCCC(=O)N[C@@H](Cc1c[nH]c2ccccc12)C(=O)N[C@H](CC(N)=O)C(=O)N[C@@H](CC(=O)O)C(=O)N[C@@H]1C(=O)NCC(=O)N[C@@H](CCCN)C(=O)N[C@@H](CC(=O)O)C(=O)N[C@H](C)C(=O)N[C@@H](CC(=O)O)C(=O)NCC(=O)N[C@H](CO)C(=O)N[C@@H](C(C)CC(=O)O)C(=O)N[C@@H](CC(=O)c2ccccc2N)C(=O)O[C@@H]1C
# Structure Exist:  Cl.Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)C2(F)F)c(=O)n1
# Structure Exist:  Cn1cc(C2=C(c3cn(C4CCN(Cc5ccccn5)CC4)c4ccccc34)C(=O)NC2=O)c2ccccc21
# Structure Exist:  COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)C[C@@H]3O[C@H]1C[C@H](N)[C@H](O)[C@H](C)O1.Cl
# Structure Exist:  O=c1nc(-c2ccc(C(F)(F)F)cc2)[nH]c2c1CSCC2
# Structure Exist:  Nc1ncn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)n1
# Structure Exist:  Nc1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)n1
# Structure Exist:  O=C(Nc1ccc2c(O)cc(S(=O)(=O)[O-])cc2c1)Nc1ccc2c(O)cc(S(=O)(=O)[O-])cc2c1.[Na+].[Na+]
# Structure Exist:  COc1cc2nc(N3CCCN(C)CC3)nc(NC3CCN(Cc4ccccc4)CC3)c2cc1OC
# ...

# %%
inf = open('../Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf', 'rb')

print(inf)
# Out:
# <_io.BufferedReader name='../Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf'>

# %%
import os
from rdkit import Chem
from rdkit.Chem.ChemUtils.SDFToCSV import Convert
from rdkit.Chem import PandasTools
from rdkit import RDConfig

#sdfFile = '../Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf'
#sdfFile = os.path.join(RDConfig.RDDataDir,'C:/Users/peter/Python_Projects/Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf')
#frame=PandasTools.LoadSDF(sdfFile) #,smilesName='SMILES',molColName='Molecule',includeFingerprints=True)
#frame.info
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_888\2265540158.py in <module>
#       7 sdfFile = '../Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf'
#       8 #sdfFile = os.path.join(RDConfig.RDDataDir,'C:/Users/peter/Python_Projects/Drug_Libraries/L1033-DiscoveryProbe-DNA-Damage-DNA-Repair-Library-SDF.sdf')
# ----> 9 frame=PandasTools.LoadSDF(sdfFile) #,smilesName='SMILES',molColName='Molecule',includeFingerprints=True)
#      10 frame.info
#
# ~\anaconda3\envs\rdkit\lib\site-packages\rdkit\Chem\PandasTools.py in LoadSDF(filename, idName, molColName, includeFingerprints, isomericSmiles, smilesName, embedProps, removeHs, strictParsing)
#     466     if mol is None:
#     467       continue
# --> 468     row = dict((k, mol.GetProp(k)) for k in mol.GetPropNames())
# ...
