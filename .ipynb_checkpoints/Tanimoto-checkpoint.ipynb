# %%
import pandas as pd
from rdkit import Chem, rdBase
from rdkit.Chem import Draw,rdDepictor
from rdkit.Chem import AllChem, Descriptors, DataStructs
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D

df = pd.read_csv("../RBP_Nodes.csv")
print(df)
# Out:
#           CHEMBLID             Name  \
# 0    CHEMBL1172192              NaN
# 1    CHEMBL1201753     PITAVASTATIN
# 2    CHEMBL1240928              NaN
# 3    CHEMBL1240971        OKICENONE
# 4    CHEMBL1242196  DEHYDROMUTACTIN
# ..             ...              ...
# 107       CHEMBL81       RALOXIFENE
# 108       CHEMBL83        TAMOXIFEN
# 109      CHEMBL896      HYDROXYZINE
# 110  CHEMBL4439279              NaN
# 111  CHEMBL4439280              NaN
#
#                                               Synonyms            Type  \
# 0                                                  NaN  Small molecule
# 1                             ITAVASTATIN|PITAVASTATIN  Small molecule
# 2                                                  NaN  Small molecule
# 3                                            Okicenone  Small molecule
# 4                                      Dehydromutactin  Small molecule
# ..                                                 ...             ...
# 107    Evista|J22.982B|LY-139481|RALOXIFENE|Raloxifene  Small molecule
# 108  ICI-46474|ICI-47699|Nolvadex|Soltamox|TAMOXIFE...  Small molecule
# 109  Atarax|HYDROXYZINE|Hydroxyzine|NSC-169188|Orga...  Small molecule
# 110                                                NaN  Small molecule
# 111                                                NaN  Small molecule
#
#      Max Phase  Molecular Weight  Targets  Bioactivities AlogP     PSA  ...  \
# 0          0.0            697.14     99.0          112.0  5.37  189.78  ...
# 1          4.0            421.47     16.0           50.0  4.52   90.65  ...
# 2          0.0            230.22      4.0           22.0  2.13   70.67  ...
# 3          0.0            258.27      2.0            4.0  2.57   77.76  ...
# 4          0.0            284.27      3.0           18.0  2.89    90.9  ...
# ..         ...               ...      ...            ...   ...     ...  ...
# 107        4.0            473.59    203.0         1663.0  6.08      70  ...
# 108        4.0            371.52    279.0         3738.0     6   12.47  ...
# 109        4.0            374.91     42.0         1509.0  3.06   35.94  ...
# 110        0.0            484.52      3.0            6.0  4.92   92.34  ...
# 111        0.0            434.51      5.0            9.0  4.04   92.34  ...
#
#     Structure Type Inorganic Flag Heavy Atoms HBA Lipinski HBD Lipinski  \
# 0              MOL           -1.0          49           13            5
# 1              MOL            0.0          31            5            3
# 2              MOL           -1.0          17            4            2
# 3              MOL           -1.0          19            4            3
# 4              MOL           -1.0          21            5            3
# ..             ...            ...         ...          ...          ...
# 107            MOL            0.0          34            5            2
# 108            MOL            0.0          28            2            0
# 109            MOL            0.0          26            4            1
# 110            MOL           -1.0          32            6            2
# 111            MOL           -1.0          29            6            2
#
#     #RO5 Violations (Lipinski) Molecular Weight (Monoisotopic)  \
# 0                            3                        696.2086
# 1                            0                        421.1689
# 2                            0                        230.0579
# 3                            0                        258.0892
# 4                            0                        284.0685
# ..                         ...                             ...
# 107                          1                        473.1661
# 108                          1                        371.2249
# 109                          0                        374.1761
# 110                          0                        484.0738
# 111                          0                        434.0770
#
#     Molecular Species Molecular Formula  \
# 0                ACID     C35H37ClN2O11
# 1                ACID        C25H24FNO4
# 2             NEUTRAL          C13H10O4
# 3             NEUTRAL          C15H14O4
# 4                ACID          C16H12O5
# ..                ...               ...
# 107           NEUTRAL        C28H27NO4S
# 108              BASE          C26H29NO
# 109           NEUTRAL      C21H27ClN2O2
# 110           NEUTRAL    C21H19F3N2O4S2
# 111           NEUTRAL     C20H19FN2O4S2
#
#                                                 Smiles
# 0    COC1C(OC(=O)c2ccc(C)[nH]2)C(O)C(Oc2ccc3c(O)c(N...
# 1    O=C(O)C[C@H](O)C[C@H](O)/C=C/c1c(C2CC2)nc2cccc...
# 2                       Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# 3                   Cc1cc(O)cc2cc3c(c(O)c12)C(=O)CCC3O
# 4                Cc1cc(O)c2c(O)cccc2c1-c1cc(=O)cc(O)o1
# ..                                                 ...
# 107  O=C(c1ccc(OCCN2CCCCC2)cc1)c1c(-c2ccc(O)cc2)sc2...
# 108      CC/C(=C(\c1ccccc1)c1ccc(OCCN(C)C)cc1)c1ccccc1
# 109            OCCOCCN1CCN(C(c2ccccc2)c2ccc(Cl)cc2)CC1
# 110  Cc1ccc(S(=O)(=O)Nc2ccc(C)cc2NS(=O)(=O)c2cccc(C...
# 111  Cc1ccc(S(=O)(=O)Nc2ccc(F)cc2NS(=O)(=O)c2ccc(C)...
#
# [112 rows x 31 columns]

# %%
import os
os.getcwd()
# Out:
# '/home/peter/Python_projects/Neural_Network'

# %%
m = df[["CHEMBLID", "Type", "Smiles"]]
r = m.to_records(index=False)
#print(r[0][1])
#mol = Chem.MolFromSmiles(r[0][1])
mol = []
rcl = []
for i in r:
    #print(i[1])
    if i[1] != 'Protein':
        rcl.append(i)
        mt = Chem.MolFromSmiles(i[2])
        mol.append(mt)
    else:
        print('Fail',i)

print(rcl)
Draw.MolsToGridImage(mol, molsPerRow=4, maxMols = 200)
# Out:
# Fail ('CHEMBL1250379', 'Protein', nan)
# Fail ('CHEMBL3774293', 'Protein', nan)
# Fail ('CHEMBL3826841', 'Protein', nan)
# Fail ('CHEMBL4105924', 'Protein', nan)
# Fail ('CHEMBL4295873', 'Protein', nan)
# Fail ('CHEMBL4295897', 'Protein', nan)
# Fail ('CHEMBL4523458', 'Protein', nan)
# Fail ('CHEMBL4523614', 'Protein', nan)
# [('CHEMBL1172192', 'Small molecule', 'COC1C(OC(=O)c2ccc(C)[nH]2)C(O)C(Oc2ccc3c(O)c(NC(=O)c4ccc(O)c(CC=C(C)C)c4)c(=O)oc3c2Cl)OC1(C)C'), ('CHEMBL1201753', 'Small molecule', 'O=C(O)C[C@H](O)C[C@H](O)/C=C/c1c(C2CC2)nc2ccccc2c1-c1ccc(F)cc1'), ('CHEMBL1240928', 'Small molecule', 'Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2'), ('CHEMBL1240971', 'Small molecule', 'Cc1cc(O)cc2cc3c(c(O)c12)C(=O)CCC3O'), ('CHEMBL1242196', 'Small molecule', 'Cc1cc(O)c2c(O)cccc2c1-c1cc(=O)cc(O)o1'), ('CHEMBL1242197', 'Small molecule', 'Cc1cc(O)cc2oc(Cc3cc(O)cc(=O)o3)cc(=O)c12'), ('CHEMBL1309685', 'Small molecule', 'COc1cc(OC)c2c(-c3ccccc3)cc(=O)oc2c1C(CC(=O)N1CCCC1)c1ccc2c(c1)OCO2'), ('CHEMBL1330249', 'Small molecule', 'CCN(CC)C(=O)CC(c1cc(OC)c(OC)c(OC)c1)c1c(OC)cc(OC)c2c(-c3ccccc3)cc(=O)oc12'), ('CHEMBL1390568', 'Small molecule', 'COc1ccc(C(CC(=O)N2CCOCC2)c2c(OC)cc(OC)c3c(-c4ccccc4)cc(=O)oc23)cc1'), ('CHEMBL1398194', 'Small molecule', 'COc1cc(C(CC(=O)N2CCCC2)c2c(OC)cc(OC)c3c(-c4ccccc4)cc(=O)oc23)cc(OC)c1OC'), ('CHEMBL1483840', 'Small molecule', 'CC#CC#Cc1cccc(=O)o1'), ('CHEMBL1499653', 'Small molecule', 'COc1ccc(C(CC(=O)N2CCCC2)c2c(OC)cc(OC)c3c(-c4ccccc4)cc(=O)oc23)cc1'), ('CHEMBL1506938', 'Small molecule', 'Cc1ccc(Nc2ccc(N)cc2S(=O)(=O)O)cc1'), ('CHEMBL1522581', 'Small molecule', 'CCN(CC)C(=O)CC(c1ccc(OC)cc1)c1c(OC)cc(OC)c2c(-c3ccccc3)cc(=O)oc12'), ('CHEMBL1568877', 'Small molecule', 'O=C(Nc1cccc([N+](=O)[O-])c1)c1ccc2ccccc2c1O'), ('CHEMBL1570894', 'Small molecule', 'O=S(=O)(c1ccccc1)N1CCN(S(=O)(=O)c2ccccc2)c2ccccc21'), ('CHEMBL1580068', 'Small molecule', 'CC1=CC(C)(C)N=C(S)N1c1cccc2cc(S(=O)(=O)O)ccc12'), ('CHEMBL164', 'Small molecule', 'O=c1c(O)c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12'), ('CHEMBL1655', 'Small molecule', 'CN(C)CCOc1ccc(/C(=C(/CCCl)c2ccccc2)c2ccccc2)cc1'), ('CHEMBL1700644', 'Small molecule', 'COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)CC(O)(C(C)=NO)CC3OC1CC(N)C(O)C(C)O1'), ('CHEMBL1706128', 'Small molecule', 'CCOC(=O)C(=O)Cc1cccnn1'), ('CHEMBL1710057', 'Small molecule', 'O=C(O)C1=NN(c2cc(Cl)c(S(=O)(=O)O)cc2Cl)C(=O)C1'), ('CHEMBL1736648', 'Small molecule', 'O=C(O)c1cc(N2C(=O)C=CC2=O)cc(N2C(=O)C=CC2=O)c1'), ('CHEMBL187709', 'Small molecule', 'CCN(CC)CCOc1ccc(C(O)(Cc2ccc(Cl)cc2)c2ccc(C)cc2)cc1'), ('CHEMBL2139421', 'Small molecule', 'Cc1ccc(NS(=O)(=O)c2ccccc2)c(NS(=O)(=O)c2ccccc2)c1'), ('CHEMBL227075', 'Small molecule', 'Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1'), ('CHEMBL2355051', 'Small molecule', 'CCN(CC)CCOc1ccc(C(=C(Cl)c2ccccc2)c2ccccc2)cc1'), ('CHEMBL27953', 'Small molecule', 'COCC(=O)OC1CCn2c1nc1c2C(=O)C(C)=C(NC(C)=O)C1=O'), ('CHEMBL301327', 'Small molecule', 'COc1ccc2c(c1)OC(C)(C)[C@@H](c1ccccc1)[C@@H]2c1ccc(OCCN2CCCC2)cc1'), ('CHEMBL312163', 'Small molecule', 'COc1cc(O)c2c(=O)c(O)c(-c3ccc(O)c(O)c3)oc2c1'), ('CHEMBL328190', 'Small molecule', 'Oc1ccc2c(c1)CC[C@H](c1ccccc1)[C@@H]2c1ccc(OCCN2CCCC2)cc1'), ('CHEMBL3561597', 'Small molecule', 'COC(=O)CC1OCC=C2CN3CCC45C6=CC(=O)C(=O)C([N+](=O)[O-])=C6NC4C1C2CC35'), ('CHEMBL3561684', 'Small molecule', 'CSC1=NC(=O)/C(=N\\Nc2ccc([As](=O)(O)O)cc2)C(N)=N1'), ('CHEMBL36327', 'Small molecule', 'O=C(O[C@@H]1Cc2c(O)cc(O)cc2O[C@@H]1c1ccc(O)c(O)c1)c1cc(O)c(O)c(O)c1'), ('CHEMBL4061748', 'Small molecule', 'N#Cc1c(N)nc(SCC(=O)c2ccc(O)c(O)c2)c(C#N)c1-c1ccc(COc2ccccc2)cc1'), ('CHEMBL4063466', 'Small molecule', 'CC(=O)Nc1ccc(S(=O)(=O)Nc2ccccc2NS(=O)(=O)c2ccc(NC(C)=O)cc2)cc1'), ('CHEMBL4064932', 'Small molecule', 'COc1ccc(SC2=CC(=O)C(=O)c3c(-c4ccccc4)cn(S(=O)(=O)c4ccccc4)c32)cc1'), ('CHEMBL4066821', 'Small molecule', 'CO[C@H]1[C@@H](OC(=O)c2ccc[nH]2)[C@@H](O)C(Oc2ccc3c(O)c(NC(=O)c4ccc(O)c(CC(C)=C(C)C)c4)c(=O)oc3c2Cl)OC1(C)C'), ('CHEMBL4067653', 'Small molecule', 'O=C1C=C(c2ccc([N+](=O)[O-])cc2)c2c(c(-c3ccccc3)cn2S(=O)(=O)c2ccccc2)C1=O'), ('CHEMBL4070465', 'Small molecule', 'CC1=CC(=O)C(=O)c2c(-c3ccccc3)cn(S(=O)(=O)c3ccccc3)c21'), ('CHEMBL4073526', 'Small molecule', 'CS(=O)(=O)n1cc(-c2ccccc2)c2c1C=CC(=O)C2=O'), ('CHEMBL4073683', 'Small molecule', 'O=C1C(=O)c2c(-c3ccccc3)cn(S(=O)(=O)c3ccccc3)c2C2=C1C1C=CC2CC1'), ('CHEMBL4075458', ...
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x5200 at 0x7F4BE4BF9710>

# %%
nmol = len(mol)
print(nmol)
fps = [Chem.RDKFingerprint(i) for i in mol]
tmd = []
for i in range(0, nmol-1):
    for j in range(i+1, nmol):
        td = DataStructs.FingerprintSimilarity(fps[i],fps[j])
        if td >= 0.6:
            #print(r[i][0],r[j][0],td)
            k = (r[i][0],"cc",r[j][0],td)
            #print(k)
            tmd.append(k)
        #else:
            #print(r[i][0],r[j][0],'No Connect')
            
print(len(tmd))
print(tmd)
# Out:
# 104
# 585
# [('CHEMBL1172192', 'cc', 'CHEMBL1250379', 0.6066739606126915), ('CHEMBL1172192', 'cc', 'CHEMBL1390568', 0.6032876712328767), ('CHEMBL1172192', 'cc', 'CHEMBL1655', 0.6277217206585236), ('CHEMBL1172192', 'cc', 'CHEMBL2355051', 0.6046389035318924), ('CHEMBL1172192', 'cc', 'CHEMBL3826841', 0.6419753086419753), ('CHEMBL1172192', 'cc', 'CHEMBL4061748', 0.9766414141414141), ('CHEMBL1172192', 'cc', 'CHEMBL4063466', 0.6406970784213224), ('CHEMBL1172192', 'cc', 'CHEMBL4064932', 0.6062337662337662), ('CHEMBL1172192', 'cc', 'CHEMBL4067653', 0.6747109100050277), ('CHEMBL1172192', 'cc', 'CHEMBL4075916', 0.615056059797117), ('CHEMBL1172192', 'cc', 'CHEMBL4076484', 0.642051282051282), ('CHEMBL1172192', 'cc', 'CHEMBL4078539', 0.6340710241893979), ('CHEMBL1172192', 'cc', 'CHEMBL4088244', 0.6416837782340863), ('CHEMBL1172192', 'cc', 'CHEMBL4095060', 0.6339331619537275), ('CHEMBL1172192', 'cc', 'CHEMBL4095140', 0.6492039034411916), ('CHEMBL1172192', 'cc', 'CHEMBL4439278', 0.643305439330544), ('CHEMBL1250379', 'cc', 'CHEMBL1309685', 0.9667630057803468), ('CHEMBL1250379', 'cc', 'CHEMBL1330249', 0.9306151645207439), ('CHEMBL1250379', 'cc', 'CHEMBL1390568', 0.9776011560693642), ('CHEMBL1250379', 'cc', 'CHEMBL1483840', 0.9570596797671034), ('CHEMBL1250379', 'cc', 'CHEMBL1506938', 0.9454148471615721), ('CHEMBL1250379', 'cc', 'CHEMBL4061748', 0.6102900930487137), ('CHEMBL1250379', 'cc', 'CHEMBL4067653', 0.6046986721144024), ('CHEMBL1250379', 'cc', 'CHEMBL4095140', 0.6040339702760085), ('CHEMBL1309685', 'cc', 'CHEMBL1330249', 0.9468317552804079), ('CHEMBL1309685', 'cc', 'CHEMBL1390568', 0.9889948642699926), ('CHEMBL1309685', 'cc', 'CHEMBL1483840', 0.9537784299339692), ('CHEMBL1309685', 'cc', 'CHEMBL1506938', 0.9636498516320475), ('CHEMBL1309685', 'cc', 'CHEMBL4061748', 0.6004390779363337), ('CHEMBL1330249', 'cc', 'CHEMBL1390568', 0.9379956741167988), ('CHEMBL1330249', 'cc', 'CHEMBL1483840', 0.9701492537313433), ('CHEMBL1330249', 'cc', 'CHEMBL1506938', 0.9803773584905661), ('CHEMBL1390568', 'cc', 'CHEMBL1483840', 0.9647835656639765), ('CHEMBL1390568', 'cc', 'CHEMBL1506938', 0.9530447542186353), ('CHEMBL1390568', 'cc', 'CHEMBL4061748', 0.606027397260274), ('CHEMBL1390568', 'cc', 'CHEMBL4067653', 0.6015345268542199), ('CHEMBL1390568', 'cc', 'CHEMBL4095140', 0.6007442849548112), ('CHEMBL1483840', 'cc', 'CHEMBL1506938', 0.9878326996197718), ('CHEMBL1580068', 'cc', 'CHEMBL301327', 0.9538461538461539), ('CHEMBL1580068', 'cc', 'CHEMBL4445686', 0.992), ('CHEMBL164', 'cc', 'CHEMBL4556019', 0.9292364990689013), ('CHEMBL1655', 'cc', 'CHEMBL3826841', 0.6290322580645161), ('CHEMBL1655', 'cc', 'CHEMBL4061748', 0.6321105794790005), ('CHEMBL1655', 'cc', 'CHEMBL4063466', 0.6261004660797514), ('CHEMBL1655', 'cc', 'CHEMBL4067653', 0.6598984771573604), ('CHEMBL1655', 'cc', 'CHEMBL4075916', 0.9733688415446072), ('CHEMBL1655', 'cc', 'CHEMBL4076484', 0.6308411214953271), ('CHEMBL1655', 'cc', 'CHEMBL4078539', 0.6201873048907388), ('CHEMBL1655', 'cc', 'CHEMBL4088244', 0.6262312078797304), ('CHEMBL1655', 'cc', 'CHEMBL4095060', 0.618380062305296), ('CHEMBL1655', 'cc', 'CHEMBL4095140', 0.631279129984464), ('CHEMBL1655', 'cc', 'CHEMBL4439278', 0.609717868338558), ('CHEMBL187709', 'cc', 'CHEMBL3774293', 0.6947368421052632), ('CHEMBL187709', 'cc', 'CHEMBL4100171', 0.7552986512524085), ('CHEMBL187709', 'cc', 'CHEMBL4102819', 0.9141221374045801), ('CHEMBL187709', 'cc', 'CHEMBL4105230', 0.6683587140439933), ('CHEMBL187709', 'cc', 'CHEMBL4105924', 0.7788617886178861), ('CHEMBL187709', 'cc', 'CHEMBL4159534', 0.697508896797153), ('CHEMBL187709', 'cc', 'CHEMBL4160599', 0.81419624217119), ('CHEMBL187709', 'cc', 'CHEMBL4161003', 0.6517412935323383), ('CHEMBL187709', 'cc', 'CHEMBL4162127', 0.7640918580375783), ('CHEMBL187709', 'cc', 'CHEMBL4163991', 0.7252747252747253), ('CHEMBL187709', 'cc', 'CHEMBL4164411', 0.7461832061068703), ('CHEMBL187709', 'cc', 'CHEMBL4165508', 0.8756855575868373), ('CHEMBL187709', 'cc', 'CHEMBL4166638', 0.7480916030534351), ('CHEMBL187709', 'cc', 'CHEMBL4167849', 0.6971 ...

# %%
dfo = pd.DataFrame(tmd, columns =['Source', 'Interaction', 'Target', 'Weight'])
print(dfo)
dfo.to_csv('../RBP_Tani.csv', index=False)
# Out:
#             Source Interaction         Target    Weight
# 0    CHEMBL1172192          cc  CHEMBL1250379  0.606674
# 1    CHEMBL1172192          cc  CHEMBL1390568  0.603288
# 2    CHEMBL1172192          cc     CHEMBL1655  0.627722
# 3    CHEMBL1172192          cc  CHEMBL2355051  0.604639
# 4    CHEMBL1172192          cc  CHEMBL3826841  0.641975
# ..             ...         ...            ...       ...
# 580  CHEMBL4295873          cc  CHEMBL4297528  0.940426
# 581  CHEMBL4456988          cc    CHEMBL44839  0.691949
# 582  CHEMBL4456988          cc  CHEMBL4523458  0.979651
# 583    CHEMBL44839          cc  CHEMBL4523458  0.675613
# 584       CHEMBL50          cc      CHEMBL567  0.634146
#
# [585 rows x 4 columns]
