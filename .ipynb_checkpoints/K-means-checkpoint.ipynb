# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import sklearn.datasets
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=300, centers=6, cluster_std=0.60, random_state=0)

plc = ['b','g','r','c','m','y','k']
colors = []

for i in y:
    j = plc[i]
    #print(i, j)
    colors.append(j)
    
#print(colors)

plt.scatter(X[:,0], X[:,1], c = colors)
print(X)
#print(y)
# Out:
# [[-1.46826903e+00  3.26765447e+00]
#  [ 6.00506856e+00  1.62349966e+00]
#  [ 1.03128879e+01 -1.92046896e+00]
#  [ 1.00647373e+01 -2.86062091e+00]
#  [ 1.79417539e+00  2.00722190e+00]
#  [-1.60712495e+00  3.56452854e+00]
#  [ 1.08909896e+01 -2.37552442e+00]
#  [ 1.21767506e+00  3.89290127e+00]
#  [-2.09357177e+00  2.67185245e+00]
#  [ 8.65529404e+00 -2.54113564e+00]
#  [ 5.06668726e+00  2.26639672e-01]
#  [ 5.68928886e+00  1.48885510e+00]
#  [ 1.16411070e+00  3.79132988e+00]
#  [-1.63963193e+00  7.52274643e+00]
#  [-1.43300009e+00  3.05719088e+00]
#  [ 2.77180174e-01  4.84428322e+00]
#  [ 7.67522789e-01  4.39759671e+00]
#  [ 4.90424315e+00  8.28289688e-01]
#  [ 1.32000621e+00  1.40428145e+00]
#  [-9.01142876e-01  8.04525269e+00]
#  [ 4.66341830e+00  1.81963357e-01]
#  [-4.29536666e-01  7.42179050e+00]
#  [ 1.19008992e+00  4.72773123e+00]
#  [ 7.90008319e+00 -2.18027897e+00]
#  [-7.43277016e-01  7.68578487e+00]
#  [ 2.33812285e+00  3.43116792e+00]
#  [-2.74531469e+00  4.15657798e+00]
# ...

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=6, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)

plt.scatter(X[:,0], X[:,1])
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red')
plt.show()

print(kmeans.cluster_centers_)
print(kmeans.n_iter_)
print(kmeans.labels_)
print(len(y),len(kmeans.labels_))
# Out:
# [[-1.37472707  7.70985923]
#  [ 9.30538203 -2.35144383]
#  [ 2.04067415  0.94821936]
#  [ 5.62889458  0.43930526]
#  [ 0.95293573  4.36339816]
#  [-1.63157453  2.92435213]]
# 3
# [5 3 1 1 2 5 1 4 5 1 3 3 4 0 5 4 4 3 2 0 3 0 4 1 0 4 5 2 0 0 5 3 4 3 2 1 2
#  1 0 2 4 0 4 2 3 3 3 5 5 5 1 0 5 0 3 5 0 5 3 0 3 2 2 0 1 3 1 3 0 5 5 0 2 0
#  3 1 2 1 0 4 3 1 5 4 3 3 0 2 3 2 2 3 3 2 2 3 3 3 3 2 4 1 3 4 5 5 2 0 5 4 0
#  2 2 0 4 0 1 2 2 2 4 1 0 2 2 1 5 0 0 5 5 5 5 0 5 1 1 1 0 5 2 3 1 0 3 4 3 3
#  1 4 1 4 0 1 4 3 1 0 4 3 4 5 1 3 1 5 4 1 4 4 5 2 0 1 4 2 2 4 3 5 4 1 0 5 5
#  4 0 2 4 0 1 2 4 4 4 5 3 0 4 3 4 2 0 0 1 2 0 4 2 1 5 1 4 3 0 1 2 3 2 0 4 4
#  1 0 0 5 5 4 3 5 2 0 5 0 4 1 1 2 4 3 4 5 0 4 1 5 1 3 1 2 4 5 3 3 1 3 0 2 5
#  2 0 1 2 5 3 4 4 1 2 1 1 4 1 2 5 5 0 0 4 2 2 2 2 3 1 5 2 4 5 5 5 1 0 3 2 5
#  5 3 3 1]
# 300 300

# %%
startpts=np.array([[0,6], [4,6], [8,6], [0,0], [4,0], [8,0]], np.float64)


kmeans = KMeans(n_clusters=6, init=startpts, max_iter=300, n_init=1, random_state=0)
pred_y = kmeans.fit_predict(X)

colfit = []

for i in kmeans.labels_:
    j = plc[i]
    #print(i, j)
    colfit.append(j)
    
#print(colfit)

plt.scatter(startpts[:, 0], startpts[:, 1], s=100, c='k')
plt.show()

plt.scatter(X[:,0], X[:,1], c= colors)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='k')
plt.show()

plt.scatter(X[:,0], X[:,1], c= colfit)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='k')
plt.show()

# %%
print(kmeans.cluster_centers_)
print(kmeans.n_iter_)
print(kmeans.labels_)
print(len(y),len(kmeans.labels_))
# Out:
# [[-1.37472707  7.70985923]
#  [ 1.04051531  4.00273812]
#  [ 8.8657495  -2.65265539]
#  [-1.63157453  2.92435213]
#  [ 4.03016669  0.60203618]
#  [ 9.82147241 -1.99784766]]
# 11
# [3 4 5 5 1 3 5 1 3 2 4 4 1 0 3 1 1 4 1 0 4 0 1 2 0 1 3 4 0 0 3 4 1 4 4 5 4
#  5 0 4 1 0 1 4 4 4 4 3 3 3 5 0 3 0 4 3 0 3 4 0 4 4 4 0 2 4 2 4 0 3 3 0 1 0
#  4 5 4 2 0 1 4 5 3 1 4 4 0 4 4 1 4 4 4 4 4 4 4 4 4 4 1 2 4 1 3 3 4 0 3 1 0
#  4 4 0 1 0 5 4 4 4 1 5 0 4 4 5 3 0 0 3 3 3 3 0 3 2 2 2 0 3 1 4 2 0 4 1 4 4
#  2 1 2 1 0 5 1 4 2 0 1 4 1 3 2 4 5 3 1 5 1 1 3 4 0 2 1 4 4 1 4 3 1 5 0 3 3
#  1 0 4 1 0 2 4 1 1 1 3 4 0 1 4 1 4 0 0 2 1 0 1 4 2 3 2 1 4 0 5 1 4 4 0 1 1
#  2 0 0 3 3 1 4 3 4 0 3 0 1 2 2 1 1 4 1 3 0 1 2 3 2 4 5 4 1 3 4 4 2 4 0 4 3
#  4 0 2 4 3 4 1 1 5 4 2 5 1 2 4 3 3 0 0 1 4 4 4 4 4 5 3 4 1 3 3 3 5 0 4 4 3
#  3 4 4 5]
# 300 300

# %%
startpts2 = kmeans.cluster_centers_

kmeans = KMeans(n_clusters=6, init=startpts2, max_iter=300, n_init=1, random_state=0)
pred_y = kmeans.fit_predict(X)

colfit = []

for i in kmeans.labels_:
    j = plc[i]
    #print(i, j)
    colfit.append(j)
    
#print(colfit)

plt.scatter(startpts2[:, 0], startpts2[:, 1], s=100, c='k')
plt.show()

plt.scatter(X[:,0], X[:,1], c= colors)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='k')
plt.show()

plt.scatter(X[:,0], X[:,1], c= colfit)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='k')
plt.show()

# %%
print(pred_y)
# Out:
# [3 4 5 5 1 3 5 1 3 2 4 4 1 0 3 1 1 4 1 0 4 0 1 2 0 1 3 4 0 0 3 4 1 4 4 5 4
#  5 0 4 1 0 1 4 4 4 4 3 3 3 2 0 3 0 4 3 0 3 4 0 4 4 4 0 2 4 2 4 0 3 3 0 1 0
#  4 5 4 2 0 1 4 5 3 1 4 4 0 4 4 1 4 4 4 4 4 4 4 4 4 4 1 2 4 1 3 3 4 0 3 1 0
#  4 4 0 1 0 5 4 4 4 1 5 0 4 4 5 3 0 0 3 3 3 3 0 3 2 2 2 0 3 1 4 2 0 4 1 4 4
#  2 1 2 1 0 5 1 4 2 0 1 4 1 3 2 4 5 3 1 5 1 1 3 4 0 2 1 4 4 1 4 3 1 5 0 3 3
#  1 0 4 1 0 2 4 1 1 1 3 4 0 1 4 1 4 0 0 2 1 0 1 4 2 3 2 1 4 0 5 1 4 4 0 1 1
#  2 0 0 3 3 1 4 3 4 0 3 0 1 2 2 1 1 4 1 3 0 1 2 3 2 4 5 4 1 3 4 4 2 4 0 4 3
#  4 0 2 4 3 4 1 1 5 4 2 5 1 2 4 3 3 0 0 1 4 4 4 4 4 5 3 4 1 3 3 3 5 0 4 4 3
#  3 4 4 5]
