# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

from rdkit import Chem, rdBase
from rdkit.Chem import Draw,rdDepictor
from rdkit.Chem import AllChem, Descriptors, DataStructs
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D
from rdkit.Chem.Scaffolds import rdScaffoldNetwork
#from datetime import datetime
#import glob
#import matplotlib as mpl
#from matplotlib import pyplot as plt
#from matplotlib import image as mpimg
import ipyplot
#import os
#import pyvis
#from pyvis.network import Network
#import inspect
#from collections import defaultdict


# def net_match(ms, fp, fp_list, net, probe):
#    for i in range(0, ms):
#        for j in range(0,ms):
#            v = 0
#            for k in range(0, fp):
#                # print(i,j,k)
#                p = probe[k]
#                n = net[i][j][k][0]
#                s = net[i][j][k][1]
#                if s == 0:
#                    s = fp_list[k][1]
#                # d = math.sqrt((p-n)**2)
#               d = 1/(2*math.pi*pow(s,2)) * math.exp(-(pow(p-n,2))/(2*pow(s,2)))
#                v = v + d
#                # if p == n:
#                #    print(i,j,p,n,s,d,v)
#             
#            fit[i][j] = v
#    
#   return fit

#def net_learn(ms, ind, pr, net_mol, net):
#    
#    x = ind[0]
#    y = ind[1]
#    ma = int((ms-1)/2)
#    l = len(net_mol[ind])
#    for i in range(0, fp):        
#        n = net[x][y][i][0]
#        a = ((l-1)*n+pr[i])/l
#        # print('Net FP : ',i, n, pr[i], l, a)
#        # print("Adjust")
#        net[x][y][i][0] = a
#        for j in range(-ma, ma):
#            for k in range(-ma,ma):
#                x1 = (x+j+1 % ms)-1
#                if x1 < 0:
#                    x1 = x1 + ms
#                if x1 == ms:
#                    x1 = 0
#                y1 = (y+k+1 % ms)-1
#                if y1 < 0:
#                    y1 = y1 + ms
#                if y1 == ms:
#                    y1 = 0
#                # print(x, j, x1, y, k, y1)
#                
#                s = net[j][k][i][1]
#                if s == 0:
#                    s = .5
#                # d = a/(2*math.pi*pow(s,2)) * (math.exp(-(pow(j,2)))+math.exp(-(pow(k,2))))/(2*pow(s,2))
#                d = 1/4 * (math.exp(-(pow(j,2)))+math.exp(-(pow(k,2))))/(2*pow(s,2))
#                da = d*a
#                
#                if j != 0 or k != 0:
#                    #print(x, j, x1, y, k, y1, a, d)
#                    indn = (x1, y1)
#                    ln = len(net_mol[indn])
#                    if ln == 0:
#                        nc = (net[x1][y1][i][0] + da)/(1+d)
#                    else:
#                        nc = (ln*net[x1][y1][i][0] + da)/(ln+d)
#                    # print('New Cell : ',indn, ln, net[x1][y1][i][0], nc)
#                    net[x1][y1][i][0] = nc
#                    
#    return net

network = 2

# Initiate Global Values
fp_index =[]


# open database connection
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

# Retrieve Structures from Database
cur = db_nn.cursor()
sql = 'SELECT COUNT(*) FROM public."Structures"'
cur.execute(sql)
mol_count = cur.fetchone()
mol_count = mol_count[0]
print('Structures Available : ',mol_count)

ms = int(pow(mol_count, 1/3)+1)
msize = pow(ms,2)
print('Matrix Size : ',ms,' - ',msize)

# Retrieve Network from Database
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
sql = 'SELECT * FROM network."Neurons_2D" WHERE "Network" = '+str(network)
cur.execute(sql)
fl = cur.fetchall()
if len(fl) != 0:
    print('Network Found')
    msn = 0
    for i in fl:
        msn = max(msn, int(i[0]))
        msn = msn+1
        fpn = int(len(fl)/pow(msn,2))
    for i in range(0,fpn):
        j = fl[i][5]
        #print(j)
        fp_index.append(j)
    print('Network Size : ',msn,' - ',pow(msn,2))
    print('Network Fingerprint : ', fpn,' - ', fp_index)
else:
    print('Naive Network')

# get Morgan Fingerprints from database
cur = db_nn.cursor()
#sql = 'SELECT "Fingerprint_ID", "FP_Shannon" FROM public."Fingerprints" WHERE "FP_Type" = 1 ORDER BY "Fingerprint_ID"'
sql = 'SELECT "Fingerprint_ID", "FP_Shannon" FROM public."Fingerprints" \
WHERE "FP_Type" = 1 ORDER BY "FP_Shannon" DESC LIMIT '+str(msize)
cur.execute(sql)
fp_list = cur.fetchall()

fp = len(fp_list) # set depth of Mapping Matrix
print('Fingerprints : ',fp)
# print(fp_list)

# update FingerPrint_Index
for i in fp_list:
    if i[0] not in fp_index:
        fp_index.append(i[0])

print('Fingerprint Index: ',fp_index)
# print(fp_index.index(5))
# print(fp_index.index(10))

fpa = ''
for i in fp_index:
    #fpa.append(i[0])
    fpa = fpa + str(i) +','
fpa = fpa[:-1]
    
print('Fingerprints chosen : ',fpa)

cur = db_nn.cursor()
#sql = 'SELECT sf.* FROM public."Structure_Fingerprint" sf \
#JOIN public."Fingerprints" fp ON sf."FP_ID" = fp."Fingerprint_ID" \
#WHERE fp."FP_Type" = 1'
sql = 'SELECT sf.* FROM public."Structure_Fingerprint" sf \
WHERE sf."FP_ID" in ('+ fpa +')'

cur.execute(sql)
mol_list = cur.fetchall()
# print(mol_list)

mol_fp = collections.defaultdict(list)
mol_net = {}
net_mol = collections.defaultdict(list)

for i in mol_list:
    a = [i[1], i[2]]
    # print(i, i[0], a)
    mol_fp[i[0]].append(a)
    
# print(mol_fp)
print("Molecules : ", len(mol_fp))
l_rate = 1/len(mol_fp)
print('Rate : ',l_rate, 1-l_rate)
    
# promol = [0] * fp
# print(promol)



#ms = 5
ma = int((ms-1)/2)
print(ms, ma)
# fp = 4



fp_probes = {}
for i,j in mol_fp.items():
    #print()
    #print(i,j)
    pr = [0] * fp
    #fp_probes[i] = []
    for k in j:
        a = fp_index.index(k[0])
        pr[a] = k[1]
        
    print('Fingerprint probe : ',i, pr)
    fp_probes[i] = pr
    
#print(fp_probes)
fp_max = np.zeros(fp)
#print(fp_max)
for i,j in fp_probes.items():
    #print('Probe : ',j)
    l = len(j)
    for k in range(0,l):
        fp_max[k] = max(fp_max[k],j[k])
    #print('Pro_m : ',fp_max)
print('FP Max Probe : ',fp_max)

################################################################################

#####     Initiate Network Values
net = np.zeros((ms, ms, fp, 2))

if len(fl) != 0:
    #fp_index = []
    print('Transferring Network Values')

    for i in fl:
        #print(i)
        x = int(i[0])
        y = int(i[1])
        f = i[5]
        s = i[2]
        a = i[3]
        fi = fp_index.index(f)
        print(x,y,f, fi, a, s)
        net[x][y][fi][0] = a
        net[x][y][fi][1] = s
else:
    # generate random floating point values
    print('Random Network Seed')
    from random import seed
    from random import random
    # seed random number generator
    t = int(time.time()*1000)
    # print(t)
    seed(t)

    #print()
    #r = 5000
    for x in range(0,ms):
        for y in range(0, ms):
            for f in range(0,fp):
                #x = int(ms*random())
                #y = int(ms*random())
                #f = int(fp*random())
                # t = int(2*random())
                v = int((fp_max[f]+1)*random())
                # print(x,y,f,t,v)
                net[x][y][f][0] = v

print()                
print(net)


##################################################################################

#####     Initiate Molecule Positions if Available

# a = math.sqrt(4)
# print()
# print(fit)

# probe = [1,3,5,7]
# probe =[]
# for i in range(0,fp):
   # v = int(10*random())
   # probe.append(v)
    
# print()
# print('Probe : ', probe)

###################################################################################

#####      Network Learning Routines

# pi = math.pi
for r in range(0, 200):
    #print()
    print('Iteration : ', r)
    #print()
    # sf = 0
    for i,j in fp_probes.items(): #mol_fp.items():
        #print()
        #print('Probe list : ',i,j)
        #pr = [0] * fp
        #for k in j:
        #    a = fp_index.index(k[0])
        #    pr[a] = k[1]
        pr = j
        #print(i, pr)

        fit = n2d.net_match(ms, fp, fp_list, net, pr)
        
        # print()
        
        pfit = np.zeros((ms,ms))
        
        for fi in range(0, ms):
            for fj in range(0,ms):
                fl = len(net_mol[fi,fj])
                pfit[fi, fj] = fit[fi,fj]/(1 + fl/ms)
                #print(fl)
        
        m = np.max(pfit)
        # sf = sf + m
        # print(i, m)
        ind = np.unravel_index(np.argmax(pfit, axis=None), pfit.shape)
        l = len(net_mol[ind])
        print('Position match : ', i, m, ind,l)
        #print(fit)
        #print(pfit)
        
        # Rebuild NET
        
        # Move Molecule between cells
        indo_fl = 0
        try:
            a = mol_net[i]
            if ind != mol_net[i]:
                indo_fl = 1
                indo = mol_net[i]
                k = net_mol[indo]
                #print('Removal')
                #print('Old net : ',net_mol)
                print('Old position : ',i,indo)
                #print('Prepop : ',k)
                l = k.index(i)
                k.pop(l)
                #print('Postpop : ',k)
                mol_net[i] = ind
                #print('Molposition updated: ',mol_net)
                net_mol[ind].append(i)
                #print('Net updated :',ind, net_mol[ind])
                # Adjust New cell
                x = ind[0]
                y = ind[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[ind])
                
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    a = ((l-1)*n+pr[ii])/l
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    s = 0
                    for jj in net_mol[ind]:
                        sj = (fp_probes[jj][ii]-net[x][y][ii][0])**2
                        s = s+sj
                        #print(jj,fp_probes[jj][ii],net[x][y][ii][0],sj,s)
                    ls = len(net_mol[ind])
                    net[x][y][ii][1] = math.sqrt(s/ls)
                    #print('Deviate : ',net_mol[ind],net[x][y][ii][1], ls)
                        
                        
                # Adjust Old cell
                x = indo[0]
                y = indo[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[indo])
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    #if l > 0:
                    a = ((l+1)*n-l_rate*pr[ii])/(l+1-l_rate)
                    #else:
                    #    a = (n-l_rate*pr[i])/(1-l_rate)
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    s = 0
                    for jj in net_mol[indo]:
                        sj = (fp_probes[jj][ii]-net[x][y][ii][0])**2
                        s = s+sj
                        #print(jj,fp_probes[jj][ii],net[x][y][ii][0],sj,s)
                    ls = len(net_mol[indo])
                    net[x][y][ii][1] = math.sqrt(s/ls)
                    #print('Deviate : ',net_mol[indo],net[x][y][ii][1], ls)
        
        except:
            if indo_fl == 0:
                mol_net[i] = ind
                net_mol[ind].append(i)
                #print('New net match : ',i, ind, net_mol[ind])
                x = ind[0]
                y = ind[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[ind])
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    a = ((l-1)*n+pr[ii])/l
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    net[x][y][ii][1] = 0 
            
    #lnm =len(net_mol)
    #for i,j in net_mol.items():
    #    print(i, j, len(j))

        net = n2d.net_learn(ms, fp, ind, pr, net_mol, net)
        if indo_fl == 1:
            net = n2d.net_learn(ms, fp, indo, pr, net_mol, net)
    # print('Match Sum : ', sf)
    
    # print(net)

######################################################################################################

#####     Display Network
                    
print()
print('New_net : ',net)

cur = db_nn.cursor()
sql = 'SELECT "Structure_ID", "SMILES" FROM public."Structures"'
cur.execute(sql)
struct_list = cur.fetchall()
# print(struct_list)
struct_dict = {}
for i in struct_list:
    struct_dict[i[0]] = i[1]

print(struct_dict)    


print()
print('Net Elements : ')
for i,j in net_mol.items():
    print(i,j)
    gmol = []
    if len(j) != 0:
        for k in j:
            #print(struct_dict[k])
            s = struct_dict[k]
            m = Chem.MolFromSmiles(s)
            #print(m)
            mw = Chem.Descriptors.MolWt(m)
            # print(mw)
            
            # md = Draw.MolToImage(m)
            gmol.append(Draw.MolToImage(m))
            
            # Draw.MolsToGridImage(gmol, molsPerRow=1)
        ipyplot.plot_images(gmol, max_images = 30, img_width = 150)
            
#print(gmol)
#Draw.MolsToGridImage(gmol, molsPerRow=4)
    
#i = 13
#j = mol_net[i]
#k = net_mol[j]
#print('Removal')
#print(i,j)
#print(k)
#l = k.index(i)
#k.pop(l)
#print(k)

    
#    try:
#        k = j.index(13)
#        j.pop(k)
#    except:
#        k = -1
#    
#print(i, k, j)

#print()
# print(net_mol)
#for i, j in net_mol.items():
#    print(i,j)
# Out:
# Structures Available :  19
# Matrix Size :  3  -  9
# Network Found
# Network Size :  162  -  26244
# Network Fingerprint :  0  -  []
# Fingerprints :  9
# Fingerprint Index:  [27, 8, 11, 9, 42, 25, 35, 40, 33]
# Fingerprints chosen :  27,8,11,9,42,25,35,40,33
# Molecules :  19
# Rate :  0.05263157894736842 0.9473684210526316
# 3 1
# Fingerprint probe :  10 [0, 1, 1, 1, 0, 0, 0, 0, 0]
# Fingerprint probe :  11 [0, 1, 1, 1, 0, 0, 0, 0, 0]
# Fingerprint probe :  13 [0, 1, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  14 [0, 0, 0, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  15 [0, 2, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  16 [0, 2, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  17 [6, 0, 0, 0, 0, 6, 0, 0, 0]
# Fingerprint probe :  18 [5, 0, 0, 0, 0, 3, 2, 0, 1]
# Fingerprint probe :  19 [5, 0, 0, 1, 1, 3, 0, 2, 0]
# Fingerprint probe :  20 [4, 0, 0, 1, 1, 0, 2, 2, 1]
# Fingerprint probe :  21 [4, 0, 0, 1, 1, 1, 1, 1, 1]
# Fingerprint probe :  22 [3, 0, 0, 1, 2, 0, 1, 1, 1]
# Fingerprint probe :  23 [2, 0, 0, 1, 3, 0, 0, 0, 1]
# Fingerprint probe :  24 [0, 2, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  34 [0, 2, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  35 [0, 1, 1, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  36 [0, 2, 2, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  37 [0, 1, 1, 2, 0, 0, 0, 0, 0]
# Fingerprint probe :  38 [0, 3, 2, 2, 0, 0, 0, 0, 0]
# FP Max Probe :  [6. 3. 2. 2. 3. 6. 2. 2. 1.]
# Transferring Network Values
# 0 0 27 0 1.036420064460625 0.0
# 0 0 8 1 0.9140284738406566 0.0
# 0 0 11 2 0.9156363932549412 0.0
# 0 0 9 3 1.3514763987783063 0.0
# 0 0 42 4 0.34427782523716294 0.0
# 0 0 25 5 0.1608049847935052 0.0
# 0 0 35 6 0.32937724286026165 0.0
# 0 0 40 7 0.07985610408336082 0.0
# 0 0 33 8 0.2741530982181095 0.0
# 0 1 27 0 1.1112097852129268 0.0
# 0 1 8 1 0.7695503446283853 0.0
# 0 1 11 2 0.7945496357825726 0.0
# 0 1 9 3 1.2890170659663305 0.0
# 0 1 42 4 0.3524586527389456 0.0
# 0 1 25 5 0.16096332427788657 0.0
# 0 1 35 6 0.33752287671806264 0.0
# 0 1 40 7 0.0798657324573769 0.0
# 0 1 33 8 0.2784076536557813 0.0
# 0 2 27 0 1.7818320751027168 1.4466520181526334
# 0 2 8 1 0.654743236854991 0.12459403100531749
# 0 2 11 2 0.672219911022351 0.1320220674920835
# 0 2 9 3 1.2767458683814457 0.06958256111876415
# 0 2 42 4 0.37747241776145946 0.8362687824657462
# 0 2 25 5 0.16074151124774474 1.4413671540692572
#
#   [[1.10958364 0.        ]
#    [0.82378113 0.        ]
#    [0.84402997 0.        ]
#    [1.31175987 0.        ]
#    [0.35044554 0.        ]
#    [0.16091717 0.        ]
#    [0.33486104 0.        ]
#    [0.07986412 0.        ]
#    [0.27732623 0.        ]]]]
# Iteration :  0
# Position match :  10 19.12100849219315 (2, 1) 0
# Position match :  11 24.586016241378335 (2, 0) 0
# Position match :  13 5.351223493695697 (0, 2) 0
# Position match :  14 2.127467899378472 (2, 2) 0
# Position match :  15 2.1558872380577663 (0, 0) 0
# Position match :  16 2.222244225212454 (0, 1) 0
# Position match :  17 1.5926256848126243 (1, 2) 0
# Position match :  18 1.226274134373276 (1, 1) 0
# Position match :  19 1.3610811035902932 (1, 0) 0
# Position match :  20 0.9512435201913435 (1, 1) 1
# Position match :  21 1.4024282199626965 (2, 1) 1
# Position match :  22 1.2480864977031392 (0, 1) 1
# Position match :  23 0.8778906632042001 (0, 2) 1
# Position match :  24 0.7158568637531224 (0, 0) 1
# Position match :  34 1.0722242604821606 (0, 0) 2
# Position match :  35 1.2625521118279828 (2, 0) 1
# Position match :  36 1.3061005302656215 (1, 0) 1
# Position match :  37 1.4156876021980185 (2, 2) 1
# Position match :  38 1.4051376125496025 (1, 2) 1
# Iteration :  1
# Position match :  10 1.275231446014397 (2, 2) 2
# Old position :  10 (2, 1)
# Position match :  11 16.240812505253498 (2, 2) 3
# Old position :  11 (2, 0)
# Position match :  13 30.217467090663533 (2, 0) 1
# Old position :  13 (0, 2)
# Position match :  14 129.37986500893163 (2, 0) 2
# Old position :  14 (2, 2)
# Position match :  15 240.92630842041683 (2, 0) 3
# Old position :  15 (0, 0)
# Position match :  16 365.7817618241808 (2, 0) 4
# Old position :  16 (0, 1)
# Position match :  17 462.4479740467964 (2, 0) 5
# Old position :  17 (1, 2)
# Position match :  18 367.1150151107029 (1, 2) 1
# Old position :  18 (1, 1)
# Position match :  19 1.0449875167561546 (2, 1) 1
# Old position :  19 (1, 0)
# Position match :  20 1.615041591310208 (2, 1) 2
# Old position :  20 (1, 1)
# Position match :  21 2.842840892369532 (2, 1) 3
# Position match :  22 2.6314367084812993 (2, 1) 3
# Old position :  22 (0, 1)
# Position match :  23 3.695032093652552 (2, 1) 4
# Old position :  23 (0, 2)
# Position match :  24 0.6371366752236608 (0, 1) 0
# Old position :  24 (0, 0)
# Position match :  34 2.270809470228322 (0, 2) 0
# Old position :  34 (0, 0)
# Position match :  35 4.820226484694562 (1, 0) 1
# Old position :  35 (2, 0)
# Position match :  36 25.09543983948926 (1, 0) 2
# Position match :  37 25.402879882878445 (1, 0) 2
# Old position :  37 (2, 2)
# Position match :  38 43.62261170355885 (1, 0) 3
# Old position :  38 (1, 2)
# Iteration :  2
# Position match :  10 62.577336805996595 (1, 0) 4
# Old position :  10 (2, 2)
# Position match :  11 127.63450572281852 (2, 2) 1
# Position match :  13 124.95843603306031 (2, 2) 1
# Old position :  13 (2, 0)
# Position match :  14 541.5154917218767 (2, 2) 2
# Old position :  14 (2, 0)
# Position match :  15 1012.2847908999107 (2, 2) 3
# Old position :  15 (2, 0)
# Position match :  16 1541.588590048997 (2, 2) 4
# Old position :  16 (2, 0)
# Position match :  17 1007.3454958980864 (2, 0) 1
# Position match :  18 343.7811659461381 (2, 0) 1
# Old position :  18 (1, 2)
# Position match :  19 1.8285699846341181 (1, 0) 5
# Old position :  19 (2, 1)
# Position match :  20 8.861525453283441 (1, 1) 0
# Old position :  20 (2, 1)
# Position match :  21 1.817934494098168 (1, 2) 0
# Old position :  21 (2, 1)
# Position match :  22 1.7847858690397977 (0, 0) 0
# Old position :  22 (2, 1)
# Position match :  23 4.860786387274339 (2, 1) 1
# Position match :  24 4.2953486164356685 (2, 1) 1
# Old position :  24 (0, 1)
# Position match :  34 17.641705672326054 (2, 1) 2
# Old position :  34 (0, 2)
# Position match :  35 32.39045070067375 (2, 1) 3
# Old position :  35 (1, 0)
# Position match :  36 48.61510414347192 (2, 1) 4
# Old position :  36 (1, 0)
# Position match :  37 65.88907623067584 (2, 1) 5
# Old position :  37 (1, 0)
# Position match :  38 83.8411919915431 (2, 1) 6
# Old position :  38 (1, 0)
# Iteration :  3
# Position match :  10 102.20200111532085 (2, 1) 7
# Old position :  10 (1, 0)
# Position match :  11 127.4430872894307 (2, 2) 5
# Position match :  13 127.63313016998437 (2, 2) 5
# Position match :  14 127.5451650987001 (2, 2) 5
# Position match :  15 127.57987113219534 (2, 2) 5
# Position match :  16 127.57987113219534 (2, 2) 5
# Position match :  17 8.316177231146646 (1, 0) 1
# Old position :  17 (2, 0)
# Position match :  18 12.484382482588156 (2, 0) 1
# Position match :  19 30.553975987841838 (1, 0) 2
# Position match :  20 0.9404355539275164 (0, 2) 0
# Old position :  20 (1, 1)
# Position match :  21 1.799959569489236 (0, 1) 0
# Old position :  21 (1, 2)
# Position match :  22 1.84941738324879 (1, 2) 0
# Old position :  22 (0, 0)
# Position match :  23 1.5190622040246882 (1, 1) 0
# Old position :  23 (2, 1)
# Position match :  24 1.8252900801552394 (2, 1) 7
# Position match :  34 1.8252900801552394 (2, 1) 7
# Position match :  35 1.8768212863529878 (0, 0) 0
# Old position :  35 (2, 1)
# Position match :  36 2.2068400099407106 (2, 1) 6
# Position match :  37 2.2404503800315734 (2, 1) 6
# Position match :  38 2.194346244401818 (2, 1) 6
# Iteration :  4
# Position match :  10 2.2661768214243696 (2, 1) 6
# Position match :  11 2.2661768214243696 (2, 1) 6
# Old position :  11 (2, 2)
# Position match :  13 3.3001823272449133 (2, 2) 4
# Position match :  14 3.3062631758662477 (2, 2) 4
# Position match :  15 3.2668604964988655 (2, 2) 4
# Position match :  16 3.2668604964988655 (2, 2) 4
# Position match :  17 1.7164754490270844 (2, 2) 4
# Old position :  17 (1, 0)
# Position match :  18 1.1993313363575255 (2, 0) 1
# Position match :  19 3.6623207668063102 (1, 0) 1
# Position match :  20 1.459034155745961 (1, 0) 1
# Old position :  20 (0, 2)
# Position match :  21 5.096045284141057 (1, 0) 2
# Old position :  21 (0, 1)
# Position match :  22 6.264793924110321 (1, 0) 3
# Old position :  22 (1, 2)
# Position match :  23 9.061740543250417 (1, 0) 4
# Old position :  23 (1, 1)
# Position match :  24 1.2598520177589017 (2, 1) 7
# Position match :  34 1.3882508410148444 (0, 1) 0
# Old position :  34 (2, 1)
# Position match :  35 1.85038613013359 (0, 2) 0
# Old position :  35 (0, 0)
# Position match :  36 2.009423924859176 (0, 0) 0
# Old position :  36 (2, 1)
# Position match :  37 2.232875787346296 (2, 1) 5
# Position match :  38 2.1889676082726286 (2, 1) 5
# Iteration :  5
# Position match :  10 2.2954903691530153 (2, 1) 5
# Position match :  11 2.2954903691530153 (2, 1) 5
# Position match :  13 2.2090400618973147 (2, 1) 5
# Old position :  13 (2, 2)
# Position match :  14 3.022707421824679 (2, 1) 6
# Old position :  14 (2, 2)
# Position match :  15 3.5644214454455643 (2, 1) 7
# Old position :  15 (2, 2)
# Position match :  16 4.168313186785472 (2, 1) 8
# Old position :  16 (2, 2)
# Position match :  17 3.6095847498165377 (2, 2) 1
# Position match :  18 1.8707852147845445 (2, 2) 1
# Old position :  18 (2, 0)
# Position match :  19 1.4203668508648037 (2, 2) 2
# Old position :  19 (1, 0)
# Position match :  20 2.489291691048454 (2, 1) 9
# Old position :  20 (1, 0)
# Position match :  21 1.9465307140268766 (2, 2) 3
# Old position :  21 (1, 0)
# Position match :  22 9.503370145417975 (1, 0) 2
# Position match :  23 9.706459301806715 (1, 0) 2
# Position match :  24 7.914192052558292 (1, 0) 2
# Old position :  24 (2, 1)
# Position match :  34 13.277484988053905 (1, 0) 3
# Old position :  34 (0, 1)
# Position match :  35 19.102661110186318 (1, 0) 4
# Old position :  35 (0, 2)
# Position match :  36 25.65491956286528 (1, 0) 5
# Old position :  36 (0, 0)
# Position match :  37 32.58056856110786 (1, 0) 6
# Old position :  37 (2, 1)
# Position match :  38 39.432509664224526 (1, 0) 7
# Old position :  38 (2, 1)
# Iteration :  6
# Position match :  10 46.33561063597446 (1, 0) 8
# Old position :  10 (2, 1)
# Position match :  11 61.437755720228836 (2, 1) 6
# Position match :  13 61.47300097837854 (2, 1) 6
# Position match :  14 61.49004815533132 (2, 1) 6
# Position match :  15 61.440725336651575 (2, 1) 6
# Position match :  16 61.440725336651575 (2, 1) 6
# Position match :  17 8.016591178332103 (2, 0) 0
# Old position :  17 (2, 2)
# Position match :  18 1.3225888099517034 (0, 0) 0
# Old position :  18 (2, 2)
# Position match :  19 1.8356541427402544 (2, 2) 2
# Position match :  20 1.5671108467370016 (2, 2) 2
# Old position :  20 (2, 1)
# Position match :  21 7.428631062306149 (2, 2) 3
# Position match :  22 7.249325169493241 (2, 2) 3
# Old position :  22 (1, 0)
# Position match :  23 10.482486980822642 (2, 2) 4
# Old position :  23 (1, 0)
# Position match :  24 2.278091353927572 (2, 1) 5
# Old position :  24 (1, 0)
# Position match :  34 2.5830777128038207 (2, 1) 6
# Old position :  34 (1, 0)
# Position match :  35 3.0571867118482654 (2, 1) 7
# Old position :  35 (1, 0)
# Position match :  36 4.293669779201043 (1, 0) 4
# Position match :  37 4.3191407734729514 (1, 0) 4
# Position match :  38 4.286132626216927 (1, 0) 4
# Iteration :  7
# Position match :  10 4.3648466183236705 (1, 0) 4
# Position match :  11 4.3648466183236705 (1, 0) 4
# Old position :  11 (2, 1)
# Position match :  13 6.5250547961023315 (1, 0) 5
# Old position :  13 (2, 1)
# Position match :  14 7.9521458245866965 (1, 0) 6
# Old position :  14 (2, 1)
# Position match :  15 9.361633329380819 (2, 1) 5
# Position match :  16 9.361633329380819 (2, 1) 5
# Position match :  17 9.16598322979403 (2, 1) 5
# Old position :  17 (2, 0)
# Position match :  18 12.328769912235941 (2, 1) 6
# Old position :  18 (0, 0)
# Position match :  19 1.2988516015163531 (1, 0) 7
# Old position :  19 (2, 2)
# Position match :  20 1.4233943263597115 (2, 2) 4
# Position match :  21 1.4982394582008047 (2, 2) 4
# Position match :  22 1.4781739382835863 (2, 2) 4
# Position match :  23 7.08262149120768 (2, 1) 7
# Old position :  23 (2, 2)
# Position match :  24 7.216828767345068 (2, 1) 8
# Position match :  34 7.216828767345068 (2, 1) 8
# Position match :  35 7.249212392746856 (2, 1) 8
# Position match :  36 7.216828767345068 (2, 1) 8
# Old position :  36 (1, 0)
# Position match :  37 8.36003499678474 (2, 1) 9
# Old position :  37 (1, 0)
# Position match :  38 9.42389734789694 (2, 1) 10
# Old position :  38 (1, 0)
# Iteration :  8
# Position match :  10 10.593873029926359 (2, 1) 11
# Old position :  10 (1, 0)
# Position match :  11 11.719374814248706 (2, 1) 12
# Old position :  11 (1, 0)
# Position match :  13 12.81852288368647 (2, 1) 13
# Old position :  13 (1, 0)
# Position match :  14 13.957129340842513 (2, 1) 14
# Old position :  14 (1, 0)
# Position match :  15 15.082453677916169 (2, 1) 15
# Position match :  16 15.082453677916169 (2, 1) 15
# Position match :  17 15.056613623912591 (2, 1) 15
# Position match :  18 14.796380373120064 (2, 1) 15
# Position match :  19 4.6750179091576065 (1, 0) 1
# Position match :  20 1.1600429032235815 (1, 0) 1
# Old position :  20 (2, 2)
# Position match :  21 3.213197408256741 (1, 0) 2
# Old position :  21 (2, 2)
# Position match :  22 4.3505390299407765 (1, 0) 3
# Old position :  22 (2, 2)
# Position match :  23 6.0323128815646765 (1, 0) 4
# Old position :  23 (2, 1)
# Position match :  24 1.573279731945627 (0, 1) 0
# Old position :  24 (2, 1)
# Position match :  34 1.875036723699146 (0, 2) 0
# Old position :  34 (2, 1)
# Position match :  35 2.700736598759713 (2, 2) 0
# Old position :  35 (2, 1)
# Position match :  36 2.0011858073148403 (1, 2) 0
# Old position :  36 (2, 1)
# Position match :  37 2.09315396034239 (0, 0) 0
# Old position :  37 (2, 1)
# Position match :  38 1.939705253292204 (2, 0) 0
# Old position :  38 (2, 1)
# Iteration :  9
# Position match :  10 3.709030687019006 (1, 0) 5
# Old position :  10 (2, 1)
# Position match :  11 2.1999913879623727 (2, 1) 7
# Position match :  13 2.1622561103163 (2, 1) 7
# Position match :  14 2.1677851456879607 (2, 1) 7
# Position match :  15 2.1211347143173 (2, 1) 7
# Position match :  16 2.1211347143173 (2, 1) 7
# Position match :  17 2.1280917509500963 (2, 1) 7
# Position match :  18 1.9225975954926804 (2, 1) 7
# Position match :  19 1.3108620919774583 (1, 1) 0
# Old position :  19 (1, 0)
# Position match :  20 0.944702835658161 (1, 1) 1
# Old position :  20 (1, 0)
# Position match :  21 20.16785509160333 (1, 1) 2
# Old position :  21 (1, 0)
# Position match :  22 9.095530980928157 (1, 1) 3
# Old position :  22 (1, 0)
# Position match :  23 12.885900245647676 (1, 1) 4
# Old position :  23 (1, 0)
# Position match :  24 0.847660059831435 (1, 0) 1
# Old position :  24 (0, 1)
# Position match :  34 2.9804046261367114 (1, 0) 2
# Old position :  34 (0, 2)
# Position match :  35 5.397149495316153 (1, 0) 3
# Old position :  35 (2, 2)
# Position match :  36 7.535425397246216 (1, 0) 4
# Old position :  36 (1, 2)
# Position match :  37 11.565791849726375 (1, 1) 5
# Old position :  37 (0, 0)
# Position match :  38 10.193597294147105 (1, 0) 5
# Old position :  38 (2, 0)
# Iteration :  10
# Position match :  10 12.978044945936203 (1, 0) 6
# Position match :  11 12.978044945936203 (1, 0) 6
# Old position :  11 (2, 1)
# Position match :  13 15.790276911730379 (1, 0) 7
# Old position :  13 (2, 1)
# Position match :  14 18.355285083987845 (1, 0) 8
# Old position :  14 (2, 1)
# Position match :  15 21.20091034168685 (1, 0) 9
# Old position :  15 (2, 1)
# Position match :  16 24.05159136037806 (1, 0) 10
# Old position :  16 (2, 1)
# Position match :  17 15.848296306878087 (1, 0) 11
# Old position :  17 (2, 1)
# Position match :  18 7.726827817791152 (2, 1) 1
# Position match :  19 15.351011696718766 (1, 0) 12
# Old position :  19 (1, 1)
# Position match :  20 0.8623747082424525 (2, 0) 0
# Old position :  20 (1, 1)
# Position match :  21 1.5446342975907945 (0, 0) 0
# Old position :  21 (1, 1)
# Position match :  22 1.6064223071659973 (0, 2) 0
# Old position :  22 (1, 1)
# Position match :  23 4.262801675422355 (1, 1) 2
# Position match :  24 4.285986997814208 (1, 1) 2
# Old position :  24 (1, 0)
# Position match :  34 8.311789841010254 (1, 1) 3
# Old position :  34 (1, 0)
# Position match :  35 11.964542861931925 (1, 1) 4
# Old position :  35 (1, 0)
# Position match :  36 15.72777358343934 (1, 1) 5
# Old position :  36 (1, 0)
# Position match :  37 19.7564814095312 (1, 1) 6
# Position match :  38 19.65671475175908 (1, 1) 6
# Old position :  38 (1, 0)
# Iteration :  11
# Position match :  10 23.556861443260082 (1, 1) 7
# Old position :  10 (1, 0)
# Position match :  11 27.814815850087296 (1, 1) 8
# Old position :  11 (1, 0)
# Position match :  13 32.14657490668674 (1, 1) 9
# Old position :  13 (1, 0)
# Position match :  14 36.42529342311552 (1, 1) 10
# Old position :  14 (1, 0)
# Position match :  15 40.86835748651787 (1, 1) 11
# Old position :  15 (1, 0)
# Position match :  16 45.307738476117656 (1, 1) 12
# Old position :  16 (1, 0)
# Position match :  17 12.084107524192719 (1, 0) 2
# Position match :  18 7.232979654275594 (2, 1) 1
# Position match :  19 11.92007623144927 (1, 0) 2
# Position match :  20 44.33779059864789 (1, 1) 13
# Old position :  20 (2, 0)
# Position match :  21 1.0548321155614975 (1, 2) 0
# Old position :  21 (0, 0)
# Position match :  22 1.5640455452722704 (2, 2) 0
# Old position :  22 (0, 2)
# Position match :  23 1.6480348502259923 (2, 0) 0
# Old position :  23 (1, 1)
# Position match :  24 4.198497159110702 (1, 1) 13
# Position match :  34 4.198497159110702 (1, 1) 13
# Position match :  35 4.237765249134265 (1, 1) 13
# Position match :  36 4.198497159110702 (1, 1) 13
# Position match :  37 4.237765249134265 (1, 1) 13
# Position match :  38 4.179378748082803 (1, 1) 13
# Iteration :  12
# Position match :  10 4.1939280352911785 (1, 1) 13
# Position match :  11 4.1939280352911785 (1, 1) 13
# Position match :  13 4.214466450415886 (1, 1) 13
# Position match :  14 4.185790767773532 (1, 1) 13
# Position match :  15 4.198497159110702 (1, 1) 13
# Position match :  16 4.198497159110702 (1, 1) 13
# Position match :  17 1.4899651632141417 (0, 0) 0
# Old position :  17 (1, 0)
# Position match :  18 3.1364647257396236 (2, 1) 1
# Position match :  19 3.19536670361919 (1, 0) 1
# Position match :  20 0.808933791651141 (0, 2) 0
# Old position :  20 (1, 1)
# Position match :  21 1.4181578795253453 (0, 1) 0
# Old position :  21 (1, 2)
# Position match :  22 1.6187025265628479 (1, 2) 0
# Old position :  22 (2, 2)
# Position match :  23 1.6064943287239462 (2, 2) 0
# Old position :  23 (2, 0)
# Position match :  24 1.2996329336042893 (2, 0) 0
# Old position :  24 (1, 1)
# Position match :  34 1.9457970297053557 (1, 0) 1
# Old position :  34 (1, 1)
# Position match :  35 3.8386917180856086 (1, 0) 2
# Old position :  35 (1, 1)
# Position match :  36 5.271525477865673 (1, 0) 3
# Old position :  36 (1, 1)
# Position match :  37 6.886287624603568 (1, 0) 4
# Old position :  37 (1, 1)
# Position match :  38 8.518010198474327 (1, 0) 5
# Old position :  38 (1, 1)
# Iteration :  13
# Position match :  10 10.284761348405366 (1, 0) 6
# Old position :  10 (1, 1)
# Position match :  11 13.68477954138915 (1, 1) 5
# Position match :  13 13.789807352443075 (1, 1) 5
# Position match :  14 13.717970876197256 (1, 1) 5
# Position match :  15 13.738164368685792 (1, 1) 5
# Position match :  16 13.738164368685792 (1, 1) 5
# Position match :  17 12.940242948739314 (1, 1) 5
# Old position :  17 (0, 0)
# Position match :  18 2.83839580465214 (2, 1) 1
# Position match :  19 18.706397941421134 (1, 1) 6
# Old position :  19 (1, 0)
# Position match :  20 0.8954345312627306 (0, 0) 0
# Old position :  20 (0, 2)
# Position match :  21 2.944676622072545 (2, 1) 1
# Old position :  21 (0, 1)
# Position match :  22 2.077121933439464 (2, 1) 2
# Old position :  22 (1, 2)
# Position match :  23 3.092732504752475 (2, 1) 3
# Old position :  23 (2, 2)
# Position match :  24 1.1249886226490091 (1, 2) 0
# Old position :  24 (2, 0)
# Position match :  34 1.6754283292631778 (0, 2) 0
# Old position :  34 (1, 0)
# Position match :  35 1.9135157941473038 (2, 2) 0
# Old position :  35 (1, 0)
# Position match :  36 1.8455981912487147 (0, 1) 0
# Old position :  36 (1, 0)
# Position match :  37 2.7062490046239014 (2, 1) 4
# Old position :  37 (1, 0)
# Position match :  38 3.2575199812328806 (1, 0) 2
# Iteration :  14
# Position match :  10 3.309544942062889 (1, 0) 2
# Position match :  11 3.309544942062889 (1, 0) 2
# Old position :  11 (1, 1)
# Position match :  13 5.742376702333984 (1, 0) 3
# Old position :  13 (1, 1)
# Position match :  14 8.157795777932089 (1, 0) 4
# Old position :  14 (1, 1)
# Position match :  15 10.707991606618146 (1, 0) 5
# Old position :  15 (1, 1)
# Position match :  16 13.468256933845161 (1, 0) 6
# Old position :  16 (1, 1)
# Position match :  17 5.367413731064422 (1, 0) 7
# Old position :  17 (1, 1)
# Position match :  18 3.1165670426007557 (1, 0) 8
# Old position :  18 (2, 1)
# Position match :  19 5.099469971507477 (1, 1) 1
# Position match :  20 0.9674051566882703 (2, 0) 0
# Old position :  20 (0, 0)
# Position match :  21 1.8088234946444959 (0, 0) 0
# Old position :  21 (2, 1)
# Position match :  22 1.4760139048540168 (0, 0) 1
# Old position :  22 (2, 1)
# Position match :  23 9.37857961151381 (0, 0) 2
# Old position :  23 (2, 1)
# Position match :  24 5.837781181873445 (2, 1) 1
# Old position :  24 (1, 2)
# Position match :  34 24.46431272024581 (2, 1) 2
# Old position :  34 (0, 2)
# Position match :  35 45.77840288740026 (2, 1) 3
# Old position :  35 (2, 2)
# Position match :  36 69.1589617606789 (2, 1) 4
# Old position :  36 (0, 1)
# Position match :  37 94.61124215641956 (2, 1) 5
# Position match :  38 94.38784769255568 (2, 1) 5
# Old position :  38 (1, 0)
# Iteration :  15
# Position match :  10 119.39057767389039 (2, 1) 6
# Old position :  10 (1, 0)
# Position match :  11 145.7757443668216 (2, 1) 7
# Old position :  11 (1, 0)
# Position match :  13 172.78159099115427 (2, 1) 8
# Old position :  13 (1, 0)
# Position match :  14 200.12416506846048 (2, 1) 9
# Old position :  14 (1, 0)
# Position match :  15 227.97429398381863 (2, 1) 10
# Old position :  15 (1, 0)
# Position match :  16 256.04680391918083 (2, 1) 11
# Old position :  16 (1, 0)
# Position match :  17 15.327329177608153 (1, 0) 2
# Position match :  18 15.151415750869992 (1, 0) 2
# Position match :  19 9.87636686665492 (1, 1) 1
# Position match :  20 270.48105707465925 (2, 1) 12
# Old position :  20 (2, 0)
# Position match :  21 1.0380979528806122 (2, 0) 0
# Old position :  21 (0, 0)
# Position match :  22 1.5504454734550919 (2, 2) 0
# Old position :  22 (0, 0)
# Position match :  23 3.007647339470958 (0, 0) 1
# Position match :  24 2.652554352865042 (0, 0) 1
# Old position :  24 (2, 1)
# Position match :  34 7.658530568250539 (0, 0) 2
# Old position :  34 (2, 1)
# Position match :  20 2.744782600525227 (0, 0) 2
# Position match :  21 0.9959629159064152 (0, 2) 0
# Old position :  21 (1, 2)
# Position match :  22 1.5415259781277655 (2, 2) 0
# Old position :  22 (1, 0)
# Position match :  23 1.660400009773574 (1, 0) 0
# Old position :  23 (2, 0)
# Position match :  24 1.6206898023307466 (0, 0) 2
# Position match :  34 1.6206898023307466 (0, 0) 2
# Old position :  34 (0, 1)
# Position match :  35 2.787615259416052 (0, 0) 3
# Old position :  35 (2, 1)
# Position match :  36 3.8745835791460235 (0, 0) 4
# Old position :  36 (2, 1)
# Position match :  37 5.132931188889617 (0, 0) 5
# Old position :  37 (2, 1)
# Position match :  38 6.218152617836547 (0, 0) 6
# Old position :  38 (2, 1)
# Iteration :  28
# Position match :  10 7.326726314896675 (0, 0) 7
# Old position :  10 (2, 1)
# Position match :  11 8.587015317402141 (0, 0) 8
# Old position :  11 (2, 1)
# Position match :  13 9.821823002586203 (0, 0) 9
# Old position :  13 (2, 1)
# Position match :  14 11.030237652186964 (0, 0) 10
# Old position :  14 (2, 1)
# Position match :  15 12.326265372462393 (0, 0) 11
# Old position :  15 (2, 1)
# Position match :  16 13.612184819344133 (0, 0) 12
# Old position :  16 (2, 1)
# Position match :  17 13.653571879229268 (1, 1) 1
# Old position :  17 (2, 1)
# Position match :  18 5.953693517343942 (2, 1) 1
# Position match :  19 37.083669857397275 (1, 1) 2
# Position match :  20 2.9390022632989723 (0, 0) 13
# Position match :  21 1.0576143542655474 (1, 2) 0
# Old position :  21 (0, 2)
# Position match :  22 1.5831963356916106 (0, 2) 0
# Old position :  22 (2, 2)
# Position match :  23 1.6619835817085427 (2, 0) 0
# Old position :  23 (1, 0)
# Position match :  24 1.3325345231346473 (1, 0) 0
# Old position :  24 (0, 0)
# Position match :  34 2.1903281860077923 (0, 0) 12
# Position match :  35 2.377383139337103 (2, 1) 1
# Old position :  35 (0, 0)
# Position match :  36 5.518852767330526 (2, 1) 2
# Old position :  36 (0, 0)
# Position match :  37 9.09945520511858 (2, 1) 3
# Old position :  37 (0, 0)
# Position match :  38 12.887791441044245 (2, 1) 4
# Old position :  38 (0, 0)
# Iteration :  29
# Position match :  10 17.212800416944475 (2, 1) 5
# Old position :  10 (0, 0)
# Position match :  11 21.72345073675444 (2, 1) 6
# Old position :  11 (0, 0)
# Position match :  13 26.325455292596356 (2, 1) 7
# Old position :  13 (0, 0)
# Position match :  14 31.014870391476197 (2, 1) 8
# Old position :  14 (0, 0)
# Position match :  15 35.898277386134176 (2, 1) 9
# Old position :  15 (0, 0)
# Position match :  16 40.814837360904484 (2, 1) 10
# Old position :  16 (0, 0)
# Position match :  17 45.61057134926965 (2, 1) 11
# Old position :  17 (1, 1)
# Position match :  18 50.12820211820683 (2, 1) 12
# Position match :  19 31.099965736076058 (1, 1) 1
# Position match :  20 3.4193151608733685 (0, 0) 2
# Position match :  21 0.9701644916578195 (0, 1) 0
# Old position :  21 (1, 2)
# Position match :  22 1.4397571812318217 (0, 1) 1
# Old position :  22 (0, 2)
# Position match :  23 35.90633587828978 (0, 1) 2
# Old position :  23 (2, 0)
# Position match :  24 1.0452770730809078 (0, 2) 0
# Old position :  24 (1, 0)
# Position match :  34 1.6434547615382866 (0, 2) 1
# Old position :  34 (0, 0)
# Position match :  35 94.31931886236906 (0, 2) 2
# Old position :  35 (2, 1)
# Position match :  36 167.6766846259367 (0, 2) 3
# Old position :  36 (2, 1)
# Position match :  37 247.20121159323952 (0, 2) 4
# Old position :  37 (2, 1)
# Position match :  38 335.6105670184058 (0, 2) 5
# Old position :  38 (2, 1)
# Iteration :  30
# Position match :  10 403.0502790877461 (0, 2) 6
# Old position :  10 (2, 1)
# Position match :  11 493.08869916726775 (0, 2) 7
# Old position :  11 (2, 1)
# Position match :  13 585.1559837595531 (0, 2) 8
# Old position :  13 (2, 1)
# Position match :  14 678.4341338334441 (0, 2) 9
# Old position :  14 (2, 1)
# Position match :  15 773.0167744533734 (0, 2) 10
# Old position :  15 (2, 1)
# Position match :  16 868.4001913126065 (0, 2) 11
# Old position :  16 (2, 1)
# Position match :  17 335.49858885469183 (2, 1) 2
# Position match :  18 335.3436360751684 (2, 1) 2
# Position match :  19 178.34214961541727 (0, 2) 12
# Old position :  19 (1, 1)
# Position match :  20 1.8025245016134013 (0, 0) 1
# Position match :  21 0.9083204296137525 (2, 2) 0
# Old position :  21 (0, 1)
# Position match :  22 1.6211912980993746 (0, 0) 1
# Old position :  22 (0, 1)
# Position match :  23 5.611131095510811 (0, 0) 2
# Old position :  23 (0, 1)
# Position match :  24 7.60915912736533 (0, 0) 3
# Old position :  24 (0, 2)
# Position match :  34 11.77957049575795 (0, 0) 4
# Old position :  34 (0, 2)
# Position match :  35 15.843181036644644 (0, 0) 5
# Old position :  35 (0, 2)
# ...
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Ar5BLsyYMnf86DHvK7A77H">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-d6FJCPrDq6j59xJKEAwQK5" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-d6FJCPrDq6j59xJKEAwQK5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Wwanm2KHDn4jpixsBA3SF
#         <style>
#         #ipyplot-imgs-container-div-6fXCADECFDZvsnsCyMhGGb {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-6fXCADECFDZvsnsCyMhGGb">
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-gEpCQ7NwSrg42MEuNRgg3c" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-gEpCQ7NwSrg42MEuNRgg3c">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-UsbcowbMe7vv3KMpbzrE6i" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-UsbcowbMe7vv3KMpbzrE6i">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-LJjxhmgDQc7fiLQGp3dduk" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-LJjxhmgDQc7fiLQGp3dduk">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-9CkvtXBLNYmfXhFrHG3mqA" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-9CkvtXBLNYmfXhFrHG3mqA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-NhAefdQTCqGcg5mqAvg2D2" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-NhAefdQTCqGcg5mqAvg2D2">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Ar5BLsyYMnf86DHvK7A77H" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Ar5BLsyYMnf86DHvK7A77H">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-d6FJCPrDq6j59xJKEAwQK5" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-d6FJCPrDq6j59xJKEAwQK5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Wwanm2KHDn4jpixsBA3SF9" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-Wwanm2KHDn4jpixsBA3SF9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-KxSKARBSzw3zDjMWNtPsrP" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-KxSKARBSzw3zDjMWNtPsrP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-6fXCADECFDZvsnsCyMhGGb">
#         <div id="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-YJ6bFt5Dfc2GGHuANHRHWz" class="ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-6fXCADECFDZvsnsCyMhGGb-YJ6bFt5Dfc2GGHuANHRHWz">
# (2, 2) [19]
#     <style>
#         #ipyplot-html-viewer-toggle-atvKCpJgaHp8VNhmjHAMcA {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-atvKCpJgaHp8VNhmjHAMcA {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-atvKCpJgaHp8VNhmjHAMcA {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-atvKCpJgaHp8VNhmjHAMcA:checked ~ #ipyplot-html-viewer-textarea-atvKCpJgaHp8VNhmjHAMcA {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-atvKCpJgaHp8VNhmjHAMcA:checked + #ipyplot-html-viewer-label-atvKCpJgaHp8VNhmjHAMcA:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-atvKCpJgaHp8VNhmjHAMcA">
#         <label id="ipyplot-html-viewer-label-atvKCpJgaHp8VNhmjHAMcA" for="ipyplot-html-viewer-toggle-atvKCpJgaHp8VNhmjHAMcA">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-atvKCpJgaHp8VNhmjHAMcA" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jkP6vR4Vff5m9aG6ywymLt">
#     <div class="ipyplot-placeholder-div-jkP6vR4Vff5m9aG6ywymLt">
#         <div id="ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt-WREGMwsedtMeRM3U8BXQvE" class="ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt-WREGMwsedtMeRM3U8BXQvE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-jkP6vR4Vff5m9aG6ywymLt">
#     <div class="ipyplot-placeholder-div-jkP6vR4Vff5m9aG6ywymLt">
#         <div id="ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt-WREGMwsedtMeRM3U8BXQvE" class="ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-jkP6vR4Vff5m9aG6ywymLt-WREGMwsedtMeRM3U8BXQvE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
import importlib
importlib.reload(n2d)
# Out:
# <module 'network2d' from '/home/peter/Python_projects/pkg_mod/network2d.py'>

# %%
# Update molecule positions in database


#import psycopg2

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")

cur = db_nn.cursor()
sql = 'SELECT * FROM network."Mol_Net" WHERE "Network" = '+str(network)
cur.execute(sql)
net_count = cur.fetchall()

#mol_count = mol_count[0]
if net_count == []:
    print('No Network')
    for i,j in net_mol.items():
        print(i,j)
        for k in j:
            x = i[0]
            y = i[1]
            #print(k, x, y)
            sql = 'INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (' \
            +str(k)+','+str(x)+','+str(y)+','+str(network)+')'
            print(sql)
            cur.execute(sql)
            #id = cur.fetchone()[0]
            #print(id)
    db_nn.commit()
else:
    print('Structures Available : ',net_count)
    for i,j in net_mol.items():
        #print(i,j)
        for k in j:
            x = i[0]
            y = i[1]
            sql = 'SELECT 1 FROM network."Mol_Net" WHERE "Network" = 1 AND "Struct_ID" = '+str(k)
            cur.execute(sql)
            fl = cur.fetchone()
            if fl != None:
                #print('Update',k, fl)
                sql = 'UPDATE network."Mol_Net" SET "X" = '+str(x)+', "Y" = '+str(y)+ \
                ' WHERE "Struct_ID" = '+str(k)+' AND "Network" = '+str(network)
                #print(sql)
            else:
                #print('Insert',k, fl)
                sql = 'INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (' \
                +str(k)+','+str(x)+','+str(y)+','+str(network)+')'
            print(sql)
            cur.execute(sql)
            
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
# Out:
# Structures Available :  [(19, 0.0, 2.0, 2), (21, 0.0, 2.0, 2), (22, 0.0, 2.0, 2), (23, 0.0, 2.0, 2), (34, 1.0, 0.0, 2), (24, 1.0, 1.0, 2), (20, 1.0, 2.0, 2), (18, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (35, 2.0, 0.0, 2), (36, 2.0, 0.0, 2), (37, 2.0, 0.0, 2), (38, 2.0, 0.0, 2), (10, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (19, 0.0, 2.0, 2), (21, 0.0, 2.0, 2), (22, 0.0, 2.0, 2), (23, 0.0, 2.0, 2), (34, 1.0, 0.0, 2), (24, 1.0, 1.0, 2), (20, 1.0, 2.0, 2), (18, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (35, 2.0, 0.0, 2), (36, 2.0, 0.0, 2), (37, 2.0, 0.0, 2), (38, 2.0, 0.0, 2), (10, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (16, 2.0, 1.0, 2)]
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 0 WHERE "Struct_ID" = 23 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 21 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 0 WHERE "Struct_ID" = 18 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 0 WHERE "Struct_ID" = 17 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 35 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 24 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 34 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 36 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 37 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 38 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 10 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 11 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 13 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 14 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 15 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 16 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 20 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 1 WHERE "Struct_ID" = 22 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 2 WHERE "Struct_ID" = 19 AND "Network" = 2

# %%
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

# %%
# update network neurons in database

#print(net)

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
for x in range(0, ms):
    for y in range(0, ms):
        for f in range(0, fp):
            #print(x,y,f)
            fi = fp_index[f]
            sql = 'SELECT 1 FROM network."Neurons_2D" WHERE "Network" = '+str(network)+' AND "X" = '+str(x)+ \
            ' AND "Y" = '+str(y)+ ' AND "Fingerprint_ID" = ' +str(fi)
            #print(sql)
            cur.execute(sql)
            fl = cur.fetchone()
            #print(fl, sql)
            #print(x,y,fi,net[x,y,f,0],net[x,y,f,1])
            if fl != None:
                #print('UPDATE',fl,x,y,fi)
                sql = 'UPDATE network."Neurons_2D" SET "Sigma" = '+str(net[x,y,f,1])+ ', "Amplitude" = '+str(net[x,y,f,0])+\
                ' WHERE "Network" = '+str(network)+' AND "X" = '+str(x)+ \
                ' AND "Y" = '+str(y)+ ' AND "Fingerprint_ID" = ' +str(fi)
                print(sql)
            else:
                sql = 'INSERT INTO network."Neurons_2D" ("X","Y","Sigma", "Amplitude", "Network", "Fingerprint_ID") '+ \
                'VALUES ('+str(x)+','+str(y)+','+str(net[x,y,f,1])+','+str(net[x,y,f,0])+','+str(network)+','+str(fi)+')'
                print(sql)
            cur.execute(sql)
            
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
# Out:
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.1915051675801644 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.9569608688685728 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.016607388204994 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5718584336448365 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.45968446195300766 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.0770516486678105 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2885832941590392 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28832276555970526 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28034972903496946 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.987256649809609 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0280271364617768 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0626053300154614 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5724360616464697 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.44539319636980607 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.07705164866783844 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28989446456208556 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2896320821988233 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2802743080823138 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.2377218795533633 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.9855135885869585 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0354335030168837 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5721391825007225 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4514839126086283 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.07705164866782947 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2898794416393304 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2896177213062504 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28031135820567954 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 5.158790928339372, "Amplitude" = 1.0921005950642426 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 1.5034196349913378, "Amplitude" = 0.9982058890584521 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 1.4444993119278673, "Amplitude" = 1.043052453067753 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 1.9404842100852324, "Amplitude" = 1.5721922847799032 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0053751265636040714, "Amplitude" = 0.45087004899852273 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 3.1567525052124545, "Amplitude" = 0.07705164866782828 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 1.9950458880738549, "Amplitude" = 0.2895281143035653 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.005423883245124653, "Amplitude" = 0.2892664417233838 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.99458330947147, "Amplitude" = 0.2803058132705241 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.971251219527035 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0301720202425355 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0636993691310712 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5724401568091926 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4452352690867767 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.0770516486678385 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.289907233309477 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28964483093184573 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2802739509198657 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.1013331152198318 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0049744655155473 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.0475046540095356 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5722579138222497 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4489692482197911 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.07705164866783265 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28982314969151163 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2895611998138018 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.28029686591317804 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 5.001878837257543, "Amplitude" = 1.0341971691663687 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 1.1755288507674495, "Amplitude" = 1.009060790350444 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 1.2179936269756968, "Amplitude" = 1.0495043350061828 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 1.6554832822765206, "Amplitude" = 1.572235144211618 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.18972776361276672, "Amplitude" = 0.44943527656634746 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 4.695138728009771, "Amplitude" = 0.07705164866782867 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 1.3576168250222163, "Amplitude" = 0.2895680113056017 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.08108868377401708, "Amplitude" = 0.28930610336203094 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.6254243268505812, "Amplitude" = 0.28030185989833195 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 1.2995153505991148, "Amplitude" = 0.919575622621734 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.9084573709530637, "Amplitude" = 1.035382816716953 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.8181002918896201, "Amplitude" = 1.0662924242392922 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.46921054339562723, "Amplitude" = 1.5724486994593834 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5813455868724224, "Amplitude" = 0.4449433991439432 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.07907634277164305, "Amplitude" = 0.07705164866783858 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5640528626994282, "Amplitude" = 0.28992091374011825 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5640131711313807, "Amplitude" = 0.2896584684245871 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.36944839767713855, "Amplitude" = 0.28027322813368905 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 4.5462673284415285, "Amplitude" = 0.9848962684688571 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 1.1005274533988505, "Amplitude" = 1.0297408192533533 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 1.1899705715810893, "Amplitude" = 1.0634975011076477 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5293612870353377, "Amplitude" = 1.5724397864412878 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.9697332357050531, "Amplitude" = 0.44524319823866476 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 3.0313470467641332, "Amplitude" = 0.0770516486678385 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.1362516408617407, "Amplitude" = 0.2899108384079952 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 1.9578076413568979, "Amplitude" = 0.2896484333287031 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.12005684166835388, "Amplitude" = 0.2802739757966113 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 33

# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

network = 2
msn = 0
fpn = 0


#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
sql = 'SELECT * FROM network."Neurons_2D" WHERE "Network" = '+str(network)
cur.execute(sql)
fl = cur.fetchall()
if len(fl) != 0:
    print('Network Found')
    for i in fl:
        msn = max(msn, int(i[0]))
    msn = msn+1
    fpn = int(len(fl)/(msn*msn))
else:
    print('Naive Network')
print(fl, len(fl), msn,fpn)

#print
#print(net)
#print
ms = msn
fp = fpn
net = np.zeros((ms, ms, fp, 2))
#print(nett)
if len(fl) != 0:
    fp_index = []
    print('Transferring Network Values')
    for i in range(0,fp):
        j = fl[i][5]
        #print(j)
        fp_index.append(j)
    
    print(fp_index)
    
    fpa = ''
    for i in fp_index:
        #fpa.append(i[0])
        fpa = fpa + str(i) +','
    fpa = fpa[:-1]
    
    print('Fingerprints chosen : ',fpa)


    for i in fl:
        #print(i)
        x = int(i[0])
        y = int(i[1])
        f = i[5]
        s = i[2]
        a = i[3]
        fi = fp_index.index(f)
        #print(x,y,f, fi, a, s)
        net[x][y][fi][0] = a
        net[x][y][fi][1] = s
else:
    # generate random floating point values
    print('Random Network Seed')
    from random import seed
    from random import random
    # seed random number generator
    t = int(time.time()*1000)
    # print(t)
    seed(t)

    print()
    #r = 5000
    for x in range(0,ms):
        for y in range(0, ms):
            for f in range(0,fp):
                #x = int(ms*random())
                #y = int(ms*random())
                #f = int(fp*random())
                # t = int(2*random())
                v = int((fp_max[f]+1)*random())
                # print(x,y,f,t,v)
                net[x][y][f][0] = v
print(net)
# Out:
# Network Found
# [(0.0, 0.0, 0.0, 1.1915051675801644, 2, 27, 15), (0.0, 0.0, 0.0, 1.1915051675801644, 2, 27, 110), (0.0, 0.0, 0.0, 0.9569608688685728, 2, 8, 16), (0.0, 0.0, 0.0, 0.9569608688685728, 2, 8, 111), (0.0, 0.0, 0.0, 1.016607388204994, 2, 11, 17), (0.0, 0.0, 0.0, 1.016607388204994, 2, 11, 112), (0.0, 0.0, 0.0, 1.5718584336448365, 2, 9, 18), (0.0, 0.0, 0.0, 1.5718584336448365, 2, 9, 113), (0.0, 0.0, 0.0, 0.45968446195300766, 2, 42, 19), (0.0, 0.0, 0.0, 0.45968446195300766, 2, 42, 114), (0.0, 0.0, 0.0, 0.0770516486678105, 2, 25, 20), (0.0, 0.0, 0.0, 0.0770516486678105, 2, 25, 115), (0.0, 0.0, 0.0, 0.2885832941590392, 2, 35, 21), (0.0, 0.0, 0.0, 0.2885832941590392, 2, 35, 116), (0.0, 0.0, 0.0, 0.28832276555970526, 2, 40, 22), (0.0, 0.0, 0.0, 0.28832276555970526, 2, 40, 117), (0.0, 0.0, 0.0, 0.28034972903496946, 2, 33, 23), (0.0, 0.0, 0.0, 0.28034972903496946, 2, 33, 118), (0.0, 1.0, 0.0, 0.987256649809609, 2, 27, 24), (0.0, 1.0, 0.0, 0.987256649809609, 2, 27, 119), (0.0, 1.0, 0.0, 1.0280271364617768, 2, 8, 25), (0.0, 1.0, 0.0, 1.0280271364617768, 2, 8, 120), (0.0, 1.0, 0.0, 1.0626053300154614, 2, 11, 26), (0.0, 1.0, 0.0, 1.0626053300154614, 2, 11, 121), (0.0, 1.0, 0.0, 1.5724360616464697, 2, 9, 27), (0.0, 1.0, 0.0, 1.5724360616464697, 2, 9, 122), (0.0, 1.0, 0.0, 0.44539319636980607, 2, 42, 28), (0.0, 1.0, 0.0, 0.44539319636980607, 2, 42, 123), (0.0, 1.0, 0.0, 0.07705164866783844, 2, 25, 29), (0.0, 1.0, 0.0, 0.07705164866783844, 2, 25, 124), (0.0, 1.0, 0.0, 0.28989446456208556, 2, 35, 30), (0.0, 1.0, 0.0, 0.28989446456208556, 2, 35, 125), (0.0, 1.0, 0.0, 0.2896320821988233, 2, 40, 31), (0.0, 1.0, 0.0, 0.2896320821988233, 2, 40, 126), (0.0, 1.0, 0.0, 0.2802743080823138, 2, 33, 32), (0.0, 1.0, 0.0, 0.2802743080823138, 2, 33, 127), (0.0, 2.0, 0.0, 1.2377218795533633, 2, 27, 33), (0.0, 2.0, 0.0, 1.2377218795533633, 2, 27, 128), (0.0, 2.0, 0.0, 0.9855135885869585, 2, 8, 34), (0.0, 2.0, 0.0, 0.9855135885869585, 2, 8, 129), (
#    [1.01660739 0.        ]
#    [0.         0.        ]
#    [1.57185843 0.        ]
#    [0.         0.        ]
#    [0.45968446 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28858329 0.        ]
#    [0.         0.        ]
#    [0.28832277 0.        ]
#    [0.         0.        ]
#    [0.28034973 0.        ]
#    [0.         0.        ]]
#
#   [[0.98725665 0.        ]
#    [0.         0.        ]
#    [1.02802714 0.        ]
#    [0.         0.        ]
#    [1.06260533 0.        ]
#    [0.         0.        ]
#    [1.57243606 0.        ]
#    [0.         0.        ]
#    [0.4453932  0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28989446 0.        ]
#    [0.         0.        ]
#    [0.28963208 0.        ]
#    [0.         0.        ]
#    [0.28027431 0.        ]
#    [0.         0.        ]]
#
#   [[1.23772188 0.        ]
#    [0.         0.        ]
#    [0.98551359 0.        ]
#    [0.         0.        ]
#    [1.0354335  0.        ]
#    [0.         0.        ]
#    [1.57213918 0.        ]
#    [0.         0.        ]
#    [0.45148391 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28987944 0.        ]
#    [0.         0.        ]
#    [0.28961772 0.        ]
#    [0.         0.        ]
#    [0.28031136 0.        ]
#    [0.         0.        ]]]
#
#
#  [[[1.0921006  5.15879093]
#    [0.         0.        ]
#    [0.99820589 1.50341963]
#    [0.         0.        ]
#    [1.04305245 1.44449931]
#    [0.         0.        ]
#    [1.57219228 1.94048421]
#    [0.         0.        ]
#    [0.45087005 0.00537513]
#    [0.         0.        ]
#    [0.07705165 3.15675251]
#    [0.         0.        ]
#    [0.28952811 1.99504589]
#    [0.         0.        ]
#    [0.28926644 0.00542388]
#    [0.         0.        ]
#    [0.28030581 0.99458331]
#    [0.         0.        ]]
#
#   [[0.97125122 0.        ]
#    [0.         0.        ]
#    [1.03017202 0.        ]
#    [0.         0.        ]
#    [1.06369937 0.        ]
#    [0.         0.        ]
#    [1.57244016 0.        ]
#    [0.         0.        ]
#    [0.44523527 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28990723 0.        ]
#    [0.         0.        ]
#    [0.28964483 0.        ]
#    [0.         0.        ]
#    [0.28027395 0.        ]
#    [0.         0.        ]]
#
#   [[1.10133312 0.        ]
#    [0.         0.        ]
#    [1.00497447 0.        ]
#    [0.         0.        ]
#    [1.04750465 0.        ]
#    [0.         0.        ]
#    [1.57225791 0.        ]
#    [0.         0.        ]
#    [0.44896925 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28982315 0.        ]
#    [0.         0.        ]
#    [0.2895612  0.        ]
#    [0.         0.        ]
#    [0.28029687 0.        ]
#    [0.         0.        ]]]
#
#
#  [[[1.03419717 5.00187884]
#    [0.         0.        ]
#    [1.00906079 1.17552885]
#    [0.         0.        ]
#    [1.04950434 1.21799363]
#    [0.         0.        ]
#    [1.57223514 1.65548328]
#    [0.         0.        ]
#    [0.44943528 0.18972776]
#    [0.         0.        ]
#    [0.07705165 4.69513873]
#    [0.         0.        ]
#    [0.28956801 1.35761683]
#    [0.         0.        ]
#    [0.2893061  0.08108868]
#    [0.         0.        ]
#    [0.28030186 0.62542433]
#    [0.         0.        ]]
#
#   [[0.91957562 1.29951535]
#    [0.         0.        ]
#    [1.03538282 0.90845737]
#    [0.         0.        ]
#    [1.06629242 0.81810029]
#    [0.         0.        ]
#    [1.5724487  0.46921054]
#    [0.         0.        ]
#    [0.4449434  0.58134559]
#    [0.         0.        ]
#    [0.07705165 0.07907634]
#    [0.         0.        ]
#    [0.28992091 0.56405286]
#    [0.         0.        ]
#    [0.28965847 0.56401317]
#    [0.         0.        ]
#    [0.28027323 0.3694484 ]
#    [0.         0.        ]]
#
#   [[0.98489627 4.54626733]
#    [0.         0.        ]
#    [1.02974082 1.10052745]
#    [0.         0.        ]
#    [1.0634975  1.18997057]
#    [0.         0.        ]
#    [1.57243979 0.52936129]
#    [0.         0.        ]
#    [0.4452432  0.96973324]
#    [0.         0.        ]
#    [0.07705165 3.03134705]
#    [0.         0.        ]
#    [0.28991084 0.13625164]
#    [0.         0.        ]
#    [0.28964843 1.95780764]
#    [0.         0.        ]
#    [0.28027398 0.12005684]
#    [0.         0.        ]]]]

# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

network = 2

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

cur = db_nn.cursor()
sql = 'SELECT * FROM network."Mol_Net" WHERE "Network" = '+str(network)
cur.execute(sql)
ml = cur.fetchall()

print(ml)
# Out:
# [(23, 0.0, 0.0, 2), (23, 0.0, 0.0, 2), (21, 0.0, 2.0, 2), (21, 0.0, 2.0, 2), (18, 2.0, 0.0, 2), (18, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (35, 2.0, 1.0, 2), (35, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (19, 2.0, 2.0, 2), (19, 2.0, 2.0, 2)]
