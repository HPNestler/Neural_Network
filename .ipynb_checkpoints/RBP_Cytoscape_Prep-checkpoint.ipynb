# %%
import pandas as pd
from rdkit import Chem, rdBase
from rdkit.Chem import Draw,rdDepictor
from rdkit.Chem import AllChem, Descriptors, DataStructs
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D

df = pd.read_csv("../Chembl_RBP.csv")
print(df)
# Out:
#     component_synonym      chembl_id   molecule_type  max_phase  \
# 0                papD  CHEMBL1213881  Small molecule          0
# 1                papD  CHEMBL1213882  Small molecule          0
# 2                papD  CHEMBL1213883  Small molecule          0
# 3                papD  CHEMBL1213947  Small molecule          0
# 4                papD  CHEMBL1213948  Small molecule          0
# ..                ...            ...             ...        ...
# 480              SMN2  CHEMBL4584853             NaN          0
# 481            ELAVL1       CHEMBL50  Small molecule          3
# 482            ELAVL3       CHEMBL50  Small molecule          3
# 483            ELAVL3     CHEMBL6246  Small molecule          2
# 484              SMN2       CHEMBL98  Small molecule          4
#
#                                       canonical_smiles  CHEMBL_Target  \
# 0    COC(=O)[C@@H]1CSc2c(C3CC3)c(Cc3cccc4ccccc34)cc...  CHEMBL3309037
# 1    COC(=O)[C@@H]1C(C)Sc2c(C3CC3)c(Cc3cccc4ccccc34...  CHEMBL3309037
# 2    COC(=O)[C@@H]1C(OC)Sc2c(C3CC3)c(Cc3cccc4ccccc3...  CHEMBL3309037
# 3    COC(=O)[C@@H]1C(c2ccccc2)Sc2c(C3CC3)c(Cc3cccc4...  CHEMBL3309037
# 4     Cc1sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n2c1C(=O)O  CHEMBL3309037
# ..                                                 ...            ...
# 480  Cc1cn2nc(-c3cc(=O)n4cc(N5CCN6CCC[C@H]6C5)ccc4n...  CHEMBL1293232
# 481         O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12  CHEMBL1250379
# 482         O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12  CHEMBL4105924
# 483         O=c1oc2c(O)c(O)cc3c(=O)oc4c(O)c(O)cc1c4c23  CHEMBL4105924
# 484                        O=C(CCCCCCC(=O)Nc1ccccc1)NO  CHEMBL1293232
#
#                          pref_name   assay_id   ChemBL_Assay  \
# 0           Chaperone protein PapD   646951.0  CHEMBL1217092
# 1           Chaperone protein PapD   646951.0  CHEMBL1217092
# 2           Chaperone protein PapD   646951.0  CHEMBL1217092
# 3           Chaperone protein PapD   646951.0  CHEMBL1217092
# 4           Chaperone protein PapD   646951.0  CHEMBL1217092
# ..                             ...        ...            ...
# 480  Survival motor neuron protein  1881645.0  CHEMBL4383144
# 481            ELAV-like protein 1  1668500.0  CHEMBL4018388
# 482            ELAV-like protein 3  1668499.0  CHEMBL4018387
# 483            ELAV-like protein 3  1668499.0  CHEMBL4018387
# 484  Survival motor neuron protein  1671929.0  CHEMBL4021958
#
#                                            description  standard_value  \
# 0    Inhibition of Escherichia coli UTI89 PapD chap...        800000.0
# 1    Inhibition of Escherichia coli UTI89 PapD chap...         54000.0
# 2    Inhibition of Escherichia coli UTI89 PapD chap...        167000.0
# 3    Inhibition of Escherichia coli UTI89 PapD chap...         22000.0
# 4    Inhibition of Escherichia coli UTI89 PapD chap...         90000.0
# ..                                                 ...             ...
# 480  Activation of SMN protein in human SMA-derived...            20.0
# 481  Inhibition of ELAV1 (unknown origin)-ARE TNFal...          1400.0
# 482  Inhibition of ELAV3 (unknown origin)-artificia...          1800.0
# 483  Inhibition of ELAV3 (unknown origin)-artificia...           600.0
# 484  Stabilization of human luc fused SMN protein e...             NaN
#
#     standard_units
# 0               nM
# 1               nM
# 2               nM
# 3               nM
# 4               nM
# ..             ...
# 480             nM
# 481             nM
# 482             nM
# 483             nM
# 484            NaN
#
# [485 rows x 12 columns]

# %%
m = df[['chembl_id','molecule_type','canonical_smiles', 'max_phase']] 
r = m.to_records(index=False)
#print(r[0][1])
#mol = Chem.MolFromSmiles(r[0][1])
mol = []
chemid = []
rcl = []
for i in r:
    #print(i[1])
    
    if i[1] != 'Protein':
        if (i[0] not in chemid):
            #print(i)
            chemid.append(i[0])
            rcl.append(i)
            mt = Chem.MolFromSmiles(i[2])
            mol.append(mt)
        #else:
        #    print('Duplicate', i[0])
    else:
        print('Fail',i)

print(len(r), len(rcl))
print(rcl)
Draw.MolsToGridImage(mol, molsPerRow=4, maxMols = 200)
# Out:
# 485 259
# [('CHEMBL1213881', 'Small molecule', 'COC(=O)[C@@H]1CSc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n21', 0), ('CHEMBL1213882', 'Small molecule', 'COC(=O)[C@@H]1C(C)Sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n21', 0), ('CHEMBL1213883', 'Small molecule', 'COC(=O)[C@@H]1C(OC)Sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n21', 0), ('CHEMBL1213947', 'Small molecule', 'COC(=O)[C@@H]1C(c2ccccc2)Sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n21', 0), ('CHEMBL1213948', 'Small molecule', 'Cc1sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n2c1C(=O)O', 0), ('CHEMBL1213949', 'Small molecule', 'CC(C)(O)c1sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n2c1C(=O)O', 0), ('CHEMBL1213950', 'Small molecule', 'O=C(O)c1c(-c2ccccc2)sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n12', 0), ('CHEMBL1213994', 'Small molecule', 'COc1ccc(-c2sc3c(C4CC4)c(Cc4cccc5ccccc45)cc(=O)n3c2C(=O)O)cc1', 0), ('CHEMBL1213995', 'Small molecule', 'O=C(c1ccccc1)c1sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n2c1C(=O)O', 0), ('CHEMBL1213996', 'Small molecule', 'O=C(Nc1ccccc1)c1sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n2c1C(=O)O', 0), ('CHEMBL1213997', 'Small molecule', 'Cc1cccc(-c2sc3c(C4CC4)c(Cc4cccc5ccccc45)cc(=O)n3c2C(=O)O)c1', 0), ('CHEMBL1214051', 'Small molecule', 'Cc1ccc(-c2sc3c(C4CC4)c(Cc4cccc5ccccc45)cc(=O)n3c2C(=O)O)cc1', 0), ('CHEMBL1214052', 'Small molecule', 'O=C(O)c1c(-c2ccc3[nH]ccc3c2)sc2c(C3CC3)c(Cc3cccc4ccccc34)cc(=O)n12', 0), ('CHEMBL1214053', 'Small molecule', 'O=C(O)c1c(-c2ccc3c(c2)OC=CO3)sc2c(C3CC3)c(Cc3ccc
', 'Small molecule', 'COc1cc(C(CC(=O)N2CCCC2)c2c(OC)cc(OC)c3c(-c4ccccc4)cc(=O)oc23)cc(OC)c1OC', 0), ('CHEMBL1408693', 'Small molecule', 'NC(=O)C1CCN(c2nc(-c3ccc4c(c3)OCCO4)cs2)CC1', 0), ('CHEMBL1435554', 'Small molecule', 'Cc1noc(C)c1-c1csc(N2CCC(C(N)=O)CC2)n1', 0), ('CHEMBL1455891', 'Small molecule', 'COc1ccc(-c2csc(N3CCC(C(N)=O)CC3)n2)cc1', 0), ('CHEMBL1476918', 'Small molecule', 'NC(=O)C1CCN(c2nc(-c3cccs3)cs2)CC1', 0), ('CHEMBL1476972', 'Small molecule', 'NC(=O)C1CCN(c2 ...
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x10000 at 0x7F9EFD80D4D0>

# %%
nmol = len(mol)
print(nmol)
#fps = [Chem.RDKFingerprint(i) for i in mol]
fps = [AllChem.GetMorganFingerprintAsBitVect(i,3,nBits=2048,useFeatures=True) for i in mol]
tmd = []
for i in range(0, nmol-1):
    for j in range(i+1, nmol):
        td = DataStructs.FingerprintSimilarity(fps[i],fps[j])
        if td >= 0.7:
            #print(r[i][0],r[j][0],td)
            k = (rcl[i][0],"cc",rcl[j][0],td)
            #print(k)
            tmd.append(k)
        #else:
            #print(rcl[i][0],rcl[j][0],'No Connect')
            
print(len(tmd))
print(tmd)
# Out:
# 259
# 487
# [('CHEMBL1213881', 'cc', 'CHEMBL1213882', 0.7083333333333334), ('CHEMBL1213881', 'cc', 'CHEMBL1213883', 0.7083333333333334), ('CHEMBL1213881', 'cc', 'CHEMBL401701', 0.7027027027027027), ('CHEMBL1213881', 'cc', 'CHEMBL402627', 0.7391304347826086), ('CHEMBL1213948', 'cc', 'CHEMBL1213949', 0.7910447761194029), ('CHEMBL1213948', 'cc', 'CHEMBL1213995', 0.7464788732394366), ('CHEMBL1213948', 'cc', 'CHEMBL1214127', 0.7794117647058824), ('CHEMBL1213949', 'cc', 'CHEMBL1213995', 0.7066666666666667), ('CHEMBL1213949', 'cc', 'CHEMBL1214127', 0.7361111111111112), ('CHEMBL1213950', 'cc', 'CHEMBL1213994', 0.8356164383561644), ('CHEMBL1213950', 'cc', 'CHEMBL1213997', 0.8591549295774648), ('CHEMBL1213950', 'cc', 'CHEMBL1214051', 0.8840579710144928), ('CHEMBL1213950', 'cc', 'CHEMBL1214052', 0.7317073170731707), ('CHEMBL1213950', 'cc', 'CHEMBL1214053', 0.75), ('CHEMBL1213950', 'cc', 'CHEMBL1214054', 0.76), ('CHEMBL1213950', 'cc', 'CHEMBL1214125', 0.76), ('CHEMBL1213994', 'cc', 'CHEMBL1213997', 0.7692307692307693), ('CHEMBL1213994', 'cc', 'CHEMBL1214051', 0.8133333333333334), ('CHEMBL1213994', 'cc', 'CHEMBL1214053', 0.7804878048780488), ('CHEMBL1213994', 'cc', 'CHEMBL1214054', 0.725), ('CHEMBL1213994', 'cc', 'CHEMBL1214125', 0.725), ('CHEMBL1213995', 'cc', 'CHEMBL1214127', 0.7432432432432432), ('CHEMBL1213997', 'cc', 'CHEMBL1214051', 0.8611111111111112), ('CHEMBL1213997', 'cc', 'CHEMBL1214053', 0.7142857142857143), ('CHEMBL1213997', 