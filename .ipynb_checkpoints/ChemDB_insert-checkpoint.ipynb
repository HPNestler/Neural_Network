# %%
import chemistry_psql as cp
import importlib
importlib.reload(cp)
import psycopg2
import pandas as pd

#dfm = pd.read_csv("../RBP_Manual.csv")
#dfm = pd.read_csv("../data-1633411346295.csv")
#print(type(dfm))
dfm = pd.read_csv("../jm1c01683_si_002.csv")
print(dfm)

struct_dict = ['Smiles','canonical_smiles','smiles']
#print(dfm.columns)
#print()
#struct_col = set(struct_dict).intersection(dfm.columns)
struct_col = list(set(struct_dict).intersection(dfm.columns))[0]
print('Structure Column : ',struct_col)

struct = dfm[[struct_col]].drop_duplicates()
#print(struct)
#struct = struc.drop_duplicates()
#print(struct)

struct_list = struct.to_records(index = False)
#print(struct_list)

imp_struct = ()

print()
print('# # # Structure Insert # # #')
print()
for i in struct_list:
    #print(i)
    cp.SmilesInsert(i)


print()
print('# # # Structure Search # # #')
print()
db_chem = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
cur = db_chem.cursor()
for i in struct_list:
    j= i[0]
    print()
    print(j)
    sql = 'select * from public.structures where molecule =\' '+j+' \'::mol;'
    #print(sql)
    cur.execute(sql)
    mollist = cur.fetchall()
    print(mollist)



#test = ("C1CCCCOCCCC1","C1CCCCNCCCC1","C1CCCCSCCCC1")

#cp.SmilesInsert(test)
# Out:
#     Unnamed: 0 Compound_ID                                             Smiles  \
# 0            0  F6446-1111              O=C(Cc1ccc(Cl)cc1)NCC1CCCN(c2nccs2)C1
# 1            1  F6680-2633  Cn1cc(S(=O)(=O)N2CCN(c3ccnc(C(F)(F)F)c3)C(=O)C...
# 2            2  F2563-1096  COc1cccc(-c2nnc(SCC(=O)NCc3ccc(C)cc3)n2-n2cccc...
# 3            3  F6519-5936           Cc1cccc(CS(=O)(=O)NCC(c2ccco2)n2cccn2)c1
# 4            4  F2685-0280   Cc1ccc(NC(=O)CSc2nc(=O)n(CCCN(C)C)c3c2CCC3)cc1Cl
# 5            5  F6496-3857  O=C(CCC(=O)N1CCC(Cn2nc(-c3ccc(F)cc3)ccc2=O)CC1...
# 6            6  F0566-0396  Cc1cccc2s/c(=N\C(=O)c3ccc(S(=O)(=O)N4CCCCC4)cc...
# 7            7  F0651-0161           Cc1cc2cc(CNC(=O)c3ccc(OC(C)C)cc3)ccc2n1C
# 8            8  F3398-2247  CSc1ccc(-c2noc(-c3cn(-c4ccc(Cl)cc4)c(=O)c4cccc...
# 9            9  F1872-0356            COc1ccc(-n2ccnc2SCC(=O)NC2CCCC2)c(OC)c1
# 10          10  F2633-0230  COc1ccccc1NC(=O)c1c(N)c(C(=O)c2ccc(C)cc2)n2ccc...
# 11          11  F6679-0008  O=C(Cn1cnc2ccccc2c1=O)N1CC(n2c(C3CC3)nc3ccccc3...
# 12          12  F0750-0169  COc1cccc(/C=C2/SC(=S)N(CCCC(=O)Nc3ccc(O)cc3)C2...
# 13          13  F0837-0557     COc1cccc(-c2csc(/C(C#N)=C\Nc3ccc(Br)cc3F)n2)c1
# 14          14  F6359-3804             Cc1ccc(OC2CCN(C(=O)Cc3ccccc3Cl)CC2)nn1
# 15          15  F3406-8422      O=c1n(Cc2ccccc2)nc2ccc(S(=O)(=O)N3CCSCC3)cn12
# 16          16  F6557-0563  O=S1(=O)CCN(S(=O)(=O)c2ccc(-n3cccn3)cc2)CCC1c1...
# 17          17  F2806-0052  O=C(Nc1ccc2ncsc2c1)c1ccc(S(=O)(=O)N2CCc3ccccc3...
# 18          18  F2714-0416  COc1ccc(Cc2nnc(SCC(=O)Nc3cc(Cl)ccc3OC)[nH]c2=O...
# 19          19  F6478-3127              Cc1nccc(OC2CCN(C(=O)CCSc3ccccc3)C2)n1
#
#     AUC(h*ng/mL)
# 0       411.0000
# 1     11323.0000
# 2         0.0563
# 3         0.0000
# 4       392.0000
# 5     22962.0000
# 6        24.0000
# 7      5931.0000
# 8        26.7000
# 9         2.1200
# 10      111.0000
# 11    15427.0000
# 12        0.1030
# 13      226.0000
# 14        9.5300
# 15      237.0000
# 16     2093.0000
# 17        4.1800
# 18    28926.0000
# 19     3768.0000
# Structure Column :  Smiles
#
# # # # Structure Insert # # #
#
# Structure Exist:  O=C(Cc1ccc(Cl)cc1)NCC1CCCN(c2nccs2)C1
# Structure Exist:  Cn1cc(S(=O)(=O)N2CCN(c3ccnc(C(F)(F)F)c3)C(=O)C2)cn1
# Structure Exist:  COc1cccc(-c2nnc(SCC(=O)NCc3ccc(C)cc3)n2-n2cccc2)c1
# Structure Exist:  Cc1cccc(CS(=O)(=O)NCC(c2ccco2)n2cccn2)c1
# Structure Exist:  Cc1ccc(NC(=O)CSc2nc(=O)n(CCCN(C)C)c3c2CCC3)cc1Cl
# Structure Exist:  O=C(CCC(=O)N1CCC(Cn2nc(-c3ccc(F)cc3)ccc2=O)CC1)c1ccccc1
# Structure Exist:  Cc1cccc2s/c(=N\C(=O)c3ccc(S(=O)(=O)N4CCCCC4)cc3)n(C)c12
# Structure Exist:  Cc1cc2cc(CNC(=O)c3ccc(OC(C)C)cc3)ccc2n1C
# Structure Exist:  CSc1ccc(-c2noc(-c3cn(-c4ccc(Cl)cc4)c(=O)c4ccccc34)n2)cc1
# Structure Exist:  COc1ccc(-n2ccnc2SCC(=O)NC2CCCC2)c(OC)c1
# Structure Exist:  COc1ccccc1NC(=O)c1c(N)c(C(=O)c2ccc(C)cc2)n2ccccc12
# Structure Exist:  O=C(Cn1cnc2ccccc2c1=O)N1CC(n2c(C3CC3)nc3ccccc32)C1
# Structure Exist:  COc1cccc(/C=C2/SC(=S)N(CCCC(=O)Nc3ccc(O)cc3)C2=O)c1
# O=c1n(Cc2ccccc2)nc2ccc(S(=O)(=O)N3CCSCC3)cn12
# [(16305, 'O=c1n(Cc2ccccc2)nc2ccc(S(=O)(=O)N3CCSCC3)cn12', 'O=c1n(Cc2ccccc2)nc2ccc(S(=O)(=O)N3CCSCC3)cn12', None)]
#
# O=S1(=O)CCN(S(=O)(=O)c2ccc(-n3cccn3)cc2)CCC1c1cccs1
# [(16306, 'O=S1(=O)CCN(S(=O)(=O)c2ccc(-n3cccn3)cc2)CCC1c1cccs1', 'O=S1(=O)CCN(S(=O)(=O)c2ccc(-n3cccn3)cc2)CCC1c1cccs1', None)]
#
# O=C(Nc1ccc2ncsc2c1)c1ccc(S(=O)(=O)N2CCc3ccccc3C2)cc1
# [(16307, 'O=C(Nc1ccc2ncsc2c1)c1ccc(S(=O)(=O)N2CCc3ccccc3C2)cc1', 'O=C(Nc1ccc2ncsc2c1)c1ccc(S(=O)(=O)N2CCc3ccccc3C2)cc1', None)]
#
# COc1ccc(Cc2nnc(SCC(=O)Nc3cc(Cl)ccc3OC)[nH]c2=O)cc1
# [(16308, 'COc1ccc(Cc2nnc(SCC(=O)Nc3cc(Cl)ccc3OC)[nH]c2=O)cc1', 'COc1ccc(Cc2nnc(SCC(=O)Nc3cc(Cl)ccc3OC)[nH]c2=O)cc1', None)]
#
# Cc1nccc(OC2CCN(C(=O)CCSc3ccccc3)C2)n1
# [(16309, 'Cc1nccc(OC2CCN(C(=O)CCSc3ccccc3)C2)n1', 'Cc1nccc(OC2CCN(C(=O)CCSc3ccccc3)C2)n1', None)]

# %%
from rdkit import Chem
from rdkit.Chem import SaltRemover as rdsr

remover = rdsr.SaltRemover()

# We can have a look at some of the salts
a = Chem.MolToSmarts(remover.salts[3])
print(a)
print(len(remover.salts))

for i in remover.salts:
    a = Chem.MolToSmarts(i)
    print(a)
# Out:
# N(=O)(-,:O)O
# 15
# [Cl,Br,I]
# [#3,#11,#19,#20,#12]
# [O,N]
# N(=O)(-,:O)O
# P(=O)(-,:O)(-,:O)O
# P(-,:F)(-,:F)(-,:F)(-,:F)(-,:F)F
# S(=O)(=O)(-,:O)O
# [C&H3]S(=O)(=O)-,:O
# c1cc(-,:[C&H3])ccc1S(=O)(=O)-,:O
# [C&H3]C(=O)O
# FC(-,:F)(-,:F)C(=O)O
# OC(=O)C=CC(=O)O
# OC(=O)C(=O)O
# OC(=O)C(-,:O)C(-,:O)C(=O)O
# C1CCCCC1[N&H1]C1CCCCC1

# %%
from rdkit.Chem.MolStandardize import rdMolStandardize
un = rdMolStandardize.Uncharger()

for i in struct_list:
    j = Chem.MolFromSmiles(i[0])
    r = remover.StripMol(j)
    if j.GetNumAtoms() != r.GetNumAtoms():
        r = un.uncharge(r)
        k = Chem.MolToSmiles(r)
        print(i[0], ' - ',k)
