# %%
import sys
sys.path.append('../pkg_mod')

import db_connector as db
import chemistry_psql as cp
import importlib
importlib.reload(cp)
import psycopg2
import pandas as pd
from rdkit import Chem
from rdkit.Chem import SaltRemover as rdsr

# %%
db_chem = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
cur = db_chem.cursor()
sql = 'select * from structure.structures where chiral is NULL' #limit 1000;'
#print(sql)
cur.execute(sql)
molsql = cur.fetchall()
#print(molsql)
mollist = []
molrev = []
for i in molsql:
    j = i[1].split('.')
    #print(j)
    if len(j) == 1:
        mollist.append(i)
    else:
        print(j)
        molrev.append(i)
        
print()
print(molrev)
# Out:
# ['Cc1n[nH]cc1-c1cc2nc([C@@H]3CCCCN3)[nH]c(=O)c2s1', 'Cl', 'Cl']
# ['CC(C)O[C@@H]1[C@@H](CO[PH](=O)[O-])O[C@@H](n2c[n+](Cc3ccccccccc3)c3c(=O)[nH]c([NH-])nc32)[C@@H]1OC(C)C', '[Na+]']
# ['CC(C)O[C@@H]1[C@@H](CO[PH](=O)[O-])O[C@@H](n2c[n+](Cc3ccccc3)c3c(=O)[nH]c([NH-])nc32)[C@@H]1OC(C)C', '[Na+]']
# ['C[n+]1cn([C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])O2)c2nc([NH-])[nH]c(=O)c21', '[Na+]', '[Na+]', '[Na+]', '[Na+]']
# ['CC[n+]1cn([C@@H]2O[C@H](CO[PH](=O)[O-])[C@@H](OC(C)C)[C@H]2OC(C)C)c2nc(N)[nH]c(=O)c21', '[Na+]']
# ['CC(C)O[C@@H]1[C@@H](CO[PH](=O)[O-])O[C@@H](n2c[n+](C)c3c(=O)[nH]c(N)nc32)[C@@H]1OC(C)C', '[Na+]']
# ['C[n+]1cn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c2nc(N)[nH]c(=O)c21', '[Br-]', '[Na+]', '[Na+]', '[Na+]', '[Na+]']
# ['C[n+]1cn([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c2nc(N)[nH]c(=O)c21', '[Br-]', '[Na+]', '[Na+]']
# ['CC[n+]1cn([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c2nc(N)[nH]c(=O)c21', '[Br-]', '[Na+]', '[Na+]']
# ['CCCCCCCCCCCCCO[C@@H](CO)[C@H](O)C[S@+]1C[C@@H](O)[C@H](O)[C@H]1CO', '[Cl-]']
# ['OC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)C[S@+]1C[C@@H](O)[C@H](O)[C@H]1CO', '[Cl-]']
# ['OC[C@@H](O)[C@@H](O)[C@H](O)[C@H](O)C[S@+]1C[C@@H](O)[C@H](O)[C@H]1CO', '[Cl-]']
# ['F[B-](F)(F)F', 'OC[C@H](OCc1ccccc1)[C@H](O)C[S@+]1C[C@@H](O)[C@H](O)[C@H]1CO']
# ['OC[C@H](O)[C@@H](O)[C@@H](O)[C@H](O)C[S@+]1C[C@@H](O)[C@H](O)[C@H]1CO', '[Cl-]']
# ['CCn1c(=O)/c(=C2\\Sc3cccc(F)c3N2C)s/c1=C\\c1cccc[n+]1CCCCCCNC(=O)CCCC[C@@H]1SC[C@@H]2NC(=O)N[C@H]12', '[Cl-]']
# ['CCn1c(=O)/c(=C2\\Sc3ccc(F)cc3N2C)s/c1=C\\c1cccc[n+]1CCCCCCNC(=O)CCCC[C@@H]1SC[C@@H]2NC(=O)N[C@H]12', '[Cl-]']
# ['CCn1c(=O)/c(=C2\\Sc3cc(F)ccc3N2C)s/c1=C\\c1cccc[n+]1CCCCCCNC(=O)CCCC[C@@H]1SC[C@@H]2NC(=O)N[C@H]12', '[Cl-]']
# ['CCn1c(=O)/c(=C2\\Sc3cc(Br)ccc3N2C)s/c1=C\\c1scc[n+]1Cc1ccc(C(F)(F)F)o1', '[Cl-]']
# ['O=C([O-])c1ccnc(CNCc2ccccc2)c1', '[Li+]']
# ['O=C([O-])c1ccnc(CNCc2ccco2)c1', '[Li+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3OCCC[Na])nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['C[N+]1(C)[C@H]2CC[C@@H]1CC(OC(=O)[C@@H](CO)c1ccccc1)C2', '[I-]']
# ['N#Cc1cccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['COc1cccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['COc1ccc(N=C(C)N(C)CCNS(=O)(=O)c2ccc(Cl)cc2)cc1Cl', 'I']
# ['COc1cc(-c2ccc(/N=N/c3ccc4c(S(=O)(=O)[O-])cc(S(=O)(=O)[O-])c(N)c4c3O)c(OC)c2)ccc1/N=N/c1ccc2c(S(=O)(=O)[O-])cc(S(=O)(=O)[O-])c(N)c2c1O', '[Na+]', '[Na+]', '[Na+]', '[Na+]']
# ['C[N+]1(C)C2CCC1CC(OC(=O)c1ccco1)C2', '[Br-]']
# ['N#Cc1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3cccc(-c4ccccc4)c3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Cc1nc(C)c(C(=O)OC[C@H]2CCCO2)c(-c2ccccc2C(F)(F)F)c1C(=O)[O-]', '[Na+]']
# ['CCOc1ccccc1/N=C1/SCCCN1C', 'I']
# ['Cc1cc(C)cc(-c2ccc(C)cc2-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['Cc1ccc(F)cc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)CC(Br)P(=O)([O-])O', '[Na+]']
# ['Cc1ccc(F)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['C[n+]1cnn2c1SCC1(COC1)C2', '[I-]']
# ['CCCOc1ccc(F)cc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Cc1cccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1C', '[Na+]']
# ['Cc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Cc1cccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['CC(=O)c1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['C[n+]1ccccc1/C=C1\\Sc2ccccc2N1CCO', '[I-]']
# ['NC(=O)CCC(N)COP(=O)([O-])OC[C@H]1OC(n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O', 'O=C(O)C(F)(F)F', '[Na+]']
# ['CCCOc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['COc1ccc(C(=O)C[N+]2(C)CCOCC2)cc1', '[I-]']
# ['CCCCCCC/C=C/CCCCCCCC[C@H]1OC[C@@H](COP([O-])(O)=S)O1', '[K+]']
# ['Cc1ccccc1/C=C/c1cccc[n+]1C', '[I-]']
# ['Cn1ccccc1=Nc1cccc[n+]1C', '[I-]']
# ['CC(=O)O', 'Cc1cc2c(C(C)C)c(O)c(O)c(C=O)c2c(O)c1-c1c(C)cc2c(C(C)C)c(O)c(O)c(C=O)c2c1O']
# ['C[N+]12CCCCC1[C@@H](CO)CCC2', '[Br-]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CC1=CC(C)C(CN(CCC[N+](C)(C)C)C(=O)Nc2ccccc2)C(C)C1', '[I-]']
# ['C[C@@]1(NCC2CCCCC2)COCCCCOC[C@@H](C(=O)O)NC(=O)[C@@H]2CCCN2C(=O)CNC1=O', 'Cl']
# ['C[C@@]1(NCC2CCCCCCC2)COCCCCOC[C@@H](C(=O)O)NC(=O)[C@@H]2CCCN2C(=O)CNC1=O', 'Cl']
# ['CC(C)Oc1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['Cc1cc(C=O)c(OC(C)C)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['CCCCc1c(C)nc2ccc(OC)cc2c1SCCCC#N', 'Cl']
# ['CCCCc1c(C)nc2ccc(OC)cc2c1SCCC#N', 'Cl']
# ['CC(=O)c1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['COC(=O)CCCCCCCCC(O)C[N+]1(C)CCOCC1', '[I-]']
# ['COc1ccccc1/N=C1/SCCCN1C', 'I']
# ['Cc1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['CC(=O)c1cccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['CCCn1c2c(c(=N)c3c1CCC3)CCC2', 'I']
# ['Cc1cccc(C)c1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['CCC(c1nnc(SCCNCCO)n1CCN1CCOCC1)N(C)C', 'O=C(O)C(=O)O']
# ['Cc1ccc(C)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['NCCOCCOc1ccc2nc(-c3cn(-c4ccc(O)cc4)nn3)ccc2c1', 'O=C(O)C(F)(F)F']
# ['Cc1ccc(-c2ccccc2)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3cc(C(F)(F)F)cc(C(F)(F)F)c3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Cc1ccc(-c2cccc(Cl)c2)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['COc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3Cl)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CCCOc1cc(F)ccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['CC(C)[N+](C)(C)CC#CC(O)(c1ccccc1)c1ccccc1', '[Br-]']
# ['CC[N+](C)(CC)CCC/C(=N/O)C(O)(c1ccccc1)c1ccccc1', '[I-]']
# ['C[C@@]1(NCCc2ccccc2)COCCCCOC[C@@H](C(=O)O)NC(=O)[C@@H]2CCCN2C(=O)CNC1=O', 'Cl']
# ['Cc1cc(C)cc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['CCCCn1c2c(c(=N)c3ccccc31)CCC2', 'I']
# ['NCCOc1ccc2nc(-c3cn(-c4ccc(O)cc4)nn3)ccc2c1', 'O=C(O)C(F)(F)F']
# ['CN1/C(=C/c2cccc[n+]2CCO)Sc2ccccc21', '[I-]']
# ['CCCCCCCCCCCCCCCCCOC(COC)COP([O-])(O)=S', '[Na+]']
# ['CCCCCCC/C=C/CCCCCCCC[C@@H]1OC[C@H](COP([O-])(O)=S)O1', '[K+]']
# ['COc1cc(/C=C/c2cccc[n+]2C)ccc1OCC(=O)Nc1ccccc1C', '[I-]']
# ['C[N+]1=C2c3ccccc3N=CN2CC1', '[I-]']
# ['C[n+]1cccc(/C=N/NC(=O)CC23CC4CC(CC(C4)C2)C3)c1', '[I-]']
# ['C[N+]1(CCOS(=O)C23CC4CC(CC(C4)C2)C3)CCOCC1', '[Cl-]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3OCCCO)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CC(C)COc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['C/C=C/C/C=C/C/C=C/CCCCCCCCC1OCC(COP(=O)([O-])O)O1', '[K+]']
# ['Nc1c(/N=N/c2ccc(-c3ccc(Cl)cc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CCCOc1cccc(F)c1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccc(C(F)(F)F)cc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Cc1cc(F)ccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['CCOC(=O)c1ccc2c(c1)[n+](CCO)c(C)n2CC', '[I-]']
# ['CCCCCCC/C=C/CCCCCCCCC1OCC(COP([O-])(O)=S)O1', '[K+]']
# ['CCCCCn1c2c(c(=N)c3ccccc31)CCC2', 'I']
# ['CCCCc1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccc(C(=O)c4ccccc4)cc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3C(F)(F)F)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3O)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Cc1ccc[n+](CC(=O)c2ccccc2)c1', '[Br-]']
# ['Nc1c(/N=N/c2ccc(-c3cccc(C(F)(F)F)c3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['COc1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['NCCOCCOc1ccc2nc(-c3cn(-c4ccc(O)c(F)c4)nn3)ccc2c1', 'O=C(O)C(F)(F)F']
# ['COC(=O)CCC(=O)c1ccc(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)cc1', '[Na+]']
# ['CCCCCCCCCCCCC1OCC(COP(=O)([O-])O)O1', '[K+]']
# ['CCCCCCC/C=C/CCCCCCCC[C@@H]1OC[C@@H](COP([O-])(O)=S)O1', '[K+]']
# ['CCCCCCC/C=C/CCCCCCCCC1OCC(COP(=O)([O-])O)O1', '[K+]']
# ['CCCCCCC/C=C/CCCCCCCC[C@H]1OC[C@H](COP([O-])(O)=S)O1', '[K+]']
# ['CCCCCCCCc1ccc(CCCCCCC2OCC(COP(=O)([O-])O)O2)cc1', '[K+]']
# ['CCCCCCCCCCCCCCCCCC(=O)OC(COC)COP([O-])(O)=S', '[Na+]']
# ['CCCCCCCCCCCCCCCCOC(COC)COP([O-])(O)=S', '[Na+]']
# ['CCCCCCCCCCCCCCCC(=O)OC[C@@H](O)CC(Br)P(=O)([O-])O', '[Na+]']
# ['CCOC(=O)c1c(CC)nc2ccccc2c1SCCC#N', 'Cl']
# ['CC(C)(C#CCCCCC#CC(C)(C)[N+](C)(C)C)[N+](C)(C)C', '[I-]', '[I-]']
# ['CCCCn1cc[n+](-c2nc3c([N+](=O)[O-])cccc3n2C)c1', '[I-]']
# ['C[N+]1(C)[C@H]2CC[C@@H]1CC(OC(=O)C(c1ccccc1)c1ccccc1)C2', '[I-]']
# ['CCCC[N+]12C3C[C@H](C4[C@H](O)[C@]5(C[C@@H]41)c1ccccc1N(C)[C@@H]35)[C@H](CC)[C@H]2O', '[I-]']
# ['O=C(C[n+]1ccccc1)c1ccc(Cl)cc1', '[I-]']
# ['CCCCCn1ccc(=N)cc1', 'I']
# ['CC(=O)OC(C[N+]1(C)CCCCCC1)c1ccccc1', '[I-]']
# ['CCCCOc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3-c3ccccc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CC(C)Oc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccc(Cl)cc3Cl)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3Oc3ccccc3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CCCCOc1c(C=O)cc(C)cc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['Cc1ccc(-c2ccc(Cl)cc2)c(-c2ccc(/N=N/c3cc(S(=O)(=O)[O-])c4ccccc4c3N)cn2)c1', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3cccc(Cl)c3)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3cc(Cl)ccc3O)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['Nc1c(/N=N/c2ccc(-c3ccccc3OCCCCCCO)nc2)cc(S(=O)(=O)[O-])c2ccccc12', '[Na+]']
# ['CCCCCCOc1ccccc1-c1ccc(/N=N/c2cc(S(=O)(=O)[O-])c3ccccc3c2N)cn1', '[Na+]']
# ['CNC(=O)c1cc(Oc2ccc(NC(=O)Nc3ccc(Cl)c(C(F)(F)F)c3)cc2)ccn1', 'Cc1ccc(S(=O)(=O)O)cc1']
# ['CCN(Cc1cc(Nc2nc(C)cn3c(-c4cn[nH]c4)cnc23)sn1)C(C)(C)CO', 'Cl']
# ['Cc1cn2c(-c3cn[nH]c3)cnc2c(Nc2cc(CN(CC(F)F)C(C)(C)CO)ns2)n1', 'Cl']
# ['Cc1cn2c(-c3cn[nH]c3)cnc2c(Nc2cc(CN(CC(F)(F)F)C(C)(C)CO)ns2)n1', 'Cl']
    mct = Chem.FindMolChiralCenters(m,force=True,includeUnassigned=False)
    mcl = ''.join([str(e) for e in mc])
    #print(i[0],i[1],mc)
    ### No chiral centers ###
    if len(mc) == 0:
        #print()
        sql = 'UPDATE structure.structures SET chiral = 0, chiral_assigned = 0 WHERE structure_id = '+str(i[0])+';'
        print(sql)
        cur.execute(sql)
        db_chem.commit()
    else:
    ### No defined chiral centers ###
        mct = Chem.FindMolChiralCenters(m,force=True,includeUnassigned=False)
        mcl = ''.join([str(e) for e in mc])
        print()
        print(i[0],len(mc), i[1],mc)
        print(i[0],len(mct),i[1],mct)
        mcl = mcl.replace(chr(39),'')
        mcl = mcl.replace(' ','')
        print(mcl)
        if len(mct) == 0:
            sql = "UPDATE structure.structures SET chiral = "+str(len(mc))+", chiral_assigned = 0, chiral_list = '"+mcl+"' WHERE structure_id = "+str(i[0])+";"
            print(sql)
            cur.execute(sql)
            db_chem.commit()
        else:
    ### Defined chiral centers ###
    ### Flatten structures ### 
            mf = m
            Chem.RemoveStereochemistry(mf)
            mfc = Chem.FindMolChiralCenters(mf,force=True,includeUnassigned=True)
            mfct = Chem.FindMolChiralCenters(mf,force=True,includeUnassigned=False)
            mfs = Chem.MolToSmiles(mf)
            mfcl = ''.join([str(e) for e in mfc])
            print(len(mfc), mfs, mfc)
            print(len(mfct), mfs, mfct)
            mfcl = mfcl.replace(chr(39),'')
            mfcl = mfcl.replace(' ','')
            print(mfcl)
     ### Does flattened structures exist ? ###       
            #sql = 'select * from structure.structures where molecule::structure.mol @= structure.mol_from_smiles(\''+mfs+'\'::cstring);'
            sql = 'select * from structure.structures where substruct(molecule, \''+mfs+'\'::mol) and mol_inchi(molecule)::text = mol_inchi(\''+mfs+'\'::mol)::text;'
            #print(sql)
            cur.execute(sql)
            molflat = cur.fetchall()
            print(molflat)
            if len(molflat) == 1:
     ### One flattened structure exists - update flattened structure record and original record ###
                #print(molflat)
                sid = molflat[0][0]
                sql = "UPDATE structure.structures SET chiral = "+str(len(mc))+", chiral_assigned = 0, chiral_list = '"+mfcl+"' WHERE structure_id = "+str(sid)+";"
                print(sql)
                cur.execute(sql)
                sql = "UPDATE structure.structures SET chiral = "+str(len(mc))+", chiral_assigned = "+str(len(mct))+", chiral_list = '"+mcl+"' WHERE structure_id = "+str(i[0])+";"
                print(sql)
                cur.execute(sql)
                db_chem.commit()
            elif len(molflat) == 0:
    ### No flattened structure - insert flattened structure and update original record ###
                smi = (mfs,)
                print(smi)
                cp.SmilesInsert(smi)
                sql = 'select max(structure_id) from structure.structures'
                cur.execute(sql)
                smax = cur.fetchone()
                sm = smax[0]
                print(smax, sm)
                sql = "UPDATE structure.structures SET chiral = "+str(len(mc))+", chiral_assigned = 0, chiral_list = '"+mfcl+"' WHERE structure_id = "+str(sm)+";"
                print(sql)
                cur.execute(sql)
                sql = "UPDATE structure.structures SET chiral = "+str(len(mc))+", chiral_assigned = "+str(len(mct))+", chiral_list = '"+mcl+"' WHERE structure_id = "+str(i[0])+";"
                print(sql)
                cur.execute(sql)
                db_chem.commit()
            else:
     ### More than one flattened structure --- Alert ###
                print('More than one match!!!!!')
        print()
