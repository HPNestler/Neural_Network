# %%
##### Import needed Libraries #####

import numpy as np
import pandas as pd
import math
from rdkit import Chem, rdBase
from rdkit.Chem import Draw,rdDepictor
from rdkit.Chem import AllChem, Descriptors, DataStructs
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

print('Libraries Imported')
# Out:
# Libraries Imported

# %%
##### Read Manual Connections #####

dfm = pd.read_csv("../RBP_Manual.csv")
print(dfm)
# Out:
#    component_synonym            chembl_id       synonyms  \
# 0              TRBP2          jm1c00018_1            NaN
# 1              TRBP2          jm1c00018_2            NaN
# 2              TRBP2          jm1c00018_3            NaN
# 3              TRBP2          jm1c00018_4            NaN
# 4              TRBP2          jm1c00018_5            NaN
# ..               ...                  ...            ...
# 62             LIN28  cellrep201804116_38  CHEMBL4438300
# 63             LIN28  cellrep201804116_39  CHEMBL4438300
# 64             LIN28  cellrep201804116_40  CHEMBL4438300
# 65             LIN28  cellrep201804116_41  CHEMBL4438300
# 66             LIN28  cellrep201804116_42  CHEMBL4438300
#
#                                      canonical_smiles  \
# 0   O=C(OC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C3C(OCO3)=C1
# 1   O=C(NCCN(CC)CC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C...
# 2   O=C(NCC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC...
# 3   O=C(NC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC)...
# 4   O=C(NC1=CC=CC(OC)=C1)C2=C(C3=CC=C(N(C)C)C=C3)C...
# ..                                                ...
# 62   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4
# 63         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O
# 64                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3
# 65  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...
# 66  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...
#
#                      pref_name  max_phase
# 0    TAR RNA-binding protein 2        NaN
# 1    TAR RNA-binding protein 2        NaN
# 2    TAR RNA-binding protein 2        NaN
# 3    TAR RNA-binding protein 2        NaN
# 4    TAR RNA-binding protein 2        NaN
# ..                         ...        ...
# 62  Protein lin-28 homolog A/B        NaN
# 63  Protein lin-28 homolog A/B        NaN
# 64  Protein lin-28 homolog A/B        NaN
# 65  Protein lin-28 homolog A/B        NaN
# 66  Protein lin-28 homolog A/B        NaN
#
# [67 rows x 6 columns]

# %%
##### Reformat Manual Data Frame #####

dfm['syn_type'] = ''
dfm['molecule_type'] = 'Small Molecule'
dfm['CHEMBL_Target'] = ''
dfm['ChemBL_Assay'] = ''
dfm['assay_id'] = ''
dfm['description'] = ''
dfm['standard_value'] = ''
dfm['standard_units'] = ''

dfm['max_phase'].fillna(0, inplace=True)

# Assign Assays and Targets #
l = len(dfm)
t = []
for i in range(0,l):
    tt = dfm['component_synonym'][i]
    if tt not in t:
        #print(tt)
        t.append(tt)
    
print(t)

for i in range(0,l):
    tt = dfm['component_synonym'][i]
    tx = t.index(tt)
    #print(tt, tx)
    dfm['CHEMBL_Target'][i] = 'Target_'+str(tx)
    dfm['ChemBL_Assay'][i] = 'Assay_'+str(tx)
    dfm['assay_id'][i] = 'Assay_'+str(tx)
    dfm['description'][i] = 'Assay for '+dfm['pref_name'][i] 
    
# Print Data Frame #
#dfm = dfm[['component_synonym','chembl_id','synonyms','syn_type', 'molecule_type','max_phase','canonical_smiles','CHEMBL_Target','pref_name','assay_id','ChemBL_Assay','description','standard_value','standard_units']]
print(dfm)
# Out:
# ['TRBP2', 'SMN2', 'PAPD5', 'LIN28']
#    component_synonym            chembl_id       synonyms  \
# 0              TRBP2          jm1c00018_1            NaN
# 1              TRBP2          jm1c00018_2            NaN
# 2              TRBP2          jm1c00018_3            NaN
# 3              TRBP2          jm1c00018_4            NaN
# 4              TRBP2          jm1c00018_5            NaN
# ..               ...                  ...            ...
# 62             LIN28  cellrep201804116_38  CHEMBL4438300
# 63             LIN28  cellrep201804116_39  CHEMBL4438300
# 64             LIN28  cellrep201804116_40  CHEMBL4438300
# 65             LIN28  cellrep201804116_41  CHEMBL4438300
# 66             LIN28  cellrep201804116_42  CHEMBL4438300
#
#                                      canonical_smiles  \
# 0   O=C(OC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C3C(OCO3)=C1
# 1   O=C(NCCN(CC)CC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C...
# 2   O=C(NCC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC...
# 3   O=C(NC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC)...
# 4   O=C(NC1=CC=CC(OC)=C1)C2=C(C3=CC=C(N(C)C)C=C3)C...
# ..                                                ...
# 62   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4
# 63         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O
# 64                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3
# 65  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...
# 66  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...
#
#                      pref_name  max_phase syn_type   molecule_type  \
# 0    TAR RNA-binding protein 2        0.0           Small Molecule
# 1    TAR RNA-binding protein 2        0.0           Small Molecule
# 2    TAR RNA-binding protein 2        0.0           Small Molecule
# 3    TAR RNA-binding protein 2        0.0           Small Molecule
# 4    TAR RNA-binding protein 2        0.0           Small Molecule
# ..                         ...        ...      ...             ...
# 62  Protein lin-28 homolog A/B        0.0           Small Molecule
# 63  Protein lin-28 homolog A/B        0.0           Small Molecule
# 64  Protein lin-28 homolog A/B        0.0           Small Molecule
# 65  Protein lin-28 homolog A/B        0.0           Small Molecule
# 66  Protein lin-28 homolog A/B        0.0           Small Molecule
#
#    CHEMBL_Target ChemBL_Assay assay_id                           description  \
# 0       Target_0      Assay_0  Assay_0   Assay for TAR RNA-binding protein 2
# 1       Target_0      Assay_0  Assay_0   Assay for TAR RNA-binding protein 2
# 2       Target_0      Assay_0  Assay_0   Assay for TAR RNA-binding protein 2
# 3       Target_0      Assay_0  Assay_0   Assay for TAR RNA-binding protein 2
# 4       Target_0      Assay_0  Assay_0   Assay for TAR RNA-binding protein 2
# ..           ...          ...      ...                                   ...
# 62      Target_3      Assay_3  Assay_3  Assay for Protein lin-28 homolog A/B
# 63      Target_3      Assay_3  Assay_3  Assay for Protein lin-28 homolog A/B
# 64      Target_3      Assay_3  Assay_3  Assay for Protein lin-28 homolog A/B
# 65      Target_3      Assay_3  Assay_3  Assay for Protein lin-28 homolog A/B
# 66      Target_3      Assay_3  Assay_3  Assay for Protein lin-28 homolog A/B
#
#    standard_value standard_units
# 0
# 1
# 2
# 3
# 4
# ..            ...            ...
# 62
# 63
# 64
# 65
# 66
#
# [67 rows x 14 columns]
# /home/peter/anaconda3/envs/rdkit/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/peter/anaconda3/envs/rdkit/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/peter/anaconda3/envs/rdkit/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/peter/anaconda3/envs/rdkit/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
##### Read ChemBL Connections #####

df = pd.read_csv("../Chembl_RBP.csv")


#print(df.columns)
dfm = dfm[df.columns]
#print(dfm.columns)
#print(dfm)


# Create ChemBL Target List #
dfp = df[['component_synonym', 'CHEMBL_Target']]

#print(dfp)

lp = []
lc = []
l = len(dfp)
#print(lp,lc,l)
for i in range(0,l):
    p = dfp['component_synonym'][i]
    c = dfp['CHEMBL_Target'][i]
    #print(p,c)
    if p not in lp and c not in lc:
        lp.append(p)
        lc.append(c)
        #print(i)
        #print(p,c)
        
#print(lp,lc)

l = len(dfm)
for i in range(0,l):
    p = dfm['component_synonym'][i]
    #print(p)
    if p in lp:
        pi = lp.index(p)
        #print(p, pi, lc[pi])
        dfm['CHEMBL_Target'][i] = lc[pi]

print(dfm)
print()
df = pd.concat([df, dfm], axis=0, ignore_index = True)

print(df)
# Out:
#    component_synonym            chembl_id       synonyms syn_type  \
# 0              TRBP2          jm1c00018_1            NaN
# 1              TRBP2          jm1c00018_2            NaN
# 2              TRBP2          jm1c00018_3            NaN
# 3              TRBP2          jm1c00018_4            NaN
# 4              TRBP2          jm1c00018_5            NaN
# ..               ...                  ...            ...      ...
# 62             LIN28  cellrep201804116_38  CHEMBL4438300
# 63             LIN28  cellrep201804116_39  CHEMBL4438300
# 64             LIN28  cellrep201804116_40  CHEMBL4438300
# 65             LIN28  cellrep201804116_41  CHEMBL4438300
# 66             LIN28  cellrep201804116_42  CHEMBL4438300
#
#      molecule_type  max_phase  \
# 0   Small Molecule        0.0
# 1   Small Molecule        0.0
# 2   Small Molecule        0.0
# 3   Small Molecule        0.0
# 4   Small Molecule        0.0
# ..             ...        ...
# 62  Small Molecule        0.0
# 63  Small Molecule        0.0
# 64  Small Molecule        0.0
# 65  Small Molecule        0.0
# 66  Small Molecule        0.0
#
#                                      canonical_smiles  CHEMBL_Target  \
# 0   O=C(OC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C3C(OCO3)=C1       Target_0
# 1   O=C(NCCN(CC)CC)C1=C(C2=CC=C(N(C)C)C=C2)C(OC)=C...       Target_0
# 2   O=C(NCC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC...       Target_0
# 3   O=C(NC1=CC=CC=C1)C2=C(C3=CC=C(N(C)C)C=C3)C(OC)...       Target_0
# 4   O=C(NC1=CC=CC(OC)=C1)C2=C(C3=CC=C(N(C)C)C=C3)C...       Target_0
# ..                                                ...            ...
# 62   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4  CHEMBL4523458
# 63         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O  CHEMBL4523458
# 64                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3  CHEMBL4523458
# 65  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...  CHEMBL4523458
# 66  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...  CHEMBL4523458
#
#                      pref_name assay_id ChemBL_Assay  \
# 0    TAR RNA-binding protein 2  Assay_0      Assay_0
# 1    TAR RNA-binding protein 2  Assay_0      Assay_0
# 2    TAR RNA-binding protein 2  Assay_0      Assay_0
# 3    TAR RNA-binding protein 2  Assay_0      Assay_0
# 4    TAR RNA-binding protein 2  Assay_0      Assay_0
# ..                         ...      ...          ...
# 62  Protein lin-28 homolog A/B  Assay_3      Assay_3
# 63  Protein lin-28 homolog A/B  Assay_3      Assay_3
# 64  Protein lin-28 homolog A/B  Assay_3      Assay_3
# 65  Protein lin-28 homolog A/B  Assay_3      Assay_3
# 66  Protein lin-28 homolog A/B  Assay_3      Assay_3
#
#                              description standard_value standard_units
# 0    Assay for TAR RNA-binding protein 2
# 1    Assay for TAR RNA-binding protein 2
# 2    Assay for TAR RNA-binding protein 2
# 3    Assay for TAR RNA-binding protein 2
# 4    Assay for TAR RNA-binding protein 2
# ..                                   ...            ...            ...
# 62  Assay for Protein lin-28 homolog A/B
# 63  Assay for Protein lin-28 homolog A/B
# 64  Assay for Protein lin-28 homolog A/B
# 65  Assay for Protein lin-28 homolog A/B
# 66  Assay for Protein lin-28 homolog A/B
#
# [67 rows x 14 columns]
#
#      component_synonym            chembl_id       synonyms syn_type  \
# 0               ELAVL1        CHEMBL1240928            NaN      NaN
# 1               ELAVL1        CHEMBL1240928            NaN      NaN
# 2               ELAVL1        CHEMBL1240928            NaN      NaN
# 3               ELAVL1        CHEMBL1240928            NaN      NaN
# 4               ELAVL1        CHEMBL1240928            NaN      NaN
# ...                ...                  ...            ...      ...
# 1264             LIN28  cellrep201804116_38  CHEMBL4438300
# 1265             LIN28  cellrep201804116_39  CHEMBL4438300
# 1266             LIN28  cellrep201804116_40  CHEMBL4438300
# 1267             LIN28  cellrep201804116_41  CHEMBL4438300
# 1268             LIN28  cellrep201804116_42  CHEMBL4438300
#
#        molecule_type  max_phase  \
# 0     Small molecule        0.0
# 1     Small molecule        0.0
# 2     Small molecule        0.0
# 3     Small molecule        0.0
# 4     Small molecule        0.0
# ...              ...        ...
# 1264  Small Molecule        0.0
# 1265  Small Molecule        0.0
# 1266  Small Molecule        0.0
# 1267  Small Molecule        0.0
# 1268  Small Molecule        0.0
#
#                                        canonical_smiles  CHEMBL_Target  \
# 0                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 1                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 2                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 3                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 4                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# ...                                                 ...            ...
# 1264   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4  CHEMBL4523458
# 1265         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O  CHEMBL4523458
# 1266                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3  CHEMBL4523458
# 1267  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...  CHEMBL4523458
# 1268  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...  CHEMBL4523458
#
#                        pref_name assay_id   ChemBL_Assay  \
# 0            ELAV-like protein 1   654837  CHEMBL1243881
# 1            ELAV-like protein 1   654838  CHEMBL1243882
# 2            ELAV-like protein 1   654841  CHEMBL1243885
# 3            ELAV-like protein 1   654842  CHEMBL1243886
# 4            ELAV-like protein 1   654843  CHEMBL1243887
# ...                          ...      ...            ...
# 1264  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1265  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1266  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1267  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1268  Protein lin-28 homolog A/B  Assay_3        Assay_3
#
#                                             description standard_value  \
# 0     Inhibition of recombinant HuR RRM1/RRM2 domain...          230.0
# 1     Inhibition of recombinant HuR RRM1/RRM2 domain...           14.0
# 2     Inhibition of HuR homodimerization after 24 hr...            NaN
# 3     Inhibition of recombinant full length HuR asse...            NaN
# 4     Binding affinity to HuR after 24 hrs by microd...            NaN
# ...                                                 ...            ...
# 1264               Assay for Protein lin-28 homolog A/B
# 1265               Assay for Protein lin-28 homolog A/B
# 1266               Assay for Protein lin-28 homolog A/B
# 1267               Assay for Protein lin-28 homolog A/B
# 1268               Assay for Protein lin-28 homolog A/B
#
#      standard_units
# 0                nM
# 1                nM
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1264
# 1265
# 1266
# 1267
# 1268
#
# [1269 rows x 14 columns]
# /home/peter/anaconda3/envs/rdkit/lib/python3.7/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mollist = df['canonical_smiles']
print(mollist)
# Out:
# 0                          Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# 1                          Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# 2                          Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# 3                          Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# 4                          Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
#                               ...
# 1264     N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4
# 1265           C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O
# 1266                    c12c(cccn1)cccc2OC(=O)C=C/c3occc3
# 1267    N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...
# 1268    c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...
# Name: canonical_smiles, Length: 1269, dtype: object

# %%
mol =[]
qed =[]
for i in mollist:
    #print(i)
    mt = Chem.MolFromSmiles(i)
    qed.append(Chem.QED.default(mt))
    mol.append(mt)
    
#Draw.MolsToGridImage(mol, molsPerRow=4, maxMols = 200)
#print(qed)
df['qed'] = qed
print(df)
# Out:
#      component_synonym            chembl_id       synonyms syn_type  \
# 0               ELAVL1        CHEMBL1240928            NaN      NaN
# 1               ELAVL1        CHEMBL1240928            NaN      NaN
# 2               ELAVL1        CHEMBL1240928            NaN      NaN
# 3               ELAVL1        CHEMBL1240928            NaN      NaN
# 4               ELAVL1        CHEMBL1240928            NaN      NaN
# ...                ...                  ...            ...      ...
# 1264             LIN28  cellrep201804116_38  CHEMBL4438300
# 1265             LIN28  cellrep201804116_39  CHEMBL4438300
# 1266             LIN28  cellrep201804116_40  CHEMBL4438300
# 1267             LIN28  cellrep201804116_41  CHEMBL4438300
# 1268             LIN28  cellrep201804116_42  CHEMBL4438300
#
#        molecule_type  max_phase  \
# 0     Small molecule        0.0
# 1     Small molecule        0.0
# 2     Small molecule        0.0
# 3     Small molecule        0.0
# 4     Small molecule        0.0
# ...              ...        ...
# 1264  Small Molecule        0.0
# 1265  Small Molecule        0.0
# 1266  Small Molecule        0.0
# 1267  Small Molecule        0.0
# 1268  Small Molecule        0.0
#
#                                        canonical_smiles  CHEMBL_Target  \
# 0                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 1                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 2                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 3                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# 4                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2  CHEMBL1250379
# ...                                                 ...            ...
# 1264   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4  CHEMBL4523458
# 1265         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O  CHEMBL4523458
# 1266                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3  CHEMBL4523458
# 1267  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...  CHEMBL4523458
# 1268  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...  CHEMBL4523458
#
#                        pref_name assay_id   ChemBL_Assay  \
# 0            ELAV-like protein 1   654837  CHEMBL1243881
# 1            ELAV-like protein 1   654838  CHEMBL1243882
# 2            ELAV-like protein 1   654841  CHEMBL1243885
# 3            ELAV-like protein 1   654842  CHEMBL1243886
# 4            ELAV-like protein 1   654843  CHEMBL1243887
# ...                          ...      ...            ...
# 1264  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1265  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1266  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1267  Protein lin-28 homolog A/B  Assay_3        Assay_3
# 1268  Protein lin-28 homolog A/B  Assay_3        Assay_3
#
#                                             description standard_value  \
# 0     Inhibition of recombinant HuR RRM1/RRM2 domain...          230.0
# 1     Inhibition of recombinant HuR RRM1/RRM2 domain...           14.0
# 2     Inhibition of HuR homodimerization after 24 hr...            NaN
# 3     Inhibition of recombinant full length HuR asse...            NaN
# 4     Binding affinity to HuR after 24 hrs by microd...            NaN
# ...                                                 ...            ...
# 1264               Assay for Protein lin-28 homolog A/B
# 1265               Assay for Protein lin-28 homolog A/B
# 1266               Assay for Protein lin-28 homolog A/B
# 1267               Assay for Protein lin-28 homolog A/B
# 1268               Assay for Protein lin-28 homolog A/B
#
#      standard_units       qed
# 0                nM  0.580243
# 1                nM  0.580243
# 2               NaN  0.580243
# 3               NaN  0.580243
# 4               NaN  0.580243
# ...             ...       ...
# 1264                 0.363114
# 1265                 0.434190
# 1266                 0.413266
# 1267                 0.801188
# 1268                 0.059805
#
# [1269 rows x 15 columns]

# %%
### Prepare Nodes ###

#print(df)
#print
chemlist = df[['chembl_id','synonyms','canonical_smiles','max_phase','qed']]
print(chemlist)
protlist = df[['CHEMBL_Target', 'component_synonym','pref_name']]
print(protlist)
asslist = df[['ChemBL_Assay', 'assay_id', 'description']]
print(asslist)

# unify Compound List
records = chemlist.to_records(index=False)
result = list(records)
#print(result)

comps = []
j = 0
for i in result:
    #print(i[1], type(i[1]))
    j = j+1
    if type(i[1]) == float:
        i[1] = ''
        #print('Convert :', i[1])
    if j % 1000 == 0:
        print(j, "Compound Rows - intake ",len(comps))
    if i not in comps:
        comps.append(i)

#print(compounds)
print(len(comps))
#print

compounds = []
cochem = []
codesc = {}

for i in comps:
    #print(i)
    
    if i[0] not in cochem:
        cochem.append(i[0])
        codesc[i[0]] = i[1]
        compounds.append(i)
    else:
        codesc[i[0]] = codesc[i[0]]+'/'+i[1]
        
#print(len(compounds))
#for i in compounds:
#    print(i)

#for k,v in codesc.items():
#    print(k, v)
    


# unify Protein List
records = protlist.to_records(index=False)
result = list(records)
#print(result)

proteins = []
for i in result:
    #print(i)
    if i not in proteins:
        proteins.append(i)

#print(proteins)
#print(len(proteins))
#print

# unify Assay List
records = asslist.to_records(index=False)
result = list(records)
#print(result)

assays = []
for i in result:
    #print(i)
    if i not in assays:
        assays.append(i)

#print(assays)
#print(len(assays))


comind = []
for i in compounds:
    comind.append(i[0])

dfc = pd.DataFrame.from_records(compounds, columns =['ChemblID', 'Name', 'Smiles', 'Phase', 'QED'], index = comind)
dfp = pd.DataFrame.from_records(proteins, columns =['ChemblID', 'Name', 'Description'])
dfa = pd.DataFrame.from_records(assays, columns =['ChemblID', 'Name', 'Description'])

dfc['Type'] = 'Small Molecule'
#dfc['Name'] = ''
dfc['Description'] = ''
for k,v in codesc.items():
    if v != '':
        print(k, v)
        dfc.at[k, 'Description'] = v
        l = dfc.loc[k]
        #print(l)

dfc = dfc[['ChemblID', 'Name', 'Description', 'Type', 'Phase', 'QED','Smiles']]

dfp['Type'] = 'Protein'
dfp['Phase'] = 100
dfp['QED'] = -1

dfa['Type'] = 'Assay'
dfa['Phase'] = 200
dfa['QED'] = -2

dfc = dfc[['ChemblID', 'Name', 'Description', 'Type', 'Phase', 'QED','Smiles']]

#print(dfp)
#print(dfa)
print(dfc)

dfno = pd.concat([dfc, dfp, dfa], axis=0)
print(dfno)
# Out:
#                 chembl_id       synonyms  \
# 0           CHEMBL1240928            NaN
# 1           CHEMBL1240928            NaN
# 2           CHEMBL1240928            NaN
# 3           CHEMBL1240928            NaN
# 4           CHEMBL1240928            NaN
# ...                   ...            ...
# 1264  cellrep201804116_38  CHEMBL4438300
# 1265  cellrep201804116_39  CHEMBL4438300
# 1266  cellrep201804116_40  CHEMBL4438300
# 1267  cellrep201804116_41  CHEMBL4438300
# 1268  cellrep201804116_42  CHEMBL4438300
#
#                                        canonical_smiles  max_phase       qed
# 0                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2        0.0  0.580243
# 1                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2        0.0  0.580243
# 2                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2        0.0  0.580243
# 3                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2        0.0  0.580243
# 4                        Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2        0.0  0.580243
# ...                                                 ...        ...       ...
# 1264   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4        0.0  0.363114
# 1265         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O        0.0  0.434190
# 1266                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3        0.0  0.413266
# 1267  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...        0.0  0.801188
# 1268  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...        0.0  0.059805
#
# [1269 rows x 5 columns]
#       CHEMBL_Target component_synonym                   pref_name
# 0     CHEMBL1250379            ELAVL1         ELAV-like protein 1
# 1     CHEMBL1250379            ELAVL1         ELAV-like protein 1
# 2     CHEMBL1250379            ELAVL1         ELAV-like protein 1
# 3     CHEMBL1250379            ELAVL1         ELAV-like protein 1
# 4     CHEMBL1250379            ELAVL1         ELAV-like protein 1
# ...             ...               ...                         ...
# 1264  CHEMBL4523458             LIN28  Protein lin-28 homolog A/B
# 1265  CHEMBL4523458             LIN28  Protein lin-28 homolog A/B
# 1266  CHEMBL4523458             LIN28  Protein lin-28 homolog A/B
# 1267  CHEMBL4523458             LIN28  Protein lin-28 homolog A/B
# 1268  CHEMBL4523458             LIN28  Protein lin-28 homolog A/B
#
# [1269 rows x 3 columns]
#        ChemBL_Assay assay_id  \
# 0     CHEMBL1243881   654837
# 1     CHEMBL1243882   654838
# 2     CHEMBL1243885   654841
# 3     CHEMBL1243886   654842
# 4     CHEMBL1243887   654843
# ...             ...      ...
# 1264        Assay_3  Assay_3
# 1265        Assay_3  Assay_3
# 1266        Assay_3  Assay_3
# 1267        Assay_3  Assay_3
# 1268        Assay_3  Assay_3
#
#                                             description
# 0     Inhibition of recombinant HuR RRM1/RRM2 domain...
# 1     Inhibition of recombinant HuR RRM1/RRM2 domain...
# 2     Inhibition of HuR homodimerization after 24 hr...
# 3     Inhibition of recombinant full length HuR asse...
# 4     Binding affinity to HuR after 24 hrs by microd...
# ...                                                 ...
# 1264               Assay for Protein lin-28 homolog A/B
# 1265               Assay for Protein lin-28 homolog A/B
# 1266               Assay for Protein lin-28 homolog A/B
# 1267               Assay for Protein lin-28 homolog A/B
# 1268               Assay for Protein lin-28 homolog A/B
#
# [1269 rows x 3 columns]
# 1000 Compound Rows - intake  585
# 758
# CHEMBL1240971 Okicenone
# CHEMBL1242196 Dehydromutactin
# CHEMBL227075 Dihydrotanshinone/Dihydrotanshinone I
# CHEMBL50 C.I. Natural Red 1/LDN 0052529/LDN-0052529/Meletin/NSC 57655/NSC-57655/NSC 9219/NSC-9219/Quercetin/Sophoretin/Xanthaurine
# CHEMBL164 NSC-407290
# CHEMBL312163 NSC-19802
# CHEMBL36327 (-)-Epicatechin Gallate/Epicatechin Gallate
# CHEMBL6246 Benzoaric acid/Ellagic acid/NSC-407286/NSC-656272
# CHEMBL441687 E958/Glycyrrhetinic acid/Glycyrrhizic acid/Glycyrrhizic Acid/Glycyrrhizin/Glycyrrhizinic acid/NSC-167409/NSC-234419
# cellrep201804116_33 CHEMBL4438300
# cellrep201804116_34 CHEMBL4438300
# cellrep201804116_35 CHEMBL4438300
# cellrep201804116_36 CHEMBL4438300
# cellrep201804116_37 CHEMBL4438300
# cellrep201804116_38 CHEMBL4438300
# cellrep201804116_39 CHEMBL4438300
# cellrep201804116_40 CHEMBL4438300
# cellrep201804116_41 CHEMBL4438300
# cellrep201804116_42 CHEMBL4438300
#                                 ChemblID             Name      Description  \
# CHEMBL1240928              CHEMBL1240928
# CHEMBL1240971              CHEMBL1240971        Okicenone        Okicenone
# CHEMBL1242196              CHEMBL1242196  Dehydromutactin  Dehydromutactin
# CHEMBL1242197              CHEMBL1242197
# CHEMBL1309685              CHEMBL1309685
# ...                                  ...              ...              ...
# cellrep201804116_38  cellrep201804116_38    CHEMBL4438300    CHEMBL4438300
# cellrep201804116_39  cellrep201804116_39    CHEMBL4438300    CHEMBL4438300
# cellrep201804116_40  cellrep201804116_40    CHEMBL4438300    CHEMBL4438300
# cellrep201804116_41  cellrep201804116_41    CHEMBL4438300    CHEMBL4438300
# cellrep201804116_42  cellrep201804116_42    CHEMBL4438300    CHEMBL4438300
#
#                                Type  Phase       QED  \
# CHEMBL1240928        Small Molecule    0.0  0.580243
# CHEMBL1240971        Small Molecule    0.0  0.678314
# CHEMBL1242196        Small Molecule    0.0  0.638832
# CHEMBL1242197        Small Molecule    0.0  0.750904
# CHEMBL1309685        Small Molecule    0.0  0.299524
# ...                             ...    ...       ...
# cellrep201804116_38  Small Molecule    0.0  0.363114
# cellrep201804116_39  Small Molecule    0.0  0.434190
# cellrep201804116_40  Small Molecule    0.0  0.413266
# cellrep201804116_41  Small Molecule    0.0  0.801188
# cellrep201804116_42  Small Molecule    0.0  0.059805
#
#                                                                 Smiles
# CHEMBL1240928                           Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# CHEMBL1240971                       Cc1cc(O)cc2cc3c(c(O)c12)C(=O)CCC3O
# CHEMBL1242196                    Cc1cc(O)c2c(O)cccc2c1-c1cc(=O)cc(O)o1
# CHEMBL1242197                 Cc1cc(O)cc2oc(Cc3cc(O)cc(=O)o3)cc(=O)c12
# CHEMBL1309685        COc1cc(OC)c2c(-c3ccccc3)cc(=O)oc2c1C(CC(=O)N1C...
# ...                                                                ...
# cellrep201804116_38   N(Cc1ncccc1)(Cc2ccccn2)CCN(Cc(nccc3)c3)Cc4ncccc4
# cellrep201804116_39         C1(O)=C(c2ccc(O)c(O)c2)Oc(cc(cc3O)O)c3C1=O
# cellrep201804116_40                  c12c(cccn1)cccc2OC(=O)C=C/c3occc3
# cellrep201804116_41  N1[C@@H](c(cc2)ccc2C(O)=O)[C@@]([H])(CC=C3)[C@...
# cellrep201804116_42  c1(c2N)c(c(cc2S(=O)(=O)[O-])Nc(ccc(c3S(=O)(=O)...
#
# [651 rows x 7 columns]
#                     ChemblID             Name  \
# CHEMBL1240928  CHEMBL1240928
# CHEMBL1240971  CHEMBL1240971        Okicenone
# CHEMBL1242196  CHEMBL1242196  Dehydromutactin
# CHEMBL1242197  CHEMBL1242197
# CHEMBL1309685  CHEMBL1309685
# ...                      ...              ...
# 159            CHEMBL4197665          1762418
# 160                  Assay_0          Assay_0
# 161                  Assay_1          Assay_1
# 162                  Assay_2          Assay_2
# 163                  Assay_3          Assay_3
#
#                                                      Description  \
# CHEMBL1240928
# CHEMBL1240971                                          Okicenone
# CHEMBL1242196                                    Dehydromutactin
# CHEMBL1242197
# CHEMBL1309685
# ...                                                          ...
# 159            Displacement of [3H]naltrindole from DOR in mo...
# 160                          Assay for TAR RNA-binding protein 2
# 161                     Assay for Survival motor neuron protein
# 162                            Assay for poly(A)polymerase PAPD5
# 163                         Assay for Protein lin-28 homolog A/B
#
#                          Type  Phase       QED  \
# CHEMBL1240928  Small Molecule    0.0  0.580243
# CHEMBL1240971  Small Molecule    0.0  0.678314
# CHEMBL1242196  Small Molecule    0.0  0.638832
# CHEMBL1242197  Small Molecule    0.0  0.750904
# CHEMBL1309685  Small Molecule    0.0  0.299524
# ...                       ...    ...       ...
# 159                     Assay  200.0 -2.000000
# 160                     Assay  200.0 -2.000000
# 161                     Assay  200.0 -2.000000
# 162                     Assay  200.0 -2.000000
# 163                     Assay  200.0 -2.000000
#
#                                                           Smiles
# CHEMBL1240928                     Cc1occ2c1C(=O)c1c(O)ccc(O)c1C2
# CHEMBL1240971                 Cc1cc(O)cc2cc3c(c(O)c12)C(=O)CCC3O
# CHEMBL1242196              Cc1cc(O)c2c(O)cccc2c1-c1cc(=O)cc(O)o1
# CHEMBL1242197           Cc1cc(O)cc2oc(Cc3cc(O)cc(=O)o3)cc(=O)c12
# CHEMBL1309685  COc1cc(OC)c2c(-c3ccccc3)cc(=O)oc2c1C(CC(=O)N1C...
# ...                                                          ...
# 159                                                          NaN
# 160                                                          NaN
# 161                                                          NaN
# 162                                                          NaN
# 163                                                          NaN
#
# [841 rows x 7 columns]

# %%
dfno.to_csv('../Chembl_RBP_Nodes.csv', index=False)

# %%
# Preparing Edges #
#print(df)

ca = df[['chembl_id', 'ChemBL_Assay']]
at = df[['CHEMBL_Target', 'ChemBL_Assay']]

# unify Compound-Assay List
records = ca.to_records(index=False)
result = list(records)
#print(result)

compass = []
for i in result:
    #print(i)
    if i not in compass:
        compass.append(i)

print(compass)
print(len(compass))

# unify Compound-Target List
records = at.to_records(index=False)
result = list(records)
#print(result)

targass = []
for i in result:
    #print(i)
    if i not in targass:
        targass.append(i)

print(targass)
print(len(targass))
# Out:
# [('CHEMBL1240928', 'CHEMBL1243881'), ('CHEMBL1240928', 'CHEMBL1243882'), ('CHEMBL1240928', 'CHEMBL1243885'), ('CHEMBL1240928', 'CHEMBL1243886'), ('CHEMBL1240928', 'CHEMBL1243887'), ('CHEMBL1240928', 'CHEMBL1243895'), ('CHEMBL1240928', 'CHEMBL1243896'), ('CHEMBL1240928', 'CHEMBL1243899'), ('CHEMBL1240928', 'CHEMBL1243902'), ('CHE
CHEMBL4150506'), ('CHEMBL4295897', 'CHEMBL4150508'), ('CHEMBL4295897', 'CHEMBL4150509'), ('CHEMBL4295897', 'CHEMBL4150510'), ('CHEMBL4523458', 'CHEMBL4329767'), ('CHEMBL4523458', 'CHEMBL4329769'), ('CHEMBL4523458', 'CHEMBL4329770'), ('CHEMBL4523458', 'CHEMBL4329771'), ('CHEMBL4523458', 'CHEMBL4329773'), ('CHEMBL4523458', 'CHEMBL4329774'), ('CHEMBL4523458', 'CHEMBL4329776'), ('CHEMBL4523458', 'CHEMBL4329777'), ('CHEMBL4523458', 'CHEMBL4329792'), ('CHEMBL4523458', 'CHEMBL4329793'), ('CHEMBL4523458', 'CHEMBL4329794'), ('CHEMBL4523458', 'CHEMBL4329806'), ('CHEMBL4523458', 'CHEMBL4329807'), ('CHEMBL4523458', 'CHEMBL4329808'), ('CHEMBL4523458', 'CHEMBL4329809'), ('CHEMBL4523614', 'CHEMBL4329779'), ('CHEMBL4523614', 'CHEMBL4329780'), ('CHEMBL4523614', 'CHEMBL4329781'), ('CHEMBL4523614', 'CHEMBL4329782'), ('CHEMBL4523614', 'CHEMBL4329783'), ('CHEMBL4523614', 'CHEMBL4329784'), ('CHEMBL4523614', 'CHEMBL4329795'), ('CHEMBL4523614', 'CHEMBL4329796'), ('CHEMBL4523614', 'CHEMBL4329797'), ('CHEMBL4523614', 'CHEMBL4329801'), ('CHEMBL4523614', 'CHEMBL4329802'), ('CHEMBL4523614', 'CHEMBL4329803'), ('CHEMBL4523614', 'CHEMBL4329804'), ('CHEMBL4523614', 'CHEMBL4329805'), ('C ...
# 164

# %%
#print(compounds)

mol = []
rcl = []

for i in compounds:
    #print(i[0],i[1])
    #print(i[1])
    #if i[1] != 'Protein':
    rcl.append((i[0], i[2]))
    mt = Chem.MolFromSmiles(i[2])
    mol.append(mt)
    #else:
    #    print('Fail',i)

print(rcl)
#Draw.MolsToGridImage(mol, molsPerRow=4, maxMols = 200)

### calculate distance as Eucledian distance as network preparation ###
nmol = len(mol)
print(nmol)
#fps = [Chem.RDKFingerprint(i) for i in mol]
fps = [AllChem.GetMorganFingerprintAsBitVect(i,3,nBits=2048,useFeatures=True) for i in mol]
tmd = []
for i in range(0, nmol-1):
    for j in range(i+1, nmol):
        td = DataStructs.FingerprintSimilarity(fps[i],fps[j])        
        if td >= 0.7:
            #print(r[i][0],r[j][0],td)
            tani = 10*td
            dd = 10*DataStructs.FingerprintSimilarity(fps[i],fps[j], metric=DataStructs.DiceSimilarity)
            k = (rcl[i][0],"cc",rcl[j][0],td,tani,dd)
            #print(k)
            tmd.append(k)
        #else:
            #print(rcl[i][0],rcl[j][0],'No Connect')
            
print(len(tmd))
print(tmd)
# Out:
EMBL1398194', 'cc', 'CHEMBL1603147', 0.7375, 7.375, 8.489208633093526), ('CHEMBL1499653', 'cc', 'CHEMBL1522581', 0.8857142857142857, 8.857142857142858, 9.393939393939394), ('CHEMBL1499653', 'cc', 'CHEMBL1422657', 0.9852941176470589, 9.852941176470589, 9.925925925925926), ('CHEMBL1499653', 'cc', 'CHEMBL1603147', 0.8783783783783784, 8.783783783783784, 9.35251798561151), ('CHEMBL1522581', 'cc', 'CHEMBL1422657', 0.8732394366197183, 8.732394366197182, 9.32330827067669), ('CHEMBL1522581', 'cc', 'CHEMBL1603147', 0.8513513513513513, 8.513513513513512, 9.197080291970803), ('CHEMBL4064932', 'cc', 'CHEMBL4078539', 0.7681159420289855, 7.6811594202898545, 8.688524590163935), ('CHEMBL4064932', 'cc', 'CHEMBL4086397', 0.8983050847457628, 8.983050847457628, 9.464285714285714), ('CHEMBL4067653', 'cc', 'CHEMBL4095060', 0.7205882352941176, 7.205882352941177, 8.376068376068377), ('CHEMBL4067653', 'cc', 'CHEMBL4102819', 0.8032786885245902, 8.032786885245901, 8.909090909090908), ('CHEMBL4075458', 'cc', 'CHEMBL4075620', 0.7758620689655172, 7.758620689655173, 8.737864077669903), ('CHEMBL4075458', 'cc', 'CHEMBL4075916', 0.7758620689655172, 7.758620689655173, 8.737864077669903), ('CHEMBL4075458', 'cc', 'CHEMBL4076484', 0.8518518518518519, 8.518518518518519, 9.200000000000001), ('CHEMBL4075458', 'cc', 'CHEMBL4077265', 0.8181818181818182, 8.181818181818182, 9.0), ('CHEMBL4075458', 'cc', 'CHEMBL4081086', 0.7377049180327869, 7.3770491803278695, 8.49056603773585), ('CHEMBL4075458', 'cc', 'CHEMBL4084798', 0.8113207547169812, 8.11320754716981, 8.958333333333334), ('CHEMBL4075458', 'cc', 'CHEMBL4092808', 0.7894736842105263, 7.894736842105264, 8.823529411764707), ('CHEMBL4075458', 'cc', 'CHEMBL4094161', 0.75, 7.5, 8.571428571428571), ('CHEMBL4075458', 'cc', 'CHEMBL4100171', 0.8181818181818182, 8.181818181818182, 9.0), ('CHEMBL4075620', 'cc', 'CHEMBL4076484', 0.7580645161290323, 7.580645161290322, 8.623853211009175), ('CHEMBL4075620', 'cc', 'CHEMBL4077265', 0.8166666666666667, 8.166666666666666, 8.990825688073395), ('CHEMBL4075916', 'cc', 'CHEMBL4081086', 0.8253968253968254, 8.253968253968253, 9.043478260869565), ('CHEMBL4075916', 'cc', 'CHEMBL4100171', 0.703125, 7.03125,  ...

# %%
##### Compound Assay Target Network #####

dfcc = pd.DataFrame.from_records(tmd, columns =['source', 'interaction', 'target', 'weight', 'tani','dice'])
print(dfcc)

dfca = pd.DataFrame.from_records(compass, columns =['source', 'target'])
dfca['interaction'] = 'ca'
w = 2
dfca['weight'] = w
dfca['tani'] = w
dfca['dice'] = w
dfca = dfca[['source', 'interaction', 'target', 'weight','tani','dice']]
print(dfca)

dfta = pd.DataFrame.from_records(targass, columns =['source', 'target'])
dfta['interaction'] = 'ta'
w = 5
dfta['weight'] = w
dfta['tani'] = w
dfta['dice'] = w
dfta = dfta[['source', 'interaction', 'target', 'weight', 'tani', 'dice']]
print(dfta)

dfeo = pd.concat([dfcc, dfca, dfta], axis=0)
print(dfeo)

dfeo.to_csv('../Chembl_RBP_Edges.csv', index=False)
# Out:
#                   source interaction               target    weight      tani  \
# 0          CHEMBL1309685          cc        CHEMBL1330249  0.728395  7.283951
# 1          CHEMBL1309685          cc        CHEMBL1398194  0.820513  8.205128
# 2          CHEMBL1309685          cc        CHEMBL1499653  0.797468  7.974684
# 3          CHEMBL1309685          cc        CHEMBL1522581  0.707317  7.073171
# 4          CHEMBL1309685          cc        CHEMBL1422657  0.787500  7.875000
# ..                   ...         ...                  ...       ...       ...
# 864         jm1c00018_18          cc         jm1c00018_19  0.844828  8.448276
# 865         jm1c00018_18          cc         jm1c00018_20  0.824561  8.245614
# 866         jm1c00018_19          cc         jm1c00018_20  0.754098  7.540984
# 867        CHEMBL4290141          cc       nchembio1837_1  0.736111  7.361111
# 868  cellrep201804116_16          cc  cellrep201804116_30  0.802817  8.028169
#
#          dice
# 0    8.428571
# 1    9.014085
# 2    8.873239
# 3    8.285714
# 4    8.811189
# ..        ...
# 864  9.158879
# 865  9.038462
# 866  8.598131
# 867  8.480000
# 868  8.906250
#
# [869 rows x 6 columns]
#                   source interaction         target  weight  tani  dice
# 0          CHEMBL1240928          ca  CHEMBL1243881       2     2     2
# 1          CHEMBL1240928          ca  CHEMBL1243882       2     2     2
# 2          CHEMBL1240928          ca  CHEMBL1243885       2     2     2
# 3          CHEMBL1240928          ca  CHEMBL1243886       2     2     2
# 4          CHEMBL1240928          ca  CHEMBL1243887       2     2     2
# ..                   ...         ...            ...     ...   ...   ...
# 953  cellrep201804116_38          ca        Assay_3       2     2     2
# 954  cellrep201804116_39          ca        Assay_3       2     2     2
# 955  cellrep201804116_40          ca        Assay_3       2     2     2
# 956  cellrep201804116_41          ca        Assay_3       2     2     2
# 957  cellrep201804116_42          ca        Assay_3       2     2     2
#
# [958 rows x 6 columns]
#             source interaction         target  weight  tani  dice
# 0    CHEMBL1250379          ta  CHEMBL1243881       5     5     5
# 1    CHEMBL1250379          ta  CHEMBL1243882       5     5     5
# 2    CHEMBL1250379          ta  CHEMBL1243885       5     5     5
# 3    CHEMBL1250379          ta  CHEMBL1243886       5     5     5
# 4    CHEMBL1250379          ta  CHEMBL1243887       5     5     5
# ..             ...         ...            ...     ...   ...   ...
# 159  CHEMBL4295544          ta  CHEMBL4197665       5     5     5
# 160       Target_0          ta        Assay_0       5     5     5
# 161  CHEMBL1293232          ta        Assay_1       5     5     5
# 162       Target_2          ta        Assay_2       5     5     5
# 163  CHEMBL4523458          ta        Assay_3       5     5     5
#
# [164 rows x 6 columns]
#             source interaction         target    weight      tani      dice
# 0    CHEMBL1309685          cc  CHEMBL1330249  0.728395  7.283951  8.428571
# 1    CHEMBL1309685          cc  CHEMBL1398194  0.820513  8.205128  9.014085
# 2    CHEMBL1309685          cc  CHEMBL1499653  0.797468  7.974684  8.873239
# 3    CHEMBL1309685          cc  CHEMBL1522581  0.707317  7.073171  8.285714
# 4    CHEMBL1309685          cc  CHEMBL1422657  0.787500  7.875000  8.811189
# ..             ...         ...            ...       ...       ...       ...
# 159  CHEMBL4295544          ta  CHEMBL4197665  5.000000  5.000000  5.000000
# 160       Target_0          ta        Assay_0  5.000000  5.000000  5.000000
# 161  CHEMBL1293232          ta        Assay_1  5.000000  5.000000  5.000000
# 162       Target_2          ta        Assay_2  5.000000  5.000000  5.000000
# 163  CHEMBL4523458          ta        Assay_3  5.000000  5.000000  5.000000
#
# [1991 rows x 6 columns]

# %%
#print(df)
ct = df[['chembl_id', 'CHEMBL_Target']]

# unify Compound-Target List
records = ct.to_records(index=False)
result = list(records)
#print(result)

comtar = []
for i in result:
    #print(i)
    if i not in comtar:
        comtar.append(i)

print(comtar)
print(len(comtar))
# Out:
# [('CHEMBL1240928', 'CHEMBL1250379'), ('CHEMBL1240971', 'CHEMBL1250379'), ('CHEMBL1242196', 'CHEMBL1250379'), ('CHEMBL1242197', 'CHEMBL1250379'), ('CHEMBL1309685', 'CHEMBL1250379'), ('CHEMBL1330249', 'CHEMBL1250379'), ('CHEMBL1390568', 'CHEMBL1250379'), ('CHEMBL1398194', 'CHEMBL1250379'), ('CHEMBL1483840', 'CHEMBL1250379'), ('CHEMBL1499653', 'CHEMBL1250379'), ('CHEMBL1506938', 'CHEMBL1250379'), ('CHEMBL1522581', 'CHEMBL1250379'), ('CHEMBL227075', 'CHEMBL1250379'), ('CHEMBL4061748', 'CHEMBL1250379'), ('CHEMBL4064932', 'CHEMBL1250379'), ('CHEMBL4066821', 'CHEMBL1250379'), ('CHEMBL4067653', 'CHEMBL1250379'), ('CHEMBL4070465', 'CHEMBL1250379'), ('CHEMBL4073526', 'CHEMBL1250379'), ('CHEMBL4073683', 'CHEMBL1250379'), ('CHEMBL4075458', 'CHEMBL1250379'), ('CHEMBL4075620', 'CHEMBL1250379'), ('CHEMBL4075916', 'CHEMBL1250379'), ('CHEMBL4076484', 'CHEMBL1250379'), ('CHEMBL4077265', 'CHEMBL1250379'), ('CHEMBL4077803', 'CHEMBL1250379'), ('CHEMBL4078539', 'CHEMBL1250379'), ('CHEMBL4081086', 'CHEMBL1250379'), ('CHEMBL4084798', 'CHEMBL1250379'), ('CHEMBL4086397', 'CHEMBL1250379'), ('CHEMBL4092808', 'CHEMBL1250379'), ('CHEMBL4094161', 'CHEMBL1250379'), ('CHEMBL4095060', 'CHEMBL1250379'), ('CHEMBL4095140', 'CHEMBL1250379'), ('CHEMBL4100171', 'CHEMBL1250379'), ('CHEMBL4102819', 'CHEMBL1250379'), ('CHEMBL4105230', 'CHEMBL1250379'), ('CHEMBL4438101', 'CHEMBL1250379'), ('CHEMBL4445686', 'CHEMBL1250379'), ('CHEMBL4483423', 'CHEMBL1250379'), ('CHE
'), ('CHEMBL4098717', 'CHEMBL2311237'), ('CHEMBL4104021', 'CHEMBL2311237'), ('CHEMBL441687', 'CHEMBL2311237'), ('CHEMBL1801580', 'CHEMBL2311236'), ('CHEMBL1801668', 'CHEMBL2311236'), ('CHEMBL34259', 'CHEMBL2311236'), ('CHEMBL3623084', 'CHEMBL2311236'), ('CHEMBL4068995', 'CHEMBL2311236'), ('CHEMBL4069215', 'CHEMBL2311236'), ('CHEMBL4129393', 'CHEMBL2311236'), ('CHEMBL4176821', 'CHEMBL231 ...
# 664

# %%
##### Compound Target Network Only #####

dfct = pd.DataFrame.from_records(comtar, columns =['source', 'target'])
dfct['interaction'] = 'ct'
w = 3
dfct['weight'] = w
dfct['tani'] = w
dfct['dice'] = w
dfct = dfct[['source', 'interaction', 'target', 'weight', 'tani', 'dice']]
print(dfct)

dfeo = pd.concat([dfcc, dfct], axis=0)
print(dfeo)

dfeo.to_csv('../Chembl_RBP_Edge2.csv', index=False)
# Out:
#                   source interaction         target  weight  tani  dice
# 0          CHEMBL1240928          ct  CHEMBL1250379       3     3     3
# 1          CHEMBL1240971          ct  CHEMBL1250379       3     3     3
# 2          CHEMBL1242196          ct  CHEMBL1250379       3     3     3
# 3          CHEMBL1242197          ct  CHEMBL1250379       3     3     3
# 4          CHEMBL1309685          ct  CHEMBL1250379       3     3     3
# ..                   ...         ...            ...     ...   ...   ...
# 659  cellrep201804116_38          ct  CHEMBL4523458       3     3     3
# 660  cellrep201804116_39          ct  CHEMBL4523458       3     3     3
# 661  cellrep201804116_40          ct  CHEMBL4523458       3     3     3
# 662  cellrep201804116_41          ct  CHEMBL4523458       3     3     3
# 663  cellrep201804116_42          ct  CHEMBL4523458       3     3     3
#
# [664 rows x 6 columns]
#                   source interaction         target    weight      tani  \
# 0          CHEMBL1309685          cc  CHEMBL1330249  0.728395  7.283951
# 1          CHEMBL1309685          cc  CHEMBL1398194  0.820513  8.205128
# 2          CHEMBL1309685          cc  CHEMBL1499653  0.797468  7.974684
# 3          CHEMBL1309685          cc  CHEMBL1522581  0.707317  7.073171
# 4          CHEMBL1309685          cc  CHEMBL1422657  0.787500  7.875000
# ..                   ...         ...            ...       ...       ...
# 659  cellrep201804116_38          ct  CHEMBL4523458  3.000000  3.000000
# 660  cellrep201804116_39          ct  CHEMBL4523458  3.000000  3.000000
# 661  cellrep201804116_40          ct  CHEMBL4523458  3.000000  3.000000
# 662  cellrep201804116_41          ct  CHEMBL4523458  3.000000  3.000000
# 663  cellrep201804116_42          ct  CHEMBL4523458  3.000000  3.000000
#
#          dice
# 0    8.428571
# 1    9.014085
# 2    8.873239
# 3    8.285714
# 4    8.811189
# ..        ...
# 659  3.000000
# 660  3.000000
# 661  3.000000
# 662  3.000000
# 663  3.000000
#
# [1533 rows x 6 columns]

# %%
##### Calculate Cluster Cutoff #####

wcss = []
#print(fps)
a = int(nmol/2)+1
b = int(nmol/5)+1
i = b
ki = 100*nmol
cmol = 10*nmol

#for i in range(b, a):
while ki > cmol and i < a:
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=100, n_init=5, random_state=0)
    kmeans.fit(fps)
    print('Run ',i-b+1,' : ',i,' clusters of ',a,' - ',kmeans.inertia_,'/',cmol)
    wcss.append(kmeans.inertia_)
    i = i+1
    #if kmeans.inertia_ > 10*nmol:
    cut_off = i
    ki = kmeans.inertia_

#cut_off = cut_off +1        
        
plt.plot(range(b, i), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

#print(cut_off, wcss)

#print(fps)
#import math

#cut_off = 201
cut_off = cut_off-1
minit=int(math.sqrt(nmol)+1)
miter=int(nmol/2)
print('Clustering start')
kmeans = KMeans(n_clusters=cut_off, init='k-means++', max_iter=miter, n_init=minit, random_state=0)
kmeans.fit(fps)

print(cut_off, minit, kmeans.inertia_, kmeans.n_iter_)
print()
print(kmeans.labels_)

##### Calculate Initial PCA #####

from sklearn.decomposition import PCA

#kmc = kmeans.cluster_centers_

pca = PCA(n_components=3)

pca.fit(fps)

#kpca = pca.transform(kmc)
spca = pca.transform(fps)

print(pca.n_components_, pca.n_features_)
print(pca.explained_variance_)
print(pca.components_)

#kpcadf = pd.DataFrame(data = kpca
#             , columns = ['principal component 1', 'principal component 2', 'principal component 3'])

#print(kpca)
figdim = 15
plt.figure(figsize=(figdim,figdim))
#plt.scatter(kpca[:,0], kpca[:,1], c= 'r', s = 100)
plt.scatter(spca[:,0], spca[:,1], c= 'b', s = 10)
# Out:
# Run  1  :  131  clusters of  326  -  9122.62262478879 / 6510
# Run  2  :  132  clusters of  326  -  9153.323514862324 / 6510
# Run  3  :  133  clusters of  326  -  9012.071422531719 / 6510
# Run  4  :  134  clusters of  326  -  8987.627170715474 / 6510
# Run  5  :  135  clusters of  326  -  8981.829972068872 / 6510
# Run  6  :  136  clusters of  326  -  8932.532093564647 / 6510
# Run  7  :  137  clusters of  326  -  8880.48295119913 / 6510
# Run  8  :  138  clusters of  326  -  8884.821144720434 / 6510
# Run  9  :  139  clusters of  326  -  8815.114790139341 / 6510
# Run  10  :  140  clusters of  326  -  8732.3015829924 / 6510
# Run  11  :  141  clusters of  326  -  8631.454829892327 / 6510
# Run  12  :  142  clusters of  326  -  8796.053377178383 / 6510
# Run  13  :  143  clusters of  326  -  8531.310556110553 / 6510
# Run  14  :  144  clusters of  326  -  8641.382490523083 / 6510
# Run  15  :  145  clusters of  326  -  8437.711823888669 / 6510
# Run  16  :  146  clusters of  326  -  8457.627605053187 / 6510
# Run  17  :  147  clusters of  326  -  8398.803312366801 / 6510
# Run  18  :  148  clusters of  326  -  8364.797535226215 / 6510
# Run  19  :  149  clusters of  326  -  8340.003056884627 / 6510
# Run  20  :  150  clusters of  326  -  8257.193445165953 / 6510
# Run  21  :  151  clusters of  326  -  8171.66128348776 / 6510
# Run  22  :  152  clusters of  326  -  8219.784632034623 / 6510
# Run  23  :  153  clusters of  326  -  8181.20129870129 / 6510
