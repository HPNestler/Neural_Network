# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

from rdkit import Chem, rdBase
from rdkit.Chem import Draw,rdDepictor
from rdkit.Chem import AllChem, Descriptors, DataStructs
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D
from rdkit.Chem.Scaffolds import rdScaffoldNetwork
#from datetime import datetime
#import glob
#import matplotlib as mpl
#from matplotlib import pyplot as plt
#from matplotlib import image as mpimg
import ipyplot
#import os
#import pyvis
#from pyvis.network import Network
#import inspect
#from collections import defaultdict


# def net_match(ms, fp, fp_list, net, probe):
#    for i in range(0, ms):
#        for j in range(0,ms):
#            v = 0
#            for k in range(0, fp):
#                # print(i,j,k)
#                p = probe[k]
#                n = net[i][j][k][0]
#                s = net[i][j][k][1]
#                if s == 0:
#                    s = fp_list[k][1]
#                # d = math.sqrt((p-n)**2)
#               d = 1/(2*math.pi*pow(s,2)) * math.exp(-(pow(p-n,2))/(2*pow(s,2)))
#                v = v + d
#                # if p == n:
#                #    print(i,j,p,n,s,d,v)
#             
#            fit[i][j] = v
#    
#   return fit

#def net_learn(ms, ind, pr, net_mol, net):
#    
#    x = ind[0]
#    y = ind[1]
#    ma = int((ms-1)/2)
#    l = len(net_mol[ind])
#    for i in range(0, fp):        
#        n = net[x][y][i][0]
#        a = ((l-1)*n+pr[i])/l
#        # print('Net FP : ',i, n, pr[i], l, a)
#        # print("Adjust")
#        net[x][y][i][0] = a
#        for j in range(-ma, ma):
#            for k in range(-ma,ma):
#                x1 = (x+j+1 % ms)-1
#                if x1 < 0:
#                    x1 = x1 + ms
#                if x1 == ms:
#                    x1 = 0
#                y1 = (y+k+1 % ms)-1
#                if y1 < 0:
#                    y1 = y1 + ms
#                if y1 == ms:
#                    y1 = 0
#                # print(x, j, x1, y, k, y1)
#                
#                s = net[j][k][i][1]
#                if s == 0:
#                    s = .5
#                # d = a/(2*math.pi*pow(s,2)) * (math.exp(-(pow(j,2)))+math.exp(-(pow(k,2))))/(2*pow(s,2))
#                d = 1/4 * (math.exp(-(pow(j,2)))+math.exp(-(pow(k,2))))/(2*pow(s,2))
#                da = d*a
#                
#                if j != 0 or k != 0:
#                    #print(x, j, x1, y, k, y1, a, d)
#                    indn = (x1, y1)
#                    ln = len(net_mol[indn])
#                    if ln == 0:
#                        nc = (net[x1][y1][i][0] + da)/(1+d)
#                    else:
#                        nc = (ln*net[x1][y1][i][0] + da)/(ln+d)
#                    # print('New Cell : ',indn, ln, net[x1][y1][i][0], nc)
#                    net[x1][y1][i][0] = nc
#                    
#    return net

network = 2

# Initiate Global Values
fp_index =[]


# open database connection
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

# Retrieve Structures from Database
cur = db_nn.cursor()
sql = 'SELECT COUNT(*) FROM public."Structures"'
cur.execute(sql)
mol_count = cur.fetchone()
mol_count = mol_count[0]
print('Structures Available : ',mol_count)

ms = int(pow(mol_count, 1/3)+1)
msize = pow(ms,2)
print('Matrix Size : ',ms,' - ',msize)

# Retrieve Network from Database
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
sql = 'SELECT * FROM network."Neurons_2D" WHERE "Network" = '+str(network)
cur.execute(sql)
fl = cur.fetchall()
if len(fl) != 0:
    print('Network Found')
    msn = 0
    for i in fl:
        msn = max(msn, int(i[0]))
        msn = msn+1
        fpn = int(len(fl)/pow(msn,2))
    for i in range(0,fpn):
        j = fl[i][5]
        #print(j)
        fp_index.append(j)
    print('Network Size : ',msn,' - ',pow(msn,2))
    print('Network Fingerprint : ', fpn,' - ', fp_index)
else:
    print('Naive Network')

# get Morgan Fingerprints from database
cur = db_nn.cursor()
#sql = 'SELECT "Fingerprint_ID", "FP_Shannon" FROM public."Fingerprints" WHERE "FP_Type" = 1 ORDER BY "Fingerprint_ID"'
sql = 'SELECT "Fingerprint_ID", "FP_Shannon" FROM public."Fingerprints" \
WHERE "FP_Type" = 1 ORDER BY "FP_Shannon" DESC LIMIT '+str(msize)
cur.execute(sql)
fp_list = cur.fetchall()

fp = len(fp_list) # set depth of Mapping Matrix
print('Fingerprints : ',fp)
# print(fp_list)

# update FingerPrint_Index
for i in fp_list:
    if i[0] not in fp_index:
        fp_index.append(i[0])

print('Fingerprint Index: ',fp_index)
# print(fp_index.index(5))
# print(fp_index.index(10))

fpa = ''
for i in fp_index:
    #fpa.append(i[0])
    fpa = fpa + str(i) +','
fpa = fpa[:-1]
    
print('Fingerprints chosen : ',fpa)

cur = db_nn.cursor()
#sql = 'SELECT sf.* FROM public."Structure_Fingerprint" sf \
#JOIN public."Fingerprints" fp ON sf."FP_ID" = fp."Fingerprint_ID" \
#WHERE fp."FP_Type" = 1'
sql = 'SELECT sf.* FROM public."Structure_Fingerprint" sf \
WHERE sf."FP_ID" in ('+ fpa +')'

cur.execute(sql)
mol_list = cur.fetchall()
# print(mol_list)

mol_fp = collections.defaultdict(list)
mol_net = {}
net_mol = collections.defaultdict(list)

for i in mol_list:
    a = [i[1], i[2]]
    # print(i, i[0], a)
    mol_fp[i[0]].append(a)
    
# print(mol_fp)
print("Molecules : ", len(mol_fp))
l_rate = 1/len(mol_fp)
print('Rate : ',l_rate, 1-l_rate)
    
# promol = [0] * fp
# print(promol)



#ms = 5
ma = int((ms-1)/2)
print(ms, ma)
# fp = 4



fp_probes = {}
for i,j in mol_fp.items():
    #print()
    #print(i,j)
    pr = [0] * fp
    #fp_probes[i] = []
    for k in j:
        a = fp_index.index(k[0])
        pr[a] = k[1]
        
    print('Fingerprint probe : ',i, pr)
    fp_probes[i] = pr
    
#print(fp_probes)
fp_max = np.zeros(fp)
#print(fp_max)
for i,j in fp_probes.items():
    #print('Probe : ',j)
    l = len(j)
    for k in range(0,l):
        fp_max[k] = max(fp_max[k],j[k])
    #print('Pro_m : ',fp_max)
print('FP Max Probe : ',fp_max)

################################################################################

#####     Initiate Network Values
net = np.zeros((ms, ms, fp, 2))

if len(fl) != 0:
    #fp_index = []
    print('Transferring Network Values')

    for i in fl:
        #print(i)
        x = int(i[0])
        y = int(i[1])
        f = i[5]
        s = i[2]
        a = i[3]
        fi = fp_index.index(f)
        print(x,y,f, fi, a, s)
        net[x][y][fi][0] = a
        net[x][y][fi][1] = s
else:
    # generate random floating point values
    print('Random Network Seed')
    from random import seed
    from random import random
    # seed random number generator
    t = int(time.time()*1000)
    # print(t)
    seed(t)

    #print()
    #r = 5000
    for x in range(0,ms):
        for y in range(0, ms):
            for f in range(0,fp):
                #x = int(ms*random())
                #y = int(ms*random())
                #f = int(fp*random())
                # t = int(2*random())
                v = int((fp_max[f]+1)*random())
                # print(x,y,f,t,v)
                net[x][y][f][0] = v

print()                
print(net)


##################################################################################

#####     Initiate Molecule Positions if Available

# a = math.sqrt(4)
# print()
# print(fit)

# probe = [1,3,5,7]
# probe =[]
# for i in range(0,fp):
   # v = int(10*random())
   # probe.append(v)
    
# print()
# print('Probe : ', probe)

###################################################################################

#####      Network Learning Routines

# pi = math.pi
for r in range(0, 200):
    #print()
    print('Iteration : ', r)
    #print()
    # sf = 0
    for i,j in fp_probes.items(): #mol_fp.items():
        #print()
        #print('Probe list : ',i,j)
        #pr = [0] * fp
        #for k in j:
        #    a = fp_index.index(k[0])
        #    pr[a] = k[1]
        pr = j
        #print(i, pr)

        fit = n2d.net_match(ms, fp, fp_list, net, pr)
        
        # print()
        
        pfit = np.zeros((ms,ms))
        
        for fi in range(0, ms):
            for fj in range(0,ms):
                fl = len(net_mol[fi,fj])
                pfit[fi, fj] = fit[fi,fj]/(1 + fl/ms)
                #print(fl)
        
        m = np.max(pfit)
        # sf = sf + m
        # print(i, m)
        ind = np.unravel_index(np.argmax(pfit, axis=None), pfit.shape)
        l = len(net_mol[ind])
        print('Position match : ', i, m, ind,l)
        #print(fit)
        #print(pfit)
        
        # Rebuild NET
        
        # Move Molecule between cells
        indo_fl = 0
        try:
            a = mol_net[i]
            if ind != mol_net[i]:
                indo_fl = 1
                indo = mol_net[i]
                k = net_mol[indo]
                #print('Removal')
                #print('Old net : ',net_mol)
                print('Old position : ',i,indo)
                #print('Prepop : ',k)
                l = k.index(i)
                k.pop(l)
                #print('Postpop : ',k)
                mol_net[i] = ind
                #print('Molposition updated: ',mol_net)
                net_mol[ind].append(i)
                #print('Net updated :',ind, net_mol[ind])
                # Adjust New cell
                x = ind[0]
                y = ind[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[ind])
                
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    a = ((l-1)*n+pr[ii])/l
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    s = 0
                    for jj in net_mol[ind]:
                        sj = (fp_probes[jj][ii]-net[x][y][ii][0])**2
                        s = s+sj
                        #print(jj,fp_probes[jj][ii],net[x][y][ii][0],sj,s)
                    ls = len(net_mol[ind])
                    net[x][y][ii][1] = math.sqrt(s/ls)
                    #print('Deviate : ',net_mol[ind],net[x][y][ii][1], ls)
                        
                        
                # Adjust Old cell
                x = indo[0]
                y = indo[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[indo])
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    #if l > 0:
                    a = ((l+1)*n-l_rate*pr[ii])/(l+1-l_rate)
                    #else:
                    #    a = (n-l_rate*pr[i])/(1-l_rate)
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    s = 0
                    for jj in net_mol[indo]:
                        sj = (fp_probes[jj][ii]-net[x][y][ii][0])**2
                        s = s+sj
                        #print(jj,fp_probes[jj][ii],net[x][y][ii][0],sj,s)
                    ls = len(net_mol[indo])
                    net[x][y][ii][1] = math.sqrt(s/ls)
                    #print('Deviate : ',net_mol[indo],net[x][y][ii][1], ls)
        
        except:
            if indo_fl == 0:
                mol_net[i] = ind
                net_mol[ind].append(i)
                #print('New net match : ',i, ind, net_mol[ind])
                x = ind[0]
                y = ind[1]
                # ma = int((ms-1)/2)
                l = len(net_mol[ind])
                for ii in range(0, fp):        
                    n = net[x][y][ii][0]
                    a = ((l-1)*n+pr[ii])/l
                    # print('Net FP : ',ii, n, pr[ii], l, a)
                    # print("Adjust")
                    net[x][y][ii][0] = a
                    net[x][y][ii][1] = 0 
            
    #lnm =len(net_mol)
    #for i,j in net_mol.items():
    #    print(i, j, len(j))

        net = n2d.net_learn(ms, fp, ind, pr, net_mol, net)
        if indo_fl == 1:
            net = n2d.net_learn(ms, fp, indo, pr, net_mol, net)
    # print('Match Sum : ', sf)
    
    # print(net)

######################################################################################################

#####     Display Network
                    
print()
print('New_net : ',net)

cur = db_nn.cursor()
sql = 'SELECT "Structure_ID", "SMILES" FROM public."Structures"'
cur.execute(sql)
struct_list = cur.fetchall()
# print(struct_list)
struct_dict = {}
for i in struct_list:
    struct_dict[i[0]] = i[1]

print(struct_dict)    


print()
print('Net Elements : ')
for i,j in net_mol.items():
    print(i,j)
    gmol = []
    if len(j) != 0:
        for k in j:
            #print(struct_dict[k])
            s = struct_dict[k]
            m = Chem.MolFromSmiles(s)
            #print(m)
            mw = Chem.Descriptors.MolWt(m)
            # print(mw)
            
            # md = Draw.MolToImage(m)
            gmol.append(Draw.MolToImage(m))
            
            # Draw.MolsToGridImage(gmol, molsPerRow=1)
        ipyplot.plot_images(gmol, max_images = 30, img_width = 150)
            
#print(gmol)
#Draw.MolsToGridImage(gmol, molsPerRow=4)
    
#i = 13
#j = mol_net[i]
#k = net_mol[j]
#print('Removal')
#print(i,j)
#print(k)
#l = k.index(i)
#k.pop(l)
#print(k)

    
#    try:
#        k = j.index(13)
#        j.pop(k)
#    except:
#        k = -1
#    
#print(i, k, j)

#print()
# print(net_mol)
#for i, j in net_mol.items():
#    print(i,j)
# Out:
# Structures Available :  22
# Matrix Size :  3  -  9
# Network Found
# Network Size :  162  -  26244
# Network Fingerprint :  0  -  []
# Fingerprints :  9
# Fingerprint Index:  [27, 42, 9, 8, 25, 11, 40, 33, 35]
# Fingerprints chosen :  27,42,9,8,25,11,40,33,35
# Molecules :  22
# Rate :  0.045454545454545456 0.9545454545454546
# 3 1
# Fingerprint probe :  10 [0, 0, 1, 1, 0, 1, 0, 0, 0]
# Fingerprint probe :  11 [0, 0, 1, 1, 0, 1, 0, 0, 0]
# Fingerprint probe :  13 [0, 0, 2, 1, 0, 2, 0, 0, 0]
# Fingerprint probe :  14 [0, 0, 2, 0, 0, 0, 0, 0, 0]
# Fingerprint probe :  15 [0, 0, 2, 2, 0, 2, 0, 0, 0]
# Fingerprint probe :  16 [0, 0, 2, 2, 0, 2, 0, 0, 0]
# Fingerprint probe :  17 [6, 0, 0, 0, 6, 0, 0, 0, 0]
# Fingerprint probe :  18 [5, 0, 0, 0, 3, 0, 0, 1, 2]
# Fingerprint probe :  19 [5, 1, 1, 0, 3, 0, 2, 0, 0]
# Fingerprint probe :  20 [4, 1, 1, 0, 0, 0, 2, 1, 2]
# Fingerprint probe :  21 [4, 1, 1, 0, 1, 0, 1, 1, 1]
# Fingerprint probe :  22 [3, 2, 1, 0, 0, 0, 1, 1, 1]
# Fingerprint probe :  23 [2, 3, 1, 0, 0, 0, 0, 1, 0]
# Fingerprint probe :  24 [0, 0, 2, 2, 0, 2, 0, 0, 0]
# Fingerprint probe :  34 [0, 0, 2, 2, 0, 2, 0, 0, 0]
# Fingerprint probe :  35 [0, 0, 2, 1, 0, 1, 0, 0, 0]
# Fingerprint probe :  36 [0, 0, 2, 2, 0, 2, 0, 0, 0]
# Fingerprint probe :  37 [0, 0, 2, 1, 0, 1, 0, 0, 0]
# Fingerprint probe :  38 [0, 0, 2, 3, 0, 2, 0, 0, 0]
# Fingerprint probe :  41 [8, 6, 0, 0, 3, 0, 4, 2, 0]
# Fingerprint probe :  40 [7, 5, 3, 0, 1, 0, 4, 0, 0]
# Fingerprint probe :  39 [6, 7, 0, 0, 2, 0, 4, 0, 0]
# FP Max Probe :  [8. 7. 3. 3. 6. 2. 4. 2. 2.]
# Transferring Network Values
# 0 1 42 1 0.2970297018046045 0.0
# 0 1 42 1 0.2970297018046045 0.0
# 0 1 9 2 1.5328170390033173 0.0
# 0 1 9 2 1.5328170390033173 0.0
# 0 1 25 4 0.022159863014916705 0.0
# 0 1 25 4 0.022159863014916705 0.0
# 0 1 40 6 0.12225786737277469 0.0
# 0 1 40 6 0.12225786737277469 0.0
# 0 1 33 7 0.3190013015094225 0.0
# 0 1 33 7 0.3190013015094225 0.0
# 0 1 35 8 0.14958067892988838 0.0
# 0 1 35 8 0.14958067892988838 0.0
# 0 2 27 0 0.43184736796755535 1.2686689862008962
# 0 2 27 0 0.43184736796755535 1.2686689862008962
# 0 2 42 1 0.2970297018046044 0.879522757214471
# 0 2 42 1 0.2970297018046044 0.879522757214471
# 0 2 9 2 1.5328170390033176 0.47434570757545125
# 0 2 9 2 1.5328170390033176 0.47434570757545125
# 0 2 8 3 0.40837149928416977 1.066723829755173
# 0 2 8 3 0.40837149928416977 1.066723829755173
# 0 2 25 4 0.02215986301491671 0.015773505999599417
# 0 2 25 4 0.02215986301491671 0.015773505999599417
# 0 2 11 5 0.48725521063345784 0.966223911534873
# 0 2 11 5 0.48725521063345784 0.966223911534873
# 0 2 40 6 0.12225786737277465 0.5416064715675486
# 0 2 40 6 0.12225786737277465 0.5416064715675486
# 0 2 33 7 0.31900130150942246 0.4030395701725931
# 0 2 33 7 0.31900130150942246 0.4030395701725931
# 0 2 35 8 0.14958067892988838 0.5620400590121161
# 0 2 35 8 0.14958067892988838 0.5620400590121161
# 1 0 27 0 0.43184736796755546 0.0
# 1 0 27 0 0.43184736796755546 0.0
# 1 0 42 1 0.29702970180460453 0.0
# 1 0 42 1 0.29702970180460453 0.0
# 1 0 9 2 1.5328170390033173 0.0
# 1 0 9 2 1.5328170390033173 0.0
# 1 0 8 3 0.4083714992841697 0.0
# 1 0 8 3 0.4083714992841697 0.0
# 1 0 25 4 0.022159863014916705 0.0
# 1 0 25 4 0.022159863014916705 0.0
# 1 0 11 5 0.4872552106334577 0.0
# 1 0 11 5 0.4872552106334577 0.0
# 1 0 40 6 0.12225786737277469 0.0
# 1 0 40 6 0.12225786737277469 0.0
# 1 0 33 7 0.3190013015094225 0.0
# 1 0 33 7 0.3190013015094225 0.0
# 1 0 35 8 0.14958067892988838 0.0
# 1 0 35 8 0.14958067892988838 0.0
# 1 1 27 0 0.4318473679675561 5.3192873527424265
# 1 1 27 0 0.4318473679675561 5.3192873527424265
# 1 1 42 1 0.2970297018046045 4.481930151845036
# 1 1 42 1 0.2970297018046045 4.481930151845036
# 1 1 9 2 1.5328170390033176 1.3112050109597302
# 1 1 9 2 1.5328170390033176 1.3112050109597302
# 1 1 8 3 0.40837149928416977 0.276125159106031
# 1 1 8 3 0.40837149928416977 0.276125159106031
# 1 1 25 4 0.02215986301491671 2.4308046273649477
# 1 1 25 4 0.02215986301491671 2.4308046273649477
# 1 1 11 5 0.4872552106334577 0.2884811027516172
# 1 1 11 5 0.4872552106334577 0.2884811027516172
# 1 1 40 6 0.12225786737277468 3.2666840812138624
# 1 1 40 6 0.12225786737277468 3.2666840812138624
# 1 1 33 7 0.3190013015094225 0.8660281813550684
# 1 1 33 7 0.3190013015094225 0.8660281813550684
# 1 1 35 8 0.14958067892988838 0.06931055948722509
# 1 1 35 8 0.14958067892988838 0.06931055948722509
# 1 2 27 0 0.4318473679675555 0.0
# 1 2 27 0 0.4318473679675555 0.0
# 1 2 42 1 0.2970297018046045 0.0
# 1 2 42 1 0.2970297018046045 0.0
# 1 2 9 2 1.5328170390033173 0.0
# 1 2 9 2 1.5328170390033173 0.0
# 1 2 8 3 0.4083714992841697 0.0
# 1 2 8 3 0.4083714992841697 0.0
# 1 2 25 4 0.022159863014916705 0.0
# 1 2 25 4 0.022159863014916705 0.0
# 1 2 11 5 0.4872552106334577 0.0
# 1 2 11 5 0.4872552106334577 0.0
# 1 2 40 6 0.12225786737277469 0.0
# 1 2 40 6 0.12225786737277469 0.0
# 1 2 33 7 0.3190013015094225 0.0
# 0 0 27 0 0.4318473679675555 2.7014380694477698
# 0 0 27 0 0.4318473679675555 2.7014380694477698
# 0 0 42 1 0.29702970180460436 0.21364992095775825
# 0 0 42 1 0.29702970180460436 0.21364992095775825
# 0 0 9 2 1.5328170390033176 0.8051560646989859
# 0 0 9 2 1.5328170390033176 0.8051560646989859
# 0 0 8 3 0.4083714992841697 0.2732224349353277
# 0 0 8 3 0.4083714992841697 0.2732224349353277
# 0 0 25 4 0.02215986301491671 3.3470496978932616
# 0 0 25 4 0.02215986301491671 3.3470496978932616
# 0 0 11 5 0.4872552106334578 0.31016979512339227
# 0 0 11 5 0.4872552106334578 0.31016979512339227
# 0 0 40 6 0.12225786737277476 0.10363354053246296
# 0 0 40 6 0.12225786737277476 0.10363354053246296
# 0 0 33 7 0.3190013015094225 0.5156856733770324
# 0 0 33 7 0.3190013015094225 0.5156856733770324
# 0 0 35 8 0.14958067892988838 1.0003290723024374
# 0 0 35 8 0.14958067892988838 1.0003290723024374
# 0 1 27 0 0.4318473679675555 0.0
# 0 1 27 0 0.4318473679675555 0.0
# 0 1 8 3 0.4083714992841697 0.0
# 0 1 8 3 0.4083714992841697 0.0
# 0 1 11 5 0.4872552106334577 0.0
# 0 1 11 5 0.4872552106334577 0.0
# 1 2 33 7 0.3190013015094225 0.0
# 1 2 35 8 0.14958067892988838 0.0
# 1 2 35 8 0.14958067892988838 0.0
# 2 0 27 0 0.43184736796755563 3.3581843092495838
# 2 0 27 0 0.43184736796755563 3.3581843092495838
# 2 0 42 1 0.29702970180460453 0.5503331261774076
# 2 0 42 1 0.29702970180460453 0.5503331261774076
# 2 0 9 2 1.5328170390033176 0.6386521063979564
# 2 0 9 2 1.5328170390033176 0.6386521063979564
# 2 0 8 3 0.40837149928416977 0.5471961037785978
# 2 0 8 3 0.40837149928416977 0.5471961037785978
# 2 0 25 4 0.022159863014916723 1.0536271073440189
# 2 0 25 4 0.022159863014916723 1.0536271073440189
# 2 0 11 5 0.4872552106334578 0.6175004091053254
# 2 0 11 5 0.4872552106334578 0.6175004091053254
# 2 0 40 6 0.12225786737277468 0.7876552069612018
# 2 0 40 6 0.12225786737277468 0.7876552069612018
# 2 0 33 7 0.3190013015094226 0.7646228798228248
# 2 0 33 7 0.3190013015094226 0.7646228798228248
# 2 0 35 8 0.14958067892988838 0.9940051162994779
# 2 0 35 8 0.14958067892988838 0.9940051162994779
# 2 1 27 0 0.43184736796755546 0.0
# 2 1 27 0 0.43184736796755546 0.0
# 2 1 8 3 0.4083714992841697 0.0
# 2 1 8 3 0.4083714992841697 0.0
# 2 1 11 5 0.4872552106334577 0.0
# 2 1 42 1 0.29702970180460453 0.0
# 2 1 42 1 0.29702970180460453 0.0
# 2 1 9 2 1.5328170390033173 0.0
# 2 1 9 2 1.5328170390033173 0.0
# 2 1 25 4 0.022159863014916705 0.0
# 2 1 25 4 0.022159863014916705 0.0
# 2 1 11 5 0.4872552106334577 0.0
# 2 1 40 6 0.12225786737277469 0.0
# 2 1 40 6 0.12225786737277469 0.0
# 2 1 33 7 0.3190013015094225 0.0
# 2 1 33 7 0.3190013015094225 0.0
# 2 1 35 8 0.14958067892988838 0.0
# 2 1 35 8 0.14958067892988838 0.0
# 2 2 27 0 0.4318473679675557 0.0
# 2 2 27 0 0.4318473679675557 0.0
# 2 2 42 1 0.2970297018046044 0.0
# 2 2 42 1 0.2970297018046044 0.0
# 2 2 9 2 1.5328170390033176 0.0
# 2 2 9 2 1.5328170390033176 0.0
# 2 2 8 3 0.40837149928416977 0.0
# 2 2 8 3 0.40837149928416977 0.0
# 2 2 25 4 0.02215986301491672 0.0
# 2 2 25 4 0.02215986301491672 0.0
# 2 2 11 5 0.4872552106334578 0.0
# 2 2 11 5 0.4872552106334578 0.0
# 2 2 40 6 0.1222578673727747 0.0
# 2 2 40 6 0.1222578673727747 0.0
# 2 2 33 7 0.3190013015094226 0.0
# 2 2 33 7 0.3190013015094226 0.0
# 2 2 35 8 0.14958067892988838 0.0
# 2 2 35 8 0.14958067892988838 0.0
#
# [[[[0.43184737 2.70143807]
#    [0.2970297  0.21364992]
#    [1.53281704 0.80515606]
#    [0.4083715  0.27322243]
#    [0.02215986 3.3470497 ]
#    [0.48725521 0.3101698 ]
#    [0.12225787 0.10363354]
#    [0.3190013  0.51568567]
#    [0.14958068 1.00032907]]
#
#   [[0.43184737 0.        ]
#    [0.2970297  0.        ]
#    [1.53281704 0.        ]
#    [0.4083715  0.        ]
#    [0.02215986 0.        ]
#    [0.48725521 0.        ]
#    [0.12225787 0.        ]
#    [0.3190013  0.        ]
#    [0.14958068 0.        ]]
#
#   [[0.43184737 1.26866899]
#    [0.2970297  0.87952276]
#    [1.53281704 0.47434571]
#    [0.4083715  1.06672383]
#    [0.02215986 0.01577351]
#    [0.48725521 0.96622391]
#    [0.12225787 0.54160647]
#    [0.3190013  0.40303957]
#    [0.14958068 0.56204006]]]
#
#
#  [[[0.43184737 0.        ]
#    [0.2970297  0.        ]
#    [1.53281704 0.        ]
#    [0.4083715  0.        ]
#    [0.02215986 0.        ]
#    [0.48725521 0.        ]
#    [0.12225787 0.        ]
#    [0.3190013  0.        ]
#    [0.14958068 0.        ]]
#
#   [[0.43184737 5.31928735]
#    [0.2970297  4.48193015]
#    [1.53281704 1.31120501]
#    [0.4083715  0.27612516]
#    [0.02215986 2.43080463]
#    [0.48725521 0.2884811 ]
#    [0.12225787 3.26668408]
#    [0.3190013  0.86602818]
#    [0.14958068 0.06931056]]
#
#   [[0.43184737 0.        ]
#    [0.2970297  0.        ]
#    [1.53281704 0.        ]
#    [0.4083715  0.        ]
#    [0.02215986 0.        ]
#    [0.48725521 0.        ]
#    [0.12225787 0.        ]
#    [0.3190013  0.        ]
#    [0.14958068 0.        ]]]
#
#
#  [[[0.43184737 3.35818431]
#    [0.2970297  0.55033313]
#    [1.53281704 0.63865211]
#    [0.4083715  0.5471961 ]
#    [0.02215986 1.05362711]
#    [0.48725521 0.61750041]
#    [0.12225787 0.78765521]
#    [0.3190013  0.76462288]
#    [0.14958068 0.99400512]]
#
#   [[0.43184737 0.        ]
#    [0.2970297  0.        ]
#    [1.53281704 0.        ]
#    [0.4083715  0.        ]
#    [0.02215986 0.        ]
#    [0.48725521 0.        ]
#    [0.12225787 0.        ]
#    [0.3190013  0.        ]
#    [0.14958068 0.        ]]
#
#   [[0.43184737 0.        ]
#    [0.2970297  0.        ]
#    [1.53281704 0.        ]
#    [0.4083715  0.        ]
#    [0.02215986 0.        ]
#    [0.48725521 0.        ]
#    [0.12225787 0.        ]
#    [0.3190013  0.        ]
#    [0.14958068 0.        ]]]]
# Iteration :  0
# Position match :  10 241.10603258404996 (0, 2) 0
# Position match :  11 17.009499591591947 (0, 0) 0
# Position match :  13 18.46202658094544 (1, 1) 0
# Position match :  14 1.887753129830651 (2, 0) 0
# Position match :  15 1.50289616074725 (0, 1) 0
# Position match :  16 1.5622670696999226 (2, 1) 0
# Position match :  17 1.1951078895937997 (1, 0) 0
# Position match :  18 0.8187390864902527 (1, 2) 0
# Position match :  19 1.018179547619061 (2, 2) 0
# Position match :  20 0.7828826480228113 (1, 2) 1
# Position match :  21 1.1025992979191037 (0, 2) 1
# Position match :  22 1.0307106266772645 (1, 1) 1
# Position match :  23 0.7642123517009378 (0, 1) 1
# Position match :  24 0.6298128466244505 (2, 1) 1
# Position match :  34 0.8164098544282993 (2, 1) 2
# Position match :  35 1.011714928849334 (2, 0) 1
# Position match :  36 0.9936349326050101 (2, 2) 1
# Position match :  37 1.0910612474332722 (0, 0) 1
# Position match :  38 1.0114095799362062 (1, 0) 1
# Position match :  41 0.39599134420880794 (0, 1) 2
# Position match :  40 0.6433547094171053 (0, 0) 2
# Position match :  39 0.5989748249891786 (0, 2) 2
# Iteration :  1
# Position match :  10 0.8481810179148486 (1, 0) 2
# Old position :  10 (0, 2)
# Position match :  11 7.541713281326388 (1, 0) 3
# Old position :  11 (0, 0)
# Position match :  13 11.014288198965687 (1, 0) 4
# Old position :  13 (1, 1)
# Position match :  14 14.821559232547472 (1, 0) 5
# Old position :  14 (2, 0)
# Position match :  15 33.10011033709401 (2, 0) 1
# Old position :  15 (0, 1)
# Position match :  16 135.22929194280871 (2, 0) 2
# Old position :  16 (2, 1)
# Position match :  17 249.85993748092835 (2, 0) 3
# Old position :  17 (1, 0)
# Position match :  18 6.258399756512751 (2, 0) 4
# Old position :  18 (1, 2)
# Position match :  19 5.355823782563006 (0, 0) 2
# Old position :  19 (2, 2)
# Position match :  20 0.8358250569728165 (1, 2) 1
# Position match :  21 0.8827663946232319 (1, 1) 1
# Old position :  21 (0, 2)
# Position match :  22 2.155865498822986 (1, 1) 2
# Position match :  23 2.187011394791261 (1, 1) 2
# Old position :  23 (0, 1)
# Position match :  24 1.0283887007604362 (2, 2) 1
# Old position :  24 (2, 1)
# Position match :  34 6.176202689525548 (2, 2) 2
# Old position :  34 (2, 1)
# Position match :  35 11.097002140504696 (2, 2) 3
# Old position :  35 (2, 0)
# Position match :  36 16.12198533214264 (2, 2) 4
# Position match :  37 16.26715739562811 (2, 2) 4
# Old position :  37 (0, 0)
# Position match :  38 21.476281199418835 (2, 2) 5
# Old position :  38 (1, 0)
# Position match :  41 14.863716830563673 (0, 2) 1
# Old position :  41 (0, 1)
# Position match :  40 77.30749089429479 (0, 2) 2
# Old position :  40 (0, 0)
# Position match :  39 144.59969336962388 (0, 2) 3
# Iteration :  2
# Position match :  10 144.5192405495821 (0, 2) 3
# Old position :  10 (1, 0)
# Position match :  11 219.72166231569696 (0, 2) 4
# Old position :  11 (1, 0)
# Position match :  13 361.9501506462753 (1, 0) 2
# Position match :  14 361.85507796728626 (1, 0) 2
# Position match :  15 361.67685203059324 (1, 0) 2
# Old position :  15 (2, 0)
# Position match :  16 901.9672575172495 (1, 0) 3
# Old position :  16 (2, 0)
# Position match :  17 1371.939759459979 (1, 0) 4
# Old position :  17 (2, 0)
# Position match :  18 4.501296855181302 (2, 0) 1
# Position match :  19 1872.7880555667914 (1, 0) 5
# Old position :  19 (0, 0)
# Position match :  20 1.0298001498881244 (2, 1) 0
# Old position :  20 (1, 2)
# Position match :  21 2.1711056415036083 (2, 0) 1
# Old position :  21 (1, 1)
# Position match :  22 2.6376458586392584 (2, 0) 2
# Old position :  22 (1, 1)
# Position match :  23 3.9100995900401743 (1, 1) 1
# Position match :  24 1.4866217996427844 (1, 2) 0
# Old position :  24 (2, 2)
# Position match :  34 1.9230767894469825 (1, 1) 1
# Old position :  34 (2, 2)
# Position match :  35 4.865479637841709 (1, 1) 2
# Old position :  35 (2, 2)
# Position match :  36 7.201854167524276 (1, 1) 3
# Old position :  36 (2, 2)
# Position match :  37 9.905083576320575 (1, 1) 4
# Old position :  37 (2, 2)
# Position match :  38 19.776171879944748 (2, 2) 1
# Position match :  41 4.407856410247233 (2, 2) 1
# Old position :  41 (0, 2)
# Position match :  40 27.41279409685476 (0, 0) 0
# Old position :  40 (0, 2)
# Position match :  39 21.954434114736014 (2, 2) 2
# Old position :  39 (0, 2)
# Iteration :  3
# Position match :  10 50.051683137241234 (2, 2) 3
# Old position :  10 (0, 2)
# Position match :  11 92.0407074012014 (0, 2) 1
# Position match :  13 91.62218535822532 (0, 2) 1
# Old position :  13 (1, 0)
# Position match :  14 427.32447735307096 (0, 2) 2
# Old position :  14 (1, 0)
# Position match :  15 798.3325332829021 (0, 2) 3
# Old position :  15 (1, 0)
# Position match :  16 1215.3596993666813 (0, 2) 4
# Old position :  16 (1, 0)
# Position match :  17 1988.2353278373007 (1, 0) 2
# Position match :  18 0.8380119028273512 (0, 2) 5
# Old position :  18 (2, 0)
# Position match :  19 5.083265943653446 (1, 1) 5
# Old position :  19 (1, 0)
# Position match :  20 0.6401680058412301 (2, 0) 2
# Old position :  20 (2, 1)
# Position match :  21 1.8409671926221152 (1, 0) 1
# Old position :  21 (2, 0)
# Position match :  22 5.054400690309544 (2, 0) 2
# Position match :  23 4.9479229069652515 (2, 0) 2
# Old position :  23 (1, 1)
# Position match :  24 6.9418133947977525 (2, 0) 3
# Old position :  24 (1, 2)
# Position match :  34 10.535232252942793 (2, 0) 4
# Old position :  34 (1, 1)
# Position match :  35 14.224014822025898 (2, 0) 5
# Old position :  35 (1, 1)
# Position match :  36 17.96021361903118 (2, 0) 6
# Old position :  36 (1, 1)
# Position match :  37 21.92251566794489 (2, 0) 7
# Old position :  37 (1, 1)
# Position match :  38 25.836915351432232 (2, 0) 8
# Old position :  38 (2, 2)
# Position match :  41 1.3075207879499808 (0, 1) 0
# Old position :  41 (2, 2)
# Position match :  40 1.7965529676170617 (1, 1) 1
# Old position :  40 (0, 0)
# Position match :  39 7.744266204924643 (1, 1) 2
# Old position :  39 (2, 2)
# Iteration :  4
# Position match :  10 11.328098447231719 (1, 1) 3
# Old position :  10 (2, 2)
# Position match :  11 17.273739868477453 (1, 1) 4
# Old position :  11 (0, 2)
# Position match :  13 23.23158016985105 (1, 1) 5
# Old position :  13 (0, 2)
# Position match :  14 29.59456485342447 (1, 1) 6
# Old position :  14 (0, 2)
# Position match :  15 36.00539154117543 (1, 1) 7
# Old position :  15 (0, 2)
# Position match :  16 42.73631633255608 (1, 1) 8
# Old position :  16 (0, 2)
# Position match :  17 49.51538224224592 (1, 1) 9
# Old position :  17 (1, 0)
# Position match :  18 0.6327470404536335 (2, 2) 0
# Old position :  18 (0, 2)
# Position match :  19 2.0211477474831883 (1, 1) 10
# Position match :  20 1.5541179447475733 (1, 0) 1
# Old position :  20 (2, 0)
# Position match :  21 12.694104516868231 (1, 0) 2
# Position match :  22 7.122994293630471 (1, 0) 2
# Old position :  22 (2, 0)
# Position match :  23 11.053884802392862 (1, 0) 3
# Old position :  23 (2, 0)
# Position match :  24 1.0656691695854639 (0, 0) 0
# Old position :  24 (2, 0)
# Position match :  34 1.2270053116293058 (1, 2) 0
# Old position :  34 (2, 0)
# Position match :  35 1.9029179656294115 (0, 2) 0
# Old position :  35 (2, 0)
# Position match :  36 1.713270601754772 (2, 0) 3
# Position match :  37 1.741649330494373 (2, 0) 3
# Position match :  38 1.7042298561408513 (2, 0) 3
# Position match :  41 0.9128817467239949 (2, 0) 3
# Old position :  41 (0, 1)
# Position match :  40 1.5927394675343582 (2, 0) 4
# Old position :  40 (1, 1)
# Position match :  39 1.9435650068800951 (2, 0) 5
# Old position :  39 (1, 1)
# Iteration :  5
# Position match :  10 2.1681489582331355 (2, 0) 6
# Old position :  10 (1, 1)
# Position match :  11 2.455671368620689 (2, 0) 7
# Old position :  11 (1, 1)
# Position match :  13 2.9902950890804676 (1, 1) 6
# Position match :  14 3.0163227596713575 (1, 1) 6
# Position match :  15 2.9605009955765174 (1, 1) 6
# Position match :  16 2.9605009955765174 (1, 1) 6
# Position match :  17 2.9863202842542917 (1, 1) 6
# Position match :  18 0.7409020236835409 (2, 1) 0
# Old position :  18 (2, 2)
# Position match :  19 9.954206859996022 (1, 0) 4
# Old position :  19 (1, 1)
# Position match :  20 11.866909007204839 (1, 0) 5
# Position match :  21 11.974615902252797 (1, 0) 5
# Position match :  22 11.949361684685396 (1, 0) 5
# Position match :  23 11.852021668489071 (1, 0) 5
# Position match :  24 1.060096065298029 (0, 1) 0
# Old position :  24 (0, 0)
# Position match :  34 1.3717139988461606 (0, 0) 0
# Old position :  34 (1, 2)
# Position match :  35 1.503284369962175 (1, 2) 0
# Old position :  35 (0, 2)
# Position match :  36 1.5295811783111781 (0, 2) 0
# Old position :  36 (2, 0)
# Position match :  37 1.5583536190140366 (2, 2) 0
# Old position :  37 (2, 0)
# Position match :  38 1.0941337934612356 (0, 2) 1
# Old position :  38 (2, 0)
# Position match :  41 5.7193784302409885 (0, 2) 2
# Old position :  41 (2, 0)
# Position match :  40 9.80235667865873 (0, 2) 3
# Old position :  40 (2, 0)
# Position match :  39 14.325045235043458 (0, 2) 4
# Old position :  39 (2, 0)
# Iteration :  6
# Position match :  10 74.40322798060545 (2, 0) 2
# Position match :  11 74.40322798060545 (2, 0) 2
# Position match :  13 70.72581409849276 (2, 0) 2
# Old position :  13 (1, 1)
# Position match :  14 189056.59661708176 (2, 0) 3
# Old position :  14 (1, 1)
# Position match :  15 288084.3527910744 (2, 0) 4
# Old position :  15 (1, 1)
# Position match :  16 393864.4942656287 (2, 0) 5
# Old position :  16 (1, 1)
# Position match :  17 537.349541797904 (1, 1) 1
# Position match :  18 245.1513107960701 (1, 1) 1
# Old position :  18 (2, 1)
# Position match :  19 1.8562073947863957 (0, 2) 5
# Old position :  19 (1, 0)
# Position match :  20 1.7694156565940349 (2, 0) 6
# Old position :  20 (1, 0)
# Position match :  21 0.9802338052277801 (2, 1) 0
# Old position :  21 (1, 0)
# Position match :  22 1.3615874271213828 (1, 0) 2
# Position match :  23 1.5633711577323355 (1, 0) 2
# Position match :  24 1.5303850495490225 (1, 0) 2
# Old position :  24 (0, 1)
# Position match :  34 2.7847941219274026 (1, 0) 3
# Old position :  34 (0, 0)
# Position match :  35 3.7215154583590255 (1, 0) 4
# Old position :  35 (1, 2)
# Position match :  36 4.672839738619479 (1, 0) 5
# Old position :  36 (0, 2)
# Position match :  37 5.687608612461361 (1, 0) 6
# Old position :  37 (2, 2)
# Position match :  38 6.655500629753368 (1, 0) 7
# Old position :  38 (0, 2)
# Position match :  41 2.7525213921623215 (0, 2) 4
# Position match :  40 2.835363314439311 (0, 2) 4
# Position match :  39 2.8241530151955505 (0, 2) 4
# Iteration :  7
# Position match :  10 7.558367257222041 (1, 0) 8
# Old position :  10 (2, 0)
# Position match :  11 9.635583536382514 (2, 0) 6
# Position match :  13 9.752513168337737 (2, 0) 6
# Position match :  14 9.701091406643842 (2, 0) 6
# Position match :  15 9.712639413330487 (2, 0) 6
# Position match :  16 9.712639413330487 (2, 0) 6
# Position match :  17 3.255877523028206 (1, 1) 2
# Position match :  18 2.9033104036285895 (1, 1) 2
# Position match :  19 2.944933615796239 (0, 2) 4
# Position match :  20 8.754222930795896 (2, 0) 6
# Position match :  21 0.84811003000115 (2, 2) 0
# Old position :  21 (2, 1)
# Position match :  22 2.2121942370405927 (1, 0) 9
# Position match :  23 3.393586545964828 (2, 0) 6
# Old position :  23 (1, 0)
# Position match :  24 3.9203305331297136 (1, 0) 8
# Position match :  34 3.9203305331297136 (1, 0) 8
# Position match :  35 3.9792717782203773 (1, 0) 8
# Position match :  36 3.9203305331297136 (1, 0) 8
# Position match :  37 3.9792717782203773 (1, 0) 8
# Position match :  38 3.8980636051183875 (1, 0) 8
# Position match :  41 2.008031057953197 (0, 2) 4
# Position match :  40 2.086008719970526 (0, 2) 4
# Position match :  39 2.076831632948058 (0, 2) 4
# Iteration :  8
# Position match :  10 3.8554552214596844 (2, 0) 7
# Old position :  10 (1, 0)
# Position match :  11 4.844265860003413 (1, 0) 7
# Old position :  11 (2, 0)
# Position match :  13 6.216739395468829 (1, 0) 8
# Old position :  13 (2, 0)
# Position match :  14 7.04925164697842 (2, 0) 6
# Position match :  15 7.047436219268842 (2, 0) 6
# Position match :  16 7.047436219268842 (2, 0) 6
# Position match :  17 2.5211498919299533 (0, 2) 4
# Old position :  17 (1, 1)
# Position match :  18 9.167767863315156 (1, 1) 1
# Position match :  19 3.395929946544518 (0, 2) 5
# Position match :  20 4.8754023337264725 (2, 0) 6
# Position match :  21 0.9019937906871938 (0, 1) 0
# Old position :  21 (2, 2)
# Position match :  22 1.3739442396674477 (1, 0) 9
# Position match :  23 2.798208180604548 (1, 1) 1
# Old position :  23 (2, 0)
# Position match :  24 7.825285817523863 (1, 1) 2
# Old position :  24 (1, 0)
# Position match :  34 13.814901968598626 (1, 1) 3
# Old position :  34 (1, 0)
# Position match :  35 20.456033092139315 (1, 1) 4
# Old position :  35 (1, 0)
# Position match :  36 27.590675788829753 (1, 1) 5
# Old position :  36 (1, 0)
# Position match :  37 35.1583600446322 (1, 1) 6
# Old position :  37 (1, 0)
# Position match :  38 42.836706363416475 (1, 1) 7
# Old position :  38 (1, 0)
# Position match :  41 2.8750310366409018 (0, 2) 5
# Position match :  40 2.9572098570335004 (0, 2) 5
# Position match :  39 2.9501817008330526 (0, 2) 5
# Iteration :  9
# Position match :  10 50.79010112788212 (1, 1) 8
# Old position :  10 (2, 0)
# Position match :  11 58.84157536912897 (1, 1) 9
# Old position :  11 (1, 0)
# Position match :  13 66.96551892326565 (1, 1) 10
# Old position :  13 (1, 0)
# Position match :  14 75.13582698837295 (1, 1) 11
# Old position :  14 (2, 0)
# Position match :  15 83.4141396477808 (1, 1) 12
# Old position :  15 (2, 0)
# Position match :  16 91.728632851759 (1, 1) 13
# Old position :  16 (2, 0)
# Position match :  17 99.93445814463372 (1, 1) 14
# Old position :  17 (0, 2)
# Position match :  18 108.01401539581276 (1, 1) 15
# Position match :  19 5.3962088112617534 (0, 2) 4
# Position match :  20 2.906045742187009 (2, 0) 1
# Position match :  21 0.8466980215842553 (2, 2) 0
# Old position :  21 (0, 1)
# Position match :  22 1.2105637773558788 (1, 2) 0
# Old position :  22 (1, 0)
# Position match :  23 2.762532533194955 (1, 0) 0
# Old position :  23 (1, 1)
# Position match :  24 4.139959257443762 (2, 0) 1
# Old position :  24 (1, 1)
# Position match :  34 10.213490905982416 (2, 0) 2
# Old position :  34 (1, 1)
# Position match :  35 17.968358376568123 (2, 0) 3
# Old position :  35 (1, 1)
# Position match :  36 26.733844349391667 (2, 0) 4
# Old position :  36 (1, 1)
# Position match :  37 36.1652951098805 (2, 0) 5
# Old position :  37 (1, 1)
# Position match :  38 45.85439014545495 (2, 0) 6
# Old position :  38 (1, 1)
# Position match :  41 2.030515696247236 (0, 2) 4
# Position match :  40 2.109892711044617 (0, 2) 4
# Position match :  39 2.0989150158933643 (0, 2) 4
# Iteration :  10
# Position match :  10 55.6554087444775 (2, 0) 7
# Old position :  10 (1, 1)
# Position match :  11 65.94279766573308 (2, 0) 8
# Old position :  11 (1, 1)
# Position match :  13 76.38666715193301 (2, 0) 9
# Old position :  13 (1, 1)
# Position match :  14 86.83644857912091 (2, 0) 10
# Old position :  14 (1, 1)
# Position match :  15 97.48456280780871 (2, 0) 11
# Old position :  15 (1, 1)
# Position match :  16 108.1736210424139 (2, 0) 12
# Old position :  16 (1, 1)
# Position match :  17 8.723895146675687 (1, 1) 2
# Position match :  18 8.542178568275483 (1, 1) 2
# Position match :  19 3.79351776014359 (0, 2) 4
# Position match :  20 117.84994384897675 (2, 0) 13
# Position match :  21 0.8147258602539922 (0, 1) 0
# Old position :  21 (2, 2)
# Position match :  22 1.2042316941294473 (0, 0) 0
# Old position :  22 (1, 2)
# Position match :  23 1.2677208809506022 (1, 2) 0
# Old position :  23 (1, 0)
# Position match :  24 1.1345620102654912 (2, 2) 0
# Old position :  24 (2, 0)
# Position match :  34 7.540975758276081 (2, 0) 12
# Position match :  35 7.578526215619922 (2, 0) 12
# Position match :  36 7.540975758276081 (2, 0) 12
# Position match :  37 7.578526215619922 (2, 0) 12
# Position match :  38 7.52065302854911 (2, 0) 12
# Position match :  41 0.7459170305515714 (0, 2) 4
# Position match :  40 1.0352765779394968 (1, 0) 0
# Old position :  40 (0, 2)
# Position match :  39 1.4013454858747354 (0, 2) 3
# Iteration :  11
# Position match :  10 2.428736668011586 (2, 0) 12
# Position match :  11 2.428736668011586 (2, 0) 12
# Position match :  13 2.4923340690763953 (2, 0) 12
# Position match :  14 2.4663576389067656 (2, 0) 12
# Position match :  15 2.4747967006317007 (2, 0) 12
# Position match :  16 2.4747967006317007 (2, 0) 12
# Position match :  17 1.3820016821738168 (0, 2) 3
# Old position :  17 (1, 1)
# Position match :  18 0.855383437207586 (1, 1) 1
# Position match :  19 2.3206043365641347 (0, 2) 4
# Position match :  20 1.2655303992295859 (2, 0) 12
# Position match :  21 0.9637532544460414 (2, 1) 0
# Old position :  21 (0, 1)
# Position match :  22 1.3292909699293678 (0, 1) 0
# Old position :  22 (0, 0)
# Position match :  23 1.269962236493365 (0, 0) 0
# Old position :  23 (1, 2)
# Position match :  24 1.0608382471101916 (1, 2) 0
# Old position :  24 (2, 2)
# Position match :  34 1.36817488654442 (2, 2) 0
# Old position :  34 (2, 0)
# Position match :  35 1.4255273205716676 (2, 0) 11
# Position match :  36 1.382487639506724 (2, 0) 11
# Position match :  37 1.4255273205716676 (2, 0) 11
# Position match :  38 1.366279666684876 (2, 0) 11
# Position match :  41 1.0233983241938023 (0, 2) 4
# Position match :  40 1.0920316165609292 (0, 2) 4
# Old position :  40 (1, 0)
# Position match :  39 1.2641075067330043 (0, 2) 5
# Iteration :  12
# Position match :  10 1.5064853802563238 (1, 0) 0
# Old position :  10 (2, 0)
# Position match :  11 1.6041575106058412 (2, 0) 10
# Position match :  13 1.618933685872902 (2, 0) 10
# Position match :  14 1.6108009265882268 (2, 0) 10
# Position match :  15 1.601700573626467 (2, 0) 10
# Position match :  16 1.601700573626467 (2, 0) 10
# Position match :  17 1.2835676478913156 (0, 2) 5
# Position match :  18 0.8882739554580343 (1, 1) 1
# Position match :  19 1.2930520089994797 (0, 2) 5
# Position match :  20 1.2677841843428175 (2, 0) 10
# Position match :  21 0.8442671670548382 (1, 1) 1
# Old position :  21 (2, 1)
# Position match :  22 1.590851937330129 (1, 1) 2
# Old position :  22 (0, 1)
# Position match :  23 2.215152639163357 (1, 1) 3
# Old position :  23 (0, 0)
# Position match :  24 1.2610111176191592 (2, 0) 10
# Old position :  24 (1, 2)
# Position match :  34 1.3136604977426412 (2, 0) 11
# Old position :  34 (2, 2)
# Position match :  35 1.4636758763209998 (2, 0) 12
# Position match :  36 1.4365750532814325 (2, 0) 12
# Position match :  37 1.4636758763209998 (2, 0) 12
# Position match :  38 1.4267428947039928 (2, 0) 12
# Position match :  41 0.8773811040917213 (0, 2) 5
# Position match :  40 1.0209790199805866 (0, 1) 0
# Old position :  40 (0, 2)
# Position match :  39 1.237344143107613 (0, 2) 4
# Iteration :  13
# Position match :  10 1.2304616726984292 (2, 2) 0
# Old position :  10 (1, 0)
# Position match :  11 1.425023200324622 (1, 2) 0
# Old position :  11 (2, 0)
# Position match :  13 1.3999418851633636 (1, 0) 0
# Old position :  13 (2, 0)
# Position match :  14 1.4425100948698777 (2, 0) 10
# Position match :  15 1.426757614623025 (2, 0) 10
# Position match :  16 1.426757614623025 (2, 0) 10
# Position match :  17 1.1625928477289535 (2, 1) 0
# Old position :  17 (0, 2)
# Position match :  18 0.8440438771638037 (0, 0) 0
# Old position :  18 (1, 1)
# Position match :  19 1.1140566060069572 (1, 1) 3
# Old position :  19 (0, 2)
# Position match :  20 2.0891458849262645 (1, 1) 4
# Old position :  20 (2, 0)
# Position match :  21 2.875320235479306 (1, 1) 5
# Position match :  22 2.8519435239482633 (1, 1) 5
# Position match :  23 2.7572140350484573 (1, 1) 5
# Position match :  24 0.783329948361457 (2, 2) 1
# Old position :  24 (2, 0)
# Position match :  34 2.9295289662068154 (2, 2) 2
# Old position :  34 (2, 0)
# Position match :  35 4.3419679909802795 (2, 2) 3
# Old position :  35 (2, 0)
# Position match :  36 5.058346199603498 (2, 2) 4
# Old position :  36 (2, 0)
# Position match :  37 6.354002485774082 (2, 2) 5
# Old position :  37 (2, 0)
# Position match :  38 7.322386163730093 (2, 2) 6
# Old position :  38 (2, 0)
# Position match :  41 5.014868893054376 (2, 0) 3
# Old position :  41 (0, 2)
# Position match :  40 10.88140004557885 (0, 2) 1
# Old position :  40 (0, 1)
# Position match :  39 54.88346129181447 (0, 2) 2
# Iteration :  14
# Position match :  10 55.10192519577171 (0, 2) 2
# Old position :  10 (2, 2)
# Position match :  11 102.23296707396997 (0, 2) 3
# Old position :  11 (1, 2)
# Position match :  13 154.74503571898666 (0, 2) 4
# Old position :  13 (1, 0)
# Position match :  14 211.31808260280468 (0, 2) 5
# Old position :  14 (2, 0)
# Position match :  15 298.50292718732805 (2, 0) 3
# Position match :  16 298.50292718732805 (2, 0) 3
# Position match :  17 298.43455347187324 (2, 0) 3
# Old position :  17 (2, 1)
# Position match :  18 0.7859456419723522 (2, 2) 6
# Old position :  18 (0, 0)
# Position match :  19 1.1946076753975992 (1, 0) 0
# Old position :  19 (1, 1)
# Position match :  20 0.7986459713459155 (0, 0) 0
# Old position :  20 (1, 1)
# Position match :  21 1.3290805096950349 (0, 1) 0
# Old position :  21 (1, 1)
# Position match :  22 1.5284736704149726 (1, 1) 2
# Position match :  23 1.3742742559538579 (1, 1) 2
# Position match :  24 1.154218896141875 (1, 2) 0
# Old position :  24 (2, 2)
# Position match :  34 1.3256179961121028 (2, 1) 0
# Old position :  34 (2, 2)
# Position match :  35 1.5467345284128007 (1, 1) 2
# Old position :  35 (2, 2)
# Position match :  36 1.5520409122185317 (1, 1) 3
# Old position :  36 (2, 2)
# Position match :  37 1.8484071492535967 (1, 1) 4
# Old position :  37 (2, 2)
# Position match :  38 2.0662590895932555 (1, 1) 5
# Old position :  38 (2, 2)
# Position match :  41 0.47828457275686515 (0, 0) 1
# Old position :  41 (2, 0)
# Position match :  40 2.304563849046185 (2, 0) 3
# Old position :  40 (0, 2)
# Position match :  39 3.861374190951945 (2, 0) 4
# Old position :  39 (0, 2)
# Iteration :  15
# Position match :  10 6.274834393355057 (0, 2) 4
# Position match :  11 6.274834393355057 (0, 2) 4
# Position match :  13 6.183283675801171 (0, 2) 4
# Position match :  14 5.96074597584441 (0, 2) 4
# Position match :  15 5.873123940215049 (0, 2) 4
# Old position :  15 (2, 0)
# Position match :  16 9.391223394455512 (0, 2) 5
# Old position :  16 (2, 0)
# Position match :  17 10.626680425985148 (2, 0) 3
# Position match :  18 2.2845325350009156 (2, 2) 1
# Position match :  19 10.640135322492114 (2, 0) 3
# Old position :  19 (1, 0)
# Position match :  20 1.2988096104811429 (0, 2) 6
# Old position :  20 (0, 0)
# Position match :  21 1.0332164258207805 (1, 0) 0
# Old position :  21 (0, 1)
# Position match :  22 1.2571284217468341 (0, 1) 0
# Old position :  22 (1, 1)
# Position match :  23 1.5064983146113458 (1, 1) 5
# Position match :  24 1.5196623079291656 (1, 1) 5
# Old position :  24 (1, 2)
# Position match :  34 1.8847048803728936 (1, 1) 6
# Old position :  34 (2, 1)
# Position match :  35 2.298980659373619 (1, 1) 7
# Position match :  36 2.2486637647454124 (1, 1) 7
# Position match :  37 2.298980659373619 (1, 1) 7
# Position match :  38 2.227864783902137 (1, 1) 7
# Position match :  41 0.6438608266288727 (2, 1) 0
# Old position :  41 (0, 0)
# Position match :  40 1.0105081343331914 (1, 2) 0
# Old position :  40 (2, 0)
# Position match :  39 1.8426721914171083 (2, 0) 3
# Iteration :  16
# Position match :  10 1.9486305931898165 (2, 0) 3
# Old position :  10 (0, 2)
# Position match :  11 3.091411822353035 (2, 0) 4
# Old position :  11 (0, 2)
# Position match :  13 3.8699035274892903 (2, 0) 5
# Old position :  13 (0, 2)
# Position match :  14 4.741906519365389 (2, 0) 6
# Old position :  14 (0, 2)
# Position match :  15 5.657859203874487 (2, 0) 7
# Old position :  15 (0, 2)
# Position match :  16 6.69441826556702 (2, 0) 8
# Old position :  16 (0, 2)
# Position match :  17 7.6944206182836545 (2, 0) 9
# Position match :  18 0.4849403125401695 (2, 1) 1
# Old position :  18 (2, 2)
# Position match :  19 3.6850190025674694 (0, 2) 1
# Old position :  19 (2, 0)
# Position match :  20 26.62533374657935 (0, 2) 2
# Position match :  21 26.746349399755918 (0, 2) 2
# Old position :  21 (1, 0)
# Position match :  22 5.325563114594826 (0, 2) 3
# Old position :  22 (0, 1)
# Position match :  23 7.655435495337153 (0, 2) 4
# Old position :  23 (1, 1)
# Position match :  24 1.0887270445529065 (1, 0) 0
# Old position :  24 (1, 1)
# Position match :  34 1.245936475810882 (0, 1) 0
# Old position :  34 (1, 1)
# Position match :  35 1.8665031885977574 (1, 1) 4
# Position match :  36 1.839564368565385 (1, 1) 4
# Position match :  37 1.8665031885977574 (1, 1) 4
# Position match :  38 1.8302798856246745 (1, 1) 4
# Position match :  41 1.2642909290003503 (1, 1) 4
# Old position :  41 (2, 1)
# Position match :  40 2.1148499028256516 (1, 1) 5
# Old position :  40 (1, 2)
# Position match :  39 2.6570886272788403 (1, 1) 6
# Old position :  39 (2, 0)
# Iteration :  17
# Position match :  10 3.1297344520850316 (1, 1) 7
# Old position :  10 (2, 0)
# Position match :  11 3.889758078466111 (2, 0) 6
# Position match :  13 3.842342709292083 (2, 0) 6
# Position match :  14 3.8657231417199203 (2, 0) 6
# Position match :  15 3.811073984080299 (2, 0) 6
# Position match :  16 3.811073984080299 (2, 0) 6
# Position match :  17 3.8269663196391037 (2, 0) 6
# Position match :  18 0.847272836018444 (2, 1) 1
# Position match :  19 3.881196371398843 (2, 0) 6
# Old position :  19 (0, 2)
# Position match :  20 2.4938155524220065 (2, 2) 0
# Old position :  20 (0, 2)
# Position match :  21 2.3977513636117394 (0, 2) 3
# Position match :  22 2.409368264856167 (0, 2) 3
# Position match :  23 2.0897583256686802 (0, 2) 3
# Position match :  24 1.0841629848898127 (1, 2) 0
# Old position :  24 (1, 0)
# Position match :  34 1.3913339401083067 (1, 0) 0
# Old position :  34 (0, 1)
# Position match :  35 1.5133071891613648 (0, 1) 0
# Old position :  35 (1, 1)
# Position match :  36 1.1422555674976442 (1, 0) 1
# Old position :  36 (1, 1)
# Position match :  37 36.07749333712839 (1, 0) 2
# Old position :  37 (1, 1)
# Position match :  38 63.24739608387732 (1, 0) 3
# Old position :  38 (1, 1)
# Position match :  41 18.577850269805186 (1, 0) 4
# Old position :  41 (1, 1)
# Position match :  40 25.537552745866403 (1, 1) 3
# Position match :  39 25.503099535798526 (1, 1) 3
# Iteration :  18
# Position match :  10 25.62552460726041 (1, 1) 3
# Position match :  11 25.62552460726041 (1, 1) 3
# Old position :  11 (2, 0)
# Position match :  13 54.70052832365896 (1, 1) 4
# Old position :  13 (2, 0)
# Position match :  14 73.890481615406 (1, 1) 5
# Old position :  14 (2, 0)
# Position match :  15 97.09483113926308 (2, 0) 4
# Position match :  16 97.09483113926308 (2, 0) 4
# Position match :  17 97.00324707619632 (2, 0) 4
# Position match :  18 0.7821602424791053 (2, 1) 1
# Position match :  19 96.71596210009771 (2, 0) 4
# Position match :  20 0.46901973520979867 (1, 2) 1
# Old position :  20 (2, 2)
# Position match :  21 1.122213005252297 (2, 2) 0
# Old position :  21 (0, 2)
# Position match :  22 1.089139506583306 (2, 2) 1
# Old position :  22 (0, 2)
# Position match :  23 10.269128186257133 (2, 2) 2
# Old position :  23 (0, 2)
# Position match :  24 2.7641229047912144 (0, 2) 0
# Old position :  24 (1, 2)
# Position match :  34 5.06518942720857 (1, 2) 1
# Old position :  34 (1, 0)
# Position match :  35 32.64221044300947 (1, 2) 2
# Old position :  35 (0, 1)
# Position match :  36 60.278141070916206 (1, 2) 3
# Old position :  36 (1, 0)
# Position match :  37 91.32933468250397 (1, 2) 4
# Old position :  37 (1, 0)
# Position match :  38 124.34346139924361 (1, 2) 5
# Old position :  38 (1, 0)
# Position match :  41 0.7742368271220874 (1, 0) 1
# Position match :  40 3.0122045090435656 (2, 2) 3
# Old position :  40 (1, 1)
# Position match :  39 1.5812155121060498 (1, 1) 5
# Iteration :  19
# Position match :  10 1.8412057618632147 (1, 1) 5
# Position match :  11 1.8412057618632147 (1, 1) 5
# Position match :  13 1.8222900519231904 (1, 1) 5
# Position match :  14 1.7806270809931166 (2, 0) 4
# Old position :  14 (1, 1)
# Position match :  15 2.8948412142375637 (2, 0) 5
# Position match :  16 2.8948412142375637 (2, 0) 5
# Position match :  17 2.836378607099428 (2, 0) 5
# Position match :  18 0.8274039326954528 (2, 1) 1
# Position match :  19 2.575872496078832 (2, 0) 5
# Position match :  20 0.7165596134154089 (0, 1) 0
# Old position :  20 (1, 2)
# Position match :  21 0.9374652281453453 (0, 1) 1
# Old position :  21 (2, 2)
# Position match :  22 4.664389710041734 (0, 1) 2
# Old position :  22 (2, 2)
# Position match :  23 6.854746724403866 (0, 1) 3
# Old position :  23 (2, 2)
# Position match :  24 0.7528476415258929 (0, 2) 1
# Position match :  34 0.7528476415258929 (0, 2) 1
# Old position :  34 (1, 2)
# Position match :  35 7.1531926740182765 (0, 2) 2
# Old position :  35 (1, 2)
# Position match :  36 11.871294447122894 (0, 2) 3
# Old position :  36 (1, 2)
# Position match :  37 17.533831822758142 (0, 2) 4
# Old position :  37 (1, 2)
# Position match :  38 34.342978153985 (1, 2) 1
# Position match :  41 3.3944601249813697 (1, 2) 1
# Old position :  41 (1, 0)
# Position match :  40 14.448349906679322 (1, 2) 2
# Old position :  40 (2, 2)
# Position match :  39 26.791163320937283 (1, 2) 3
# Old position :  39 (1, 1)
# Iteration :  20
# Position match :  10 40.63960813464223 (1, 2) 4
# Old position :  10 (1, 1)
# Position match :  11 68.39787044492739 (1, 1) 2
# Position match :  13 68.3956047424345 (1, 1) 2
# Position match :  14 67.34831509310224 (1, 1) 2
# Old position :  14 (2, 0)
# Position match :  15 166.7036396166804 (1, 1) 3
# Old position :  15 (2, 0)
# Position match :  16 253.2157983254438 (1, 1) 4
# Old position :  16 (2, 0)
# Position match :  17 412.56662445243256 (2, 0) 2
# Position match :  18 1.1908712413118916 (1, 1) 5
# Old position :  18 (2, 1)
# Position match :  19 4.219644740023237 (0, 2) 5
# Old position :  19 (2, 0)
# Position match :  20 0.8944806393802942 (2, 1) 0
# Old position :  20 (0, 1)
# Position match :  21 3.2935401304454803 (2, 0) 1
# Old position :  21 (0, 1)
# Position match :  22 2.9079691843468782 (2, 2) 0
# Old position :  22 (0, 1)
# Position match :  23 4.478443953278004 (0, 1) 1
# Position match :  24 2.061993248793736 (0, 1) 1
# Old position :  24 (0, 2)
# Position match :  34 7.500428101070583 (0, 1) 2
# Old position :  34 (0, 2)
# Position match :  35 13.12482596492142 (0, 1) 3
# Old position :  35 (0, 2)
# Position match :  36 19.315785670354305 (0, 1) 4
# Old position :  36 (0, 2)
# Position match :  37 26.131244665206474 (0, 1) 5
# Old position :  37 (0, 2)
# Position match :  38 33.059771833149235 (0, 1) 6
# Old position :  38 (1, 2)
# Position match :  41 2.986794782432323 (0, 2) 1
# Old position :  41 (1, 2)
# Position match :  40 13.955930803112034 (0, 2) 2
# Old position :  40 (1, 2)
# Position match :  39 25.352138047842473 (0, 2) 3
# Old position :  39 (1, 2)
# Iteration :  21
# Position match :  10 45.665739915188595 (1, 2) 1
# Position match :  11 45.665739915188595 (1, 2) 1
# Old position :  11 (1, 1)
# Position match :  13 211.94032006307745 (1, 2) 2
# Old position :  13 (1, 1)
# Position match :  14 395.83677136960586 (1, 2) 3
# Old position :  14 (1, 1)
# Position match :  15 602.6994452340128 (1, 2) 4
# Old position :  15 (1, 1)
# Position match :  16 823.8194686155047 (1, 2) 5
# Old position :  16 (1, 1)
# Position match :  17 1050.7577645790675 (1, 2) 6
# Old position :  17 (2, 0)
# Position match :  18 1.7701959566410124 (1, 1) 1
# Position match :  19 1589.5859752399076 (0, 0) 0
# Old position :  19 (0, 2)
# Position match :  20 0.8918765994675653 (2, 0) 1
# Old position :  20 (2, 1)
# Position match :  21 5.0119632789209545 (2, 0) 2
# Position match :  22 3.9527248875871566 (2, 0) 2
# Old position :  22 (2, 2)
# Position match :  23 6.174869474419657 (2, 0) 3
# Old position :  23 (0, 1)
# Position match :  24 1.0466111662704187 (2, 1) 0
# Old position :  24 (0, 1)
# Position match :  34 1.3055661209363567 (2, 2) 0
# Old position :  34 (0, 1)
# Position match :  35 1.2375113442395358 (1, 0) 0
# Old position :  35 (0, 1)
# Position match :  36 1.6621757047944918 (0, 1) 3
# Position match :  37 1.6923255637375156 (0, 1) 3
# Position match :  38 1.6527806448643951 (0, 1) 3
# Position match :  41 0.6912183414241387 (0, 1) 3
# Old position :  41 (0, 2)
# Position match :  40 1.5985431444848595 (0, 2) 2
# Position match :  39 1.5828705094009936 (0, 2) 2
# Iteration :  22
# Position match :  10 1.7186395121004212 (0, 2) 2
# Old position :  10 (1, 2)
# Position match :  11 3.215182542523567 (0, 2) 3
# Old position :  11 (1, 2)
# Position match :  13 4.096585071890782 (0, 2) 4
# Old position :  13 (1, 2)
# Position match :  14 5.143551326628773 (0, 2) 5
# Old position :  14 (1, 2)
# Position match :  15 7.63841870650456 (1, 2) 3
# Position match :  16 7.63841870650456 (1, 2) 3
# Position match :  17 7.629143136600963 (1, 2) 3
# Position match :  18 0.7453212942311628 (1, 1) 1
# Position match :  19 7.6712395298354465 (1, 2) 3
# Old position :  19 (0, 0)
# Position match :  20 1.2438265052625506 (1, 1) 1
# Old position :  20 (2, 0)
# Position match :  21 1.7826198797011028 (1, 1) 2
# Old position :  21 (2, 0)
# Position match :  22 2.7145195619613642 (2, 0) 2
# Position match :  23 2.658056528999254 (2, 0) 2
# Position match :  24 1.2748520852542444 (2, 0) 2
# Old position :  24 (2, 1)
# Position match :  34 2.246122613126137 (2, 0) 3
# Old position :  34 (2, 2)
# Position match :  35 3.0137028115021867 (2, 0) 4
# Old position :  35 (1, 0)
# Position match :  36 3.713797168992771 (2, 0) 5
# Old position :  36 (0, 1)
# Position match :  37 4.52128224678133 (2, 0) 6
# Old position :  37 (0, 1)
# Position match :  38 5.229047543146053 (2, 0) 7
# Old position :  38 (0, 1)
# Position match :  41 5.656079803641245 (0, 1) 1
# Position match :  40 5.685745331413287 (0, 1) 1
# Old position :  40 (0, 2)
# Position match :  39 20.359166128480133 (0, 1) 2
# Old position :  39 (0, 2)
# Iteration :  23
# Position match :  10 36.716146113159056 (0, 1) 3
# Old position :  10 (0, 2)
# Position match :  11 55.40703530445923 (0, 1) 4
# Old position :  11 (0, 2)
# Position match :  13 95.00493060613572 (0, 2) 2
# Position match :  14 94.97036952711981 (0, 2) 2
# Position match :  15 94.74582789576615 (0, 2) 2
# Old position :  15 (1, 2)
# Position match :  16 233.76597611769319 (0, 2) 3
# Old position :  16 (1, 2)
# Position match :  17 346.3853411183112 (0, 2) 4
# Old position :  17 (1, 2)
# Position match :  18 0.9778708755553678 (0, 2) 5
# Old position :  18 (1, 1)
# Position match :  19 2.7618505438100525 (1, 2) 1
# Position match :  20 3.5697653709106656 (2, 0) 8
# Old position :  20 (1, 1)
# Position match :  21 1.036154841787008 (2, 2) 0
# Old position :  21 (1, 1)
# Position match :  22 1.473068693022526 (1, 1) 0
# Old position :  22 (2, 0)
# Position match :  23 1.47167753432006 (2, 0) 8
# Position match :  24 1.5759017304202756 (2, 0) 8
# Position match :  34 1.5759017304202756 (2, 0) 8
# Position match :  35 1.6094530080041802 (2, 0) 8
# Position match :  36 1.5759017304202756 (2, 0) 8
# Position match :  37 1.6094530080041802 (2, 0) 8
# Position match :  38 1.5653014740755025 (2, 0) 8
# Position match :  41 0.6469547058976549 (2, 1) 0
# Old position :  41 (0, 1)
# Position match :  40 1.0286091971083655 (0, 0) 0
# Old position :  40 (0, 1)
# Position match :  39 1.1196760943991029 (1, 0) 0
# Old position :  39 (0, 1)
# Iteration :  24
# Position match :  10 1.697071410047059 (0, 1) 2
# Position match :  11 1.697071410047059 (0, 1) 2
# Position match :  13 1.4907518827069466 (0, 1) 2
# Old position :  13 (0, 2)
# Position match :  14 2.9310768367344098 (0, 1) 3
# Old position :  14 (0, 2)
# Position match :  15 3.796624583603685 (0, 1) 4
# Old position :  15 (0, 2)
# Position match :  16 5.039733152820567 (0, 1) 5
# Old position :  16 (0, 2)
# Position match :  17 5.73352985175046 (0, 1) 6
# Old position :  17 (0, 2)
# Position match :  18 0.5657913637908424 (0, 2) 1
# Position match :  19 7.019640614378815 (0, 1) 7
# Old position :  19 (1, 2)
# Position match :  20 1.2357599619010344 (1, 2) 0
# Old position :  20 (2, 0)
# Position match :  21 0.8763546969118502 (1, 2) 1
# Old position :  21 (2, 2)
# Position match :  22 37.28969520867271 (1, 2) 2
# Old position :  22 (1, 1)
# Position match :  23 68.55704404051853 (1, 2) 3
# Old position :  23 (2, 0)
# Position match :  24 0.9945305798190722 (2, 2) 0
# Old position :  24 (2, 0)
# Position match :  34 1.1772560833001022 (1, 1) 0
# Old position :  34 (2, 0)
# Position match :  35 1.4858940471178597 (2, 0) 4
# Position match :  36 1.4638380105985143 (2, 0) 4
# Position match :  37 1.4858940471178597 (2, 0) 4
# Position match :  38 1.4563595091803974 (2, 0) 4
# Position match :  41 0.9747899320350314 (2, 0) 4
# Old position :  41 (2, 1)
# Position match :  40 1.470561884676267 (2, 0) 5
# Old position :  40 (0, 0)
# Position match :  39 1.8366197956194925 (2, 0) 6
# Old position :  39 (1, 0)
# Iteration :  25
# Position match :  10 2.2183456679633275 (2, 0) 7
# Old position :  10 (0, 1)
# Position match :  11 2.5448044365976 (2, 0) 8
# Old position :  11 (0, 1)
# Position match :  13 3.243308271466251 (0, 1) 6
# Position match :  14 3.271589314724743 (0, 1) 6
# Position match :  15 3.21703895234344 (0, 1) 6
# Position match :  16 3.21703895234344 (0, 1) 6
# Position match :  17 3.241649268388938 (0, 1) 6
# Position match :  18 0.8061990216895353 (0, 0) 0
# Old position :  18 (0, 2)
# Position match :  19 5.5516846362907195 (1, 2) 4
# Old position :  19 (0, 1)
# Position match :  20 8.180924974497191 (1, 2) 5
# Position match :  21 8.286598473639591 (1, 2) 5
# Position match :  22 8.261040392291013 (1, 2) 5
# Position match :  23 8.165335153365103 (1, 2) 5
# Position match :  24 1.0360223304317986 (2, 1) 0
# Old position :  24 (2, 2)
# Position match :  34 1.3575113989664482 (2, 2) 0
# Old position :  34 (1, 1)
# Position match :  35 1.5249771467417492 (1, 1) 0
# Old position :  35 (2, 0)
# Position match :  36 1.4042872620843905 (1, 0) 0
# Old position :  36 (2, 0)
# Position match :  37 2.0009663545490204 (1, 2) 5
# Old position :  37 (2, 0)
# Position match :  38 1.1003174147961234 (2, 0) 6
# Position match :  41 1.046036449848649 (2, 0) 6
# Position match :  40 1.142764810684027 (2, 0) 6
# Position match :  39 1.1327523049616801 (2, 0) 6
# Iteration :  26
# Position match :  10 1.211614106359667 (2, 0) 6
# Position match :  11 1.211614106359667 (2, 0) 6
# Position match :  13 1.1398532865482416 (2, 0) 6
# Old position :  13 (0, 1)
# Position match :  14 1.9595365473352446 (0, 1) 4
# Position match :  15 1.9245724248896061 (0, 1) 4
# Position match :  16 1.9245724248896061 (0, 1) 4
# Position match :  17 1.9007488907280912 (0, 1) 4
# Position match :  18 0.8088815770924381 (0, 2) 0
# Old position :  18 (0, 0)
# Position match :  19 0.930043476493376 (0, 0) 0
# Old position :  19 (1, 2)
# Position match :  20 0.6904629304893973 (1, 2) 5
# Position match :  21 1.013768286069713 (0, 2) 1
# Old position :  21 (1, 2)
# Position match :  22 2.3361970405644175 (0, 2) 2
# Old position :  22 (1, 2)
# Position match :  23 2.937864322470854 (0, 2) 3
# Old position :  23 (1, 2)
# Position match :  24 0.6931233334615441 (1, 1) 1
# Old position :  24 (2, 1)
# Position match :  34 2.491412817406595 (1, 1) 2
# Old position :  34 (2, 2)
# Position match :  35 4.584661271112947 (1, 1) 3
# Position match :  36 4.398180485333633 (1, 1) 3
# Old position :  36 (1, 0)
# ...
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-fUhUZDGNFjDTurCDRycC3q">
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-7YrSbRkwtiR5j2GTqzNHMQ" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-7YrSbRkwtiR5j2GTqzNHMQ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-k7xDXTBQtbR3LLgixkN2aT" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-k7xDXTBQtbR3LLgixkN2aT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-8hrpeUymUqr8BWqUUHGSz6" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-8hrpeUymUqr8BWqUUHGSz6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-7VXwaWn3ufCpNzPvqtvte6" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-7VXwaWn3ufCpNzPvqtvte6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-VJHLNVCii5dXgcKYbAMdfq" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-VJHLNVCii5dXgcKYbAMdfq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-nZpsGSipc63LRhCwhDBXer" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-nZpsGSipc63LRhCwhDBXer">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-eCmYke3UfmPiXu9RisKSru" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">6</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-eCmYke3UfmPiXu9RisKSru">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-PAgZuhENBMz5NParuDwYkA" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">7</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-PAgZuhENBMz5NParuDwYkA">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-AGDC9qsYzv7YfHfCZSHpKD" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">8</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-AGDC9qsYzv7YfHfCZSHpKD">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-fUhUZDGNFjDTurCDRycC3q">
#         <div id="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-f5qfSh23FsoqgvurXwPFQB" class="ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q">
#             <h4 style="font-size: 12px; word-wrap: break-word;">9</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-fUhUZDGNFjDTurCDRycC3q-f5qfSh23FsoqgvurXwPFQB">
# (2, 1) []
# (2, 2) [17, 18]
#     <style>
#         #ipyplot-html-viewer-toggle-3zqmwbk9xE95CdhRhZTnFi {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-3zqmwbk9xE95CdhRhZTnFi {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-3zqmwbk9xE95CdhRhZTnFi {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-3zqmwbk9xE95CdhRhZTnFi:checked ~ #ipyplot-html-viewer-textarea-3zqmwbk9xE95CdhRhZTnFi {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-3zqmwbk9xE95CdhRhZTnFi:checked + #ipyplot-html-viewer-label-3zqmwbk9xE95CdhRhZTnFi:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-3zqmwbk9xE95CdhRhZTnFi">
#         <label id="ipyplot-html-viewer-label-3zqmwbk9xE95CdhRhZTnFi" for="ipyplot-html-viewer-toggle-3zqmwbk9xE95CdhRhZTnFi">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-3zqmwbk9xE95CdhRhZTnFi" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-TNehPKb999mtLPX3onuc6d {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-TNehPKb999mtLPX3onuc6d">
#     <div class="ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d">
#         <div id="ipyplot-content-div-TNehPKb999mtLPX3onuc6d-ejHB8M6fWcuE9pbmzGkxbK" class="ipyplot-content-div-TNehPKb999mtLPX3onuc6d">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TNehPKb999mtLPX3onuc6d-ejHB8M6fWcuE9pbmzGkxbK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d">
#         <div id="ipyplot-content-div-TNehPKb999mtLPX3onuc6d-jTpuKtZtMoWgYAY4H6q8js" class="ipyplot-content-div-TNehPKb999mtLPX3onuc6d">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TNehPKb999mtLPX3onuc6d-jTpuKtZtMoWgYAY4H6q8js">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-TNehPKb999mtLPX3onuc6d {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-TNehPKb999mtLPX3onuc6d span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-TNehPKb999mtLPX3onuc6d]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-TNehPKb999mtLPX3onuc6d">
#     <div class="ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d">
#         <div id="ipyplot-content-div-TNehPKb999mtLPX3onuc6d-ejHB8M6fWcuE9pbmzGkxbK" class="ipyplot-content-div-TNehPKb999mtLPX3onuc6d">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TNehPKb999mtLPX3onuc6d-ejHB8M6fWcuE9pbmzGkxbK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-TNehPKb999mtLPX3onuc6d">
#         <div id="ipyplot-content-div-TNehPKb999mtLPX3onuc6d-jTpuKtZtMoWgYAY4H6q8js" class="ipyplot-content-div-TNehPKb999mtLPX3onuc6d">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-TNehPKb999mtLPX3onuc6d-jTpuKtZtMoWgYAY4H6q8js">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
import importlib
importlib.reload(n2d)
# Out:
# <module 'network2d' from '/home/peter/Python_projects/pkg_mod/network2d.py'>

# %%
# Update molecule positions in database


#import psycopg2

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")

cur = db_nn.cursor()
sql = 'SELECT * FROM network."Mol_Net" WHERE "Network" = '+str(network)
cur.execute(sql)
net_count = cur.fetchall()

#mol_count = mol_count[0]
if net_count == []:
    print('No Network')
    for i,j in net_mol.items():
        print(i,j)
        for k in j:
            x = i[0]
            y = i[1]
            #print(k, x, y)
            sql = 'INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (' \
            +str(k)+','+str(x)+','+str(y)+','+str(network)+')'
            print(sql)
            cur.execute(sql)
            #id = cur.fetchone()[0]
            #print(id)
    db_nn.commit()
else:
    print('Structures Available : ',net_count)
    for i,j in net_mol.items():
        #print(i,j)
        for k in j:
            x = i[0]
            y = i[1]
            sql = 'SELECT 1 FROM network."Mol_Net" WHERE "Network" = 1 AND "Struct_ID" = '+str(k)
            cur.execute(sql)
            fl = cur.fetchone()
            if fl != None:
                #print('Update',k, fl)
                sql = 'UPDATE network."Mol_Net" SET "X" = '+str(x)+', "Y" = '+str(y)+ \
                ' WHERE "Struct_ID" = '+str(k)+' AND "Network" = '+str(network)
                #print(sql)
            else:
                #print('Insert',k, fl)
                sql = 'INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (' \
                +str(k)+','+str(x)+','+str(y)+','+str(network)+')'
            print(sql)
            cur.execute(sql)
            
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
# Out:
# Structures Available :  [(23, 0.0, 0.0, 2), (23, 0.0, 0.0, 2), (21, 0.0, 2.0, 2), (21, 0.0, 2.0, 2), (18, 2.0, 0.0, 2), (18, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (35, 2.0, 1.0, 2), (35, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (19, 2.0, 2.0, 2), (19, 2.0, 2.0, 2)]
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 0 WHERE "Struct_ID" = 17 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 0 WHERE "Struct_ID" = 18 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 16 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 20 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 22 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 23 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 24 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 34 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 35 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 36 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 37 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 38 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 10 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 11 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 13 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 14 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 0, "Y" = 2 WHERE "Struct_ID" = 15 AND "Network" = 2
# UPDATE network."Mol_Net" SET "X" = 1, "Y" = 1 WHERE "Struct_ID" = 19 AND "Network" = 2
# INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (40,1,1,2)
# INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (39,1,1,2)
# INSERT INTO network."Mol_Net" ("Struct_ID","X","Y","Network") VALUES (41,1,1,2)
# UPDATE network."Mol_Net" SET "X" = 2, "Y" = 0 WHERE "Struct_ID" = 21 AND "Network" = 2

# %%
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

# %%
# update network neurons in database

#print(net)

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
for x in range(0, ms):
    for y in range(0, ms):
        for f in range(0, fp):
            #print(x,y,f)
            fi = fp_index[f]
            sql = 'SELECT 1 FROM network."Neurons_2D" WHERE "Network" = '+str(network)+' AND "X" = '+str(x)+ \
            ' AND "Y" = '+str(y)+ ' AND "Fingerprint_ID" = ' +str(fi)
            #print(sql)
            cur.execute(sql)
            fl = cur.fetchone()
            #print(fl, sql)
            #print(x,y,fi,net[x,y,f,0],net[x,y,f,1])
            if fl != None:
                #print('UPDATE',fl,x,y,fi)
                sql = 'UPDATE network."Neurons_2D" SET "Sigma" = '+str(net[x,y,f,1])+ ', "Amplitude" = '+str(net[x,y,f,0])+\
                ' WHERE "Network" = '+str(network)+' AND "X" = '+str(x)+ \
                ' AND "Y" = '+str(y)+ ' AND "Fingerprint_ID" = ' +str(fi)
                print(sql)
            else:
                sql = 'INSERT INTO network."Neurons_2D" ("X","Y","Sigma", "Amplitude", "Network", "Fingerprint_ID") '+ \
                'VALUES ('+str(x)+','+str(y)+','+str(net[x,y,f,1])+','+str(net[x,y,f,0])+','+str(network)+','+str(fi)+')'
                print(sql)
            cur.execute(sql)
            
db_nn.commit()
cur.close()
db_nn.close()
#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
# Out:
# UPDATE network."Neurons_2D" SET "Sigma" = 2.7014380694477698, "Amplitude" = 0.4318473679675555 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.21364992095775825, "Amplitude" = 0.29702970180460436 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.8051560646989859, "Amplitude" = 1.5328170390033176 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.2732224349353277, "Amplitude" = 0.4083714992841697 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 3.3470496978932616, "Amplitude" = 0.02215986301491671 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.31016979512339227, "Amplitude" = 0.4872552106334578 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.10363354053246296, "Amplitude" = 0.12225786737277476 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5156856733770324, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 1.0003290723024374, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4318473679675555 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2970297018046045 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5328170390033173 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4083714992841697 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.022159863014916705 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4872552106334577 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.12225786737277469 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 1.2686689862008962, "Amplitude" = 0.43184736796755535 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.879522757214471, "Amplitude" = 0.2970297018046044 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.47434570757545125, "Amplitude" = 1.5328170390033176 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 1.066723829755173, "Amplitude" = 0.40837149928416977 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.015773505999599417, "Amplitude" = 0.02215986301491671 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.966223911534873, "Amplitude" = 0.48725521063345784 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5416064715675486, "Amplitude" = 0.12225786737277465 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.4030395701725931, "Amplitude" = 0.31900130150942246 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5620400590121161, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 0 AND "Y" = 2 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.43184736796755546 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.29702970180460453 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5328170390033173 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4083714992841697 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.022159863014916705 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4872552106334577 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.12225786737277469 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 5.3192873527424265, "Amplitude" = 0.4318473679675561 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 4.481930151845036, "Amplitude" = 0.2970297018046045 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 1.3112050109597302, "Amplitude" = 1.5328170390033176 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.276125159106031, "Amplitude" = 0.40837149928416977 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 2.4308046273649477, "Amplitude" = 0.02215986301491671 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.2884811027516172, "Amplitude" = 0.4872552106334577 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 3.2666840812138624, "Amplitude" = 0.12225786737277468 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.8660281813550684, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.06931055948722509, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4318473679675555 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2970297018046045 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5328170390033173 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4083714992841697 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.022159863014916705 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4872552106334577 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.12225786737277469 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 1 AND "Y" = 2 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 3.3581843092495838, "Amplitude" = 0.43184736796755563 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5503331261774076, "Amplitude" = 0.29702970180460453 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.6386521063979564, "Amplitude" = 1.5328170390033176 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.5471961037785978, "Amplitude" = 0.40837149928416977 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 1.0536271073440189, "Amplitude" = 0.022159863014916723 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.6175004091053254, "Amplitude" = 0.4872552106334578 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.7876552069612018, "Amplitude" = 0.12225786737277468 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.7646228798228248, "Amplitude" = 0.3190013015094226 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.9940051162994779, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 0 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.43184736796755546 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.29702970180460453 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5328170390033173 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4083714992841697 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.022159863014916705 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4872552106334577 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.12225786737277469 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.3190013015094225 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 1 AND "Fingerprint_ID" = 35
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4318473679675557 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 27
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.2970297018046044 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 42
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 1.5328170390033176 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 9
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.40837149928416977 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 8
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.02215986301491672 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 25
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.4872552106334578 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 11
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.1222578673727747 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 40
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.3190013015094226 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 33
# UPDATE network."Neurons_2D" SET "Sigma" = 0.0, "Amplitude" = 0.14958067892988838 WHERE "Network" = 2 AND "X" = 2 AND "Y" = 2 AND "Fingerprint_ID" = 35

# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

network = 2
msn = 0
fpn = 0


#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")
cur = db_nn.cursor()
sql = 'SELECT * FROM network."Neurons_2D" WHERE "Network" = '+str(network)
cur.execute(sql)
fl = cur.fetchall()
if len(fl) != 0:
    print('Network Found')
    for i in fl:
        msn = max(msn, int(i[0]))
    msn = msn+1
    fpn = int(len(fl)/(msn*msn))
else:
    print('Naive Network')
print(fl, len(fl), msn,fpn)

#print
#print(net)
#print
ms = msn
fp = fpn
net = np.zeros((ms, ms, fp, 2))
#print(nett)
if len(fl) != 0:
    fp_index = []
    print('Transferring Network Values')
    for i in range(0,fp):
        j = fl[i][5]
        #print(j)
        fp_index.append(j)
    
    print(fp_index)
    
    fpa = ''
    for i in fp_index:
        #fpa.append(i[0])
        fpa = fpa + str(i) +','
    fpa = fpa[:-1]
    
    print('Fingerprints chosen : ',fpa)


    for i in fl:
        #print(i)
        x = int(i[0])
        y = int(i[1])
        f = i[5]
        s = i[2]
        a = i[3]
        fi = fp_index.index(f)
        #print(x,y,f, fi, a, s)
        net[x][y][fi][0] = a
        net[x][y][fi][1] = s
else:
    # generate random floating point values
    print('Random Network Seed')
    from random import seed
    from random import random
    # seed random number generator
    t = int(time.time()*1000)
    # print(t)
    seed(t)

    print()
    #r = 5000
    for x in range(0,ms):
        for y in range(0, ms):
            for f in range(0,fp):
                #x = int(ms*random())
                #y = int(ms*random())
                #f = int(fp*random())
                # t = int(2*random())
                v = int((fp_max[f]+1)*random())
                # print(x,y,f,t,v)
                net[x][y][f][0] = v
print(net)
# Out:
# Network Found
# [(0.0, 0.0, 0.0, 1.1915051675801644, 2, 27, 15), (0.0, 0.0, 0.0, 1.1915051675801644, 2, 27, 110), (0.0, 0.0, 0.0, 0.9569608688685728, 2, 8, 16), (0.0, 0.0, 0.0, 0.9569608688685728, 2, 8, 111), (0.0, 0.0, 0.0, 1.016607388204994, 2, 11, 17), (0.0, 0.0, 0.0, 1.016607388204994, 2, 11, 112), (0.0, 0.0, 0.0, 1.5718584336448365, 2, 9, 18), (0.0, 0.0, 0.0, 1.5718584336448365, 2, 9, 113), (0.0, 0.0, 0.0, 0.45968446195300766, 2, 42, 19), (0.0, 0.0, 0.0, 0.45968446195300766, 2, 42, 114), (0.0, 0.0, 0.0, 0.0770516486678105, 2, 25, 20), (0.0, 0.0, 0.0, 0.0770516486678105, 2, 25, 115), (0.0, 0.0, 0.0, 0.2885832941590392, 2, 35, 21), (0.0, 0.0, 0.0, 0.2885832941590392, 2, 35, 116), (0.0, 0.0, 0.0, 0.28832276555970526, 2, 40, 22), (0.0, 0.0, 0.0, 0.28832276555970526, 2, 40, 117), (0.0, 0.0, 0.0, 0.28034972903496946, 2, 33, 23), (0.0, 0.0, 0.0, 0.28034972903496946, 2, 33, 118), (0.0, 1.0, 0.0, 0.987256649809609, 2, 27, 24), (0.0, 1.0, 0.0, 0.987256649809609, 2, 27, 119), (0.0, 1.0, 0.0, 1.0280271364617768, 2, 8, 25), (0.0, 1.0, 0.0, 1.0280271364617768, 2, 8, 120), (0.0, 1.0, 0.0, 1.0626053300154614, 2, 11, 26), (0.0, 1.0, 0.0, 1.0626053300154614, 2, 11, 121), (0.0, 1.0, 0.0, 1.5724360616464697, 2, 9, 27), (0.0, 1.0, 0.0, 1.5724360616464697, 2, 9, 122), (0.0, 1.0, 0.0, 0.44539319636980607, 2, 42, 28), (0.0, 1.0, 0.0, 0.44539319636980607, 2, 42, 123), (0.0, 1.0, 0.0, 0.07705164866783844, 2, 25, 29), (0.0, 1.0, 0.0, 0.07705164866783844, 2, 25, 124), (0.0, 1.0, 0.0, 0.28989446456208556, 2, 35, 30), (0.0, 1.0, 0.0, 0.28989446456208556, 2, 35, 125), (0.0, 1.0, 0.0, 0.2896320821988233, 2, 40, 31), (0.0, 1.0, 0.0, 0.2896320821988233, 2, 40, 126), (0.0, 1.0, 0.0, 0.2802743080823138, 2, 33, 32), (0.0, 1.0, 0.0, 0.2802743080823138, 2, 33, 127), (0.0, 2.0, 0.0, 1.2377218795533633, 2, 27, 33), (0.0, 2.0, 0.0, 1.2377218795533633, 2, 27, 128), (0.0, 2.0, 0.0, 0.9855135885869585, 2, 8, 34), (0.0, 2.0, 0.0, 0.9855135885869585, 2, 8, 129), (0.0, 2.0, 0.0, 1.0354335030168837, 2, 11, 35), (0.0, 2.0, 0.0, 1.0354335030168837, 2, 11, 130), (0.0, 2.0, 0.0, 1.5721391825007225, 2, 9, 36), (0.0, 2.0, 0.0, 1.5721391825007225, 2, 9, 131), (0.0, 2.0, 0.0, 0.4514839126086283, 2, 42, 37), (0.0, 2.0, 0.0, 0.4514839126086283, 2, 42, 132), (0.0, 2.0, 0.0, 0.07705164866782947, 2, 25, 38), (0.0, 2.0, 0.0, 0.07705164866782947, 2, 25, 133), (0.0, 2.0, 0.0, 0.2898794416393304, 2, 35, 39), (0.0, 2.0, 0.0, 0.2898794416393304, 2, 35, 134), (0.0, 2.0, 0.0, 0.2896177213062504, 2, 40, 40), (0.0, 2.0, 0.0, 0.2896177213062504, 2, 40, 135), (0.0, 2.0, 0.0, 0.28031135820567954, 2, 33, 41), (0.0, 2.0, 0.0, 0.28031135820567954, 2, 33, 136), (1.0, 0.0, 5.158790928339372, 1.0921005950642426, 2, 27, 42), (1.0, 0.0, 5.158790928339372, 1.0921005950642426, 2, 27, 137), (1.0, 0.0, 1.5034196349913378, 0.9982058890584521, 2, 8, 43), (1.0, 0.0, 1.5034196349913378, 0.9982058890584521, 2, 8, 138), (1.0, 0.0, 1.4444993119278673, 1.043052453067753, 2, 11, 44), (1.0, 0.0, 1.4444993119278673, 1.043052453067753, 2, 11, 139), (1.0, 0.0, 1.9404842100852324, 1.5721922847799032, 2, 9, 45), (1.0, 0.0, 1.9404842100852324, 1.5721922847799032, 2, 9, 140), (1.0, 0.0, 0.0053751265636040714, 0.45087004899852273, 2, 42, 46), (1.0, 0.0, 0.0053751265636040714, 0.45087004899852273, 2, 42, 141), (1.0, 0.0, 3.1567525052124545, 0.07705164866782828, 2, 25, 47), (1.0, 0.0, 3.1567525052124545, 0.07705164866782828, 2, 25, 142), (1.0, 0.0, 1.9950458880738549, 0.2895281143035653, 2, 35, 48), (1.0, 0.0, 1.9950458880738549, 0.2895281143035653, 2, 35, 143), (1.0, 0.0, 0.005423883245124653, 0.2892664417233838, 2, 40, 49), (1.0, 0.0, 0.005423883245124653, 0.2892664417233838, 2, 40, 144), (1.0, 0.0, 0.99458330947147, 0.2803058132705241, 2, 33, 50), (1.0, 0.0, 0.99458330947147, 0.2803058132705241, 2, 33, 145), (1.0, 1.0, 0.0, 0.971251219527035, 2, 27, 51), (1.0, 1.0, 0.0, 0.971251219527035, 2, 27, 146), (1.0, 1.0, 0.0, 1.0301720202425355, 2, 8, 52), (1.0, 1.0, 0.0, 1.0301720202425355, 2, 8, 147), (1.0, 1.0, 0.0, 1.0636993691310712, 2, 11, 53 ...
# Transferring Network Values
# [27, 27, 8, 8, 11, 11, 9, 9, 42, 42, 25, 25, 35, 35, 40, 40, 33, 33]
# Fingerprints chosen :  27,27,8,8,11,11,9,9,42,42,25,25,35,35,40,40,33,33
# [[[[1.19150517 0.        ]
#    [0.         0.        ]
#    [0.95696087 0.        ]
#    [0.         0.        ]
#    [1.01660739 0.        ]
#    [0.         0.        ]
#    [1.57185843 0.        ]
#    [0.         0.        ]
#    [0.45968446 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28858329 0.        ]
#    [0.         0.        ]
#    [0.28832277 0.        ]
#    [0.         0.        ]
#    [0.28034973 0.        ]
#    [0.         0.        ]]
#
#   [[0.98725665 0.        ]
#    [0.         0.        ]
#    [1.02802714 0.        ]
#    [0.         0.        ]
#    [1.06260533 0.        ]
#    [0.         0.        ]
#    [1.57243606 0.        ]
#    [0.         0.        ]
#    [0.4453932  0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28989446 0.        ]
#    [0.         0.        ]
#    [0.28963208 0.        ]
#    [0.         0.        ]
#    [0.28027431 0.        ]
#    [0.         0.        ]]
#
#   [[1.23772188 0.        ]
#    [0.         0.        ]
#    [0.98551359 0.        ]
#    [0.         0.        ]
#    [1.0354335  0.        ]
#    [0.         0.        ]
#    [1.57213918 0.        ]
#    [0.         0.        ]
#    [0.45148391 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28987944 0.        ]
#    [0.         0.        ]
#    [0.28961772 0.        ]
#    [0.         0.        ]
#    [0.28031136 0.        ]
#    [0.         0.        ]]]
#
#
#  [[[1.0921006  5.15879093]
#    [0.         0.        ]
#    [0.99820589 1.50341963]
#    [0.         0.        ]
#    [1.04305245 1.44449931]
#    [0.         0.        ]
#    [1.57219228 1.94048421]
#    [0.         0.        ]
#    [0.45087005 0.00537513]
#    [0.         0.        ]
#    [0.07705165 3.15675251]
#    [0.         0.        ]
#    [0.28952811 1.99504589]
#    [0.         0.        ]
#    [0.28926644 0.00542388]
#    [0.         0.        ]
#    [0.28030581 0.99458331]
#    [0.         0.        ]]
#
#   [[0.97125122 0.        ]
#    [0.         0.        ]
#    [1.03017202 0.        ]
#    [0.         0.        ]
#    [1.06369937 0.        ]
#    [0.         0.        ]
#    [1.57244016 0.        ]
#    [0.         0.        ]
#    [0.44523527 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28990723 0.        ]
#    [0.         0.        ]
#    [0.28964483 0.        ]
#    [0.         0.        ]
#    [0.28027395 0.        ]
#    [0.         0.        ]]
#
#   [[1.10133312 0.        ]
#    [0.         0.        ]
#    [1.00497447 0.        ]
#    [0.         0.        ]
#    [1.04750465 0.        ]
#    [0.         0.        ]
#    [1.57225791 0.        ]
#    [0.         0.        ]
#    [0.44896925 0.        ]
#    [0.         0.        ]
#    [0.07705165 0.        ]
#    [0.         0.        ]
#    [0.28982315 0.        ]
#    [0.         0.        ]
#    [0.2895612  0.        ]
#    [0.         0.        ]
#    [0.28029687 0.        ]
#    [0.         0.        ]]]
#
#
#  [[[1.03419717 5.00187884]
#    [0.         0.        ]
#    [1.00906079 1.17552885]
#    [0.         0.        ]
#    [1.04950434 1.21799363]
#    [0.         0.        ]
#    [1.57223514 1.65548328]
#    [0.         0.        ]
#    [0.44943528 0.18972776]
#    [0.         0.        ]
#    [0.07705165 4.69513873]
#    [0.         0.        ]
#    [0.28956801 1.35761683]
#    [0.         0.        ]
#    [0.2893061  0.08108868]
#    [0.         0.        ]
#    [0.28030186 0.62542433]
#    [0.         0.        ]]
#
#   [[0.91957562 1.29951535]
#    [0.         0.        ]
#    [1.03538282 0.90845737]
#    [0.         0.        ]
#    [1.06629242 0.81810029]
#    [0.         0.        ]
#    [1.5724487  0.46921054]
#    [0.         0.        ]
#    [0.4449434  0.58134559]
#    [0.         0.        ]
#    [0.07705165 0.07907634]
#    [0.         0.        ]
#    [0.28992091 0.56405286]
#    [0.         0.        ]
#    [0.28965847 0.56401317]
#    [0.         0.        ]
#    [0.28027323 0.3694484 ]
#    [0.         0.        ]]
#
#   [[0.98489627 4.54626733]
#    [0.         0.        ]
#    [1.02974082 1.10052745]
#    [0.         0.        ]
#    [1.0634975  1.18997057]
#    [0.         0.        ]
#    [1.57243979 0.52936129]
#    [0.         0.        ]
#    [0.4452432  0.96973324]
#    [0.         0.        ]
#    [0.07705165 3.03134705]
#    [0.         0.        ]
#    [0.28991084 0.13625164]
#    [0.         0.        ]
#    [0.28964843 1.95780764]
#    [0.         0.        ]
#    [0.28027398 0.12005684]
#    [0.         0.        ]]]]

# %%
import numpy as np
import math
import psycopg2
import collections
import network2d as n2d
import time

network = 2

#db_nn = psycopg2.connect(host = "localhost", dbname="Chemistry", user="postgres", password="postgres")
db_nn = psycopg2.connect(host = "192.168.86.31", dbname="Chemistry", user="postgres", password="postgres")

cur = db_nn.cursor()
sql = 'SELECT * FROM network."Mol_Net" WHERE "Network" = '+str(network)
cur.execute(sql)
ml = cur.fetchall()

print(ml)
# Out:
# [(23, 0.0, 0.0, 2), (23, 0.0, 0.0, 2), (21, 0.0, 2.0, 2), (21, 0.0, 2.0, 2), (18, 2.0, 0.0, 2), (18, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (17, 2.0, 0.0, 2), (35, 2.0, 1.0, 2), (35, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (24, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (34, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (36, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (37, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (38, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (10, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (11, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (13, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (14, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (15, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (16, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (20, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (22, 2.0, 1.0, 2), (19, 2.0, 2.0, 2), (19, 2.0, 2.0, 2)]
